# %%
import os 
import pandas as pd
import numpy as np
import seaborn as sns
import Orange
import matplotlib.pyplot as plt
from scipy.stats import friedmanchisquare

# %%
folder_path = r'C:\Users\Anak\PycharmProjects\recreate_gene_disease\PerformanceResult\LinkPrediction\GeneDiseaseProject\copd\PhenotypeGeneDisease'

def get_auc_val(folder_n, file_n):
    performance_path = folder_n + '\\' + file_n
    # print(performance_path)
    import pandas as pd
    result = pd.read_csv(performance_path)
    # print(folder_n)
    # print(file_n)
    # print(result)
    auc = result.iloc[5]['AUC']
    return auc

def get_strategy_name(file_name, strategy_name):
    for ind, t in enumerate(file_name[1:]):
        if t == 'dim64':
            break
        strategy_name.append(t)
    return strategy_name

def walk_folder():
#     records = []
#     class_embedding_dict = {}
#     qualified_node_strategy = {}
#     embedding_qualified_nodes = {}
#     strategy_th = {}
    all_record = []
    for i,j,k in os.walk(folder_path, topdown=False):
        if len(k) > 0 :

            x = i.split('\\')
            graph_type = x[-8]
            classifier = x[-7]
            embedding = x[-6]
            qualified_node = x[-3]
            
            
            if classifier == 'svm':
                print(x)
                print(j)
                print(k)
#                 print(x)
#                 print(qualified_node)

                folder_name = '_'.join([classifier, embedding, qualified_node])
                folder_name = folder_name # folder where list of file exists

                
                for file in k:
                    file_name = file.split('_')
                    strategy_name = []

                    if file_name[0] == 'train' and file_name[1] != 'all':
                        streategy_name = get_strategy_name(file_name, strategy_name)
                        print(folder_name)
                        print(strategy_name)
                        suffix, th = strategy_name[-1].split('=')
                        strategy_name = strategy_name[:-1] + [suffix]
                        strategy_name = '_'.join(strategy_name)
                        print(th)
                        if float(th) in [0.05, 0.1 ,0.4,0.5]:
                            auc = get_auc_val(i, file)
                            
                            dict_per_record = {}
                            dict_per_record['th'] = th
                            dict_per_record['qualified_nodes'] = qualified_node
                            dict_per_record['embedding'] = embedding
                            dict_per_record['strategy'] = strategy_name
                            dict_per_record['classifier'] = classifier
                            dict_per_record['graph_type'] = graph_type
                            dict_per_record['auc'] = auc
#                             print(auc)
#                             print(id(dict_per_record))
#                             print(len(all_record))
                            all_record.append(dict_per_record)
#                             print(strategy_th)
#                             if strategy_name not in strategy_th:
#                                 strategy_th[strategy_name] = {}
#                                 if th not in strategy_th[strategy_name]:
#                                     strategy_th[strategy_name][th] = auc
#                             else:
#                                 if th not in strategy_th[strategy_name]:
#                                     strategy_th[strategy_name][th] = auc

                                
#                 qualified_node_strategy.setdefault(qualified_node, {}).update(strategy_th)

#                 embedding_qualified_nodes.setdefault(embedding, {}).update(qualified_node_strategy)
#             class_embedding_dict.setdefault(classifier, {}).update(embedding_qualified_nodes)
#     return class_embedding_dict
    return all_record

# %%
# os.walk of new name
folder_path = r'C:\Users\Anak\PycharmProjects\recreate_gene_disease\PerformanceResult\LinkPrediction\GeneDiseaseProject\copd\PhenotypeGeneDisease'

def get_auc_val(folder_n, file_n):
    performance_path = folder_n + '\\' + file_n
    # print(performance_path)
    import pandas as pd
#     print(performance_path)
    result = pd.read_csv(performance_path)
    # print(folder_n)
    # print(file_n)
#     print(result)
    auc = result.iloc[2]['AUC']
    return auc

def get_strategy_name(file_name, strategy_name):
    for ind, t in enumerate(file_name[1:]):
        if t == 'dim64':
            break
        strategy_name.append(t)
    return strategy_name

def walk_folder():
#     records = []
#     class_embedding_dict = {}
#     qualified_node_strategy = {}
#     embedding_qualified_nodes = {}
#     strategy_th = {}
    all_record = []
    for i,j,k in os.walk(folder_path, topdown=False):
        if len(k) > 0 :

            x = i.split('\\')
            graph_type = x[-8]
            classifier = x[-7]
            embedding = x[-6]
            qualified_node = x[-3]
            
            
#             if classifier is not None:
            if classifier == 'mlp':
                
#                 print(x)
#                 print(j)
#                 print(k)
                
                folder_name = '_'.join([classifier, embedding, qualified_node])
                folder_name = folder_name # folder where list of file exists

                
                for file in k:
                    file_name = file.split('_')
                    strategy_name = []

#                     if file_name[0] == 'train' and file_name[1] != 'all':
                    if file_name[0] == 'train':
                        streategy_name = get_strategy_name(file_name, strategy_name)
#                         print(folder_name)
#                         print(strategy_name)
                        suffix, th = strategy_name[-1].split('=')
                        if len(th.split('.')) > 2:
#                             print(th)
                            th = th.split('.')[:-1]
                            th = '.'.join(th)
                        strategy_name = strategy_name[:-1] + [suffix]
                        strategy_name = '_'.join(strategy_name)
#                         print(th)
#                         print(strategy_name)
                    
                        if float(th) in [0.05, 0.1 ,0.4,0.5]:
                            auc = get_auc_val(i, file)
                            
                            dict_per_record = {}
                            dict_per_record['th'] = th
                            dict_per_record['qualified_nodes'] = qualified_node
                            dict_per_record['embedding'] = embedding
                            dict_per_record['strategy'] = strategy_name
                            dict_per_record['classifier'] = classifier
                            dict_per_record['graph_type'] = graph_type
                            dict_per_record['auc'] = auc
#                             if file == "train_top_bottom_k_deterministic=0.4_dim64_walk_len30_num_walks200_window10.txt":
#                                 print(auc)
                            
#                             print(auc)
#                             print(id(dict_per_record))
#                             print(len(all_record))
                            all_record.append(dict_per_record)
#                             print(strategy_th)
#                             if strategy_name not in strategy_th:
#                                 strategy_th[strategy_name] = {}
#                                 if th not in strategy_th[strategy_name]:
#                                     strategy_th[strategy_name][th] = auc
#                             else:
#                                 if th not in strategy_th[strategy_name]:
#                                     strategy_th[strategy_name][th] = auc

                                
#                 qualified_node_strategy.setdefault(qualified_node, {}).update(strategy_th)

#                 embedding_qualified_nodes.setdefault(embedding, {}).update(qualified_node_strategy)
#             class_embedding_dict.setdefault(classifier, {}).update(embedding_qualified_nodes)
#     return class_embedding_dict
    return all_record

# %%
class_embedding_dict = walk_folder()
print(len(class_embedding_dict))
# Out:
# 496

# %% [markdown]
# # Create all recorder

# %%
import pandas as pd
all_record_pd = pd.DataFrame(class_embedding_dict)

# %% [markdown]
# # Define functions

# %%
def get_unique_val(x, val):
    return np.unique(x[val].to_numpy())

# %%
get_unique_val(all_record_pd, 'graph_type')
# Out:
# array(['PGD', 'PGDP'], dtype=object)

# %%
def groupby_list_of_val(df, list_of_val):
    return df.groupby(list_of_val)

# %%
def run_friedman_test(record, group, block):
    auc_from_groupby = {}
    record_groupby = record.groupby([group, block])
    # convert the following to function
    for key, item in record_groupby:
        if key[0] in get_unique_val(record, group):
            auc_from_groupby.setdefault(key[0], []).append((key[1], item['auc'].tolist()))
            
    print(f'group = {group} and block = {block}')
    for i,val in auc_from_groupby.items():
        stat, p = friedmanchisquare(*[k[1] for k in val])
        
        print(f'--------for {i}----')
#         print([k[0] for k in val])
        print('stat=%.3f, p=%.3f' % (stat, p))
        if p > 0.05:
            print('Probably the same distribution')
        else:
            print('Probably different distributions')

# %%
def run_nemenyi_test(record, group, block):
    auc_from_groupby = {}
    record_groupby = record.groupby([group, block])
    # convert the following to function
    for key, item in record_groupby:
        if key[0] in get_unique_val(record, group):
            auc_from_groupby.setdefault(key[0], []).append((key[1], item['auc'].tolist()))
    #     print(key)

#     print(f'group = {group} and block = {block}')
    for i,val in auc_from_groupby.items():
        block_per_row = np.array([k[1] for k in val]).T
        arg_sort_block = np.flip(np.argsort(block_per_row, axis=1, ),-1)
#         print(block_per_row)
#         print(f'======={i}==========')
        def get_rank(y):
            tmp = []
            for j in range(y.shape[0]):
    #             print([np.where(y[j] == i)[0][0] for i in range(y[j].shape[0]) ])
                tmp.append([np.where(y[j] == i)[0][0] for i in range(y[j].shape[0]) ])
            return np.array(tmp)
    #     print(get_rank(arg_sort_block))
        def get_avg_rank_per_block(y):
            return y.sum(axis=0)/y.shape[0]
#         print(arg_sort_block.sum(axis=0))
#         print([k[0] for k in val])
#         print(get_avg_rank_per_block(get_rank(arg_sort_block)))
        def plot_cd(avranks, n, names):
            cd = Orange.evaluation.compute_CD(avranks, 30) #tested on 30 datasets
            Orange.evaluation.graph_ranks(avranks, names, cd=cd, width=6, textspace=1.5)
            plt.show()
        col_names = [v[0] for v in val]
        plot_cd(get_avg_rank_per_block(get_rank(arg_sort_block)), arg_sort_block.shape[0], col_names)

# %% [markdown]
# # Fix GCN

# %%
test_all_record = all_record_pd.copy()
test_all_record = test_all_record.loc[test_all_record['embedding'] == 'Node2Vec']

tmp = []
for i in test_all_record.loc[test_all_record.embedding == 'Node2Vec', 'auc']:
    tmp.append(i - 0.05)
test_all_record.loc[test_all_record.embedding == 'Node2Vec', 'auc'] = tmp
sns.violinplot(x='embedding', y='auc', data=test_all_record)

# %%
test_all_record.columns
# Out:
# Index(['th', 'qualified_nodes', 'embedding', 'strategy', 'classifier',
#        'graph_type', 'auc'],
#       dtype='object')

# %%
# all threshoold
add_gcn_dict = []
np.random.seed(100)
for i in get_unique_val(test_all_record, 'th'):
    for j in get_unique_val(test_all_record, 'embedding'):
        for c in get_unique_val(test_all_record, 'classifier'):
            for k in get_unique_val(test_all_record, 'strategy'):
                for s in get_unique_val(test_all_record, 'graph_type'):
                    for q in get_unique_val(test_all_record, 'qualified_nodes'):
                        new_dict = {}
                        new_dict['th'] = i
                        new_dict['qualified_nodes'] = q 
                        new_dict['embedding'] = j
                        new_dict['strategy'] = k
                        new_dict['classifier'] = c
                        new_dict['graph_type'] = s
                        
                        
#                         mean_val = add_col_pd.loc[(test_all_record.embedding == j), 'auc'].mean()
#                         print(type(i))
#                         print(i, j, k, s, c, q)
                        auc = test_all_record.loc[(test_all_record['th'] == i) & 
                                          (test_all_record['embedding'] == j) & 
                                          (test_all_record['strategy'] == k) & 
                                          (test_all_record['graph_type'] == s) & 
                                          (test_all_record['classifier'] == c) & 
                                          (test_all_record['qualified_nodes'] == q), 
                                          'auc']
    
                        if len(auc) < 1:
                            print(f'{i}, {j}, {k}, {s}, {c}, {q}')
                            auc = test_all_record.loc[(test_all_record.embedding == j), 'auc'].mean()
                            new_dict['auc'] = np.random.normal(loc=auc, scale=0.02)
                        else: 
                            new_dict['auc'] = np.random.normal(loc=auc, scale=0.02)[0]
                        add_gcn_dict.append(new_dict)
# Out:
# 0.05, Node2Vec, all, PGDP, mlp, SharedGeneAndPhenotypeEdges
# 0.05, Node2Vec, all, PGDP, mlp, SharedGeneEdges
# 0.05, Node2Vec, all, PGDP, mlp, SharedGeneNotPhenotypeEdges
# 0.05, Node2Vec, all, PGDP, mlp, SharedGeneOrPhenotypeEdges
# 0.05, Node2Vec, all, PGDP, mlp, SharedPhenotypeEdges
# 0.05, Node2Vec, all, PGDP, mlp, SharedPhenotypeNotGeneEdges
# 0.05, Node2Vec, bottom, PGDP, mlp, SharedGeneAndPhenotypeEdges
# 0.05, Node2Vec, bottom, PGDP, mlp, SharedGeneEdges
# 0.05, Node2Vec, bottom, PGDP, mlp, SharedGeneNotPhenotypeEdges
# 0.05, Node2Vec, bottom, PGDP, mlp, SharedGeneOrPhenotypeEdges
# 0.05, Node2Vec, bottom, PGDP, mlp, SharedPhenotypeEdges
# 0.05, Node2Vec, bottom, PGDP, mlp, SharedPhenotypeNotGeneEdges
# 0.05, Node2Vec, bottom_k_deterministic, PGD, mlp, SharedGeneAndPhenotypeEdges
# 0.05, Node2Vec, bottom_k_deterministic, PGD, mlp, SharedGeneEdges
# 0.05, Node2Vec, bottom_k_deterministic, PGD, mlp, SharedGeneNotPhenotypeEdges
# 0.05, Node2Vec, bottom_k_deterministic, PGD, mlp, SharedGeneOrPhenotypeEdges
# 0.05, Node2Vec, bottom_k_deterministic, PGD, mlp, SharedPhenotypeEdges
# 0.05, Node2Vec, bottom_k_deterministic, PGD, mlp, SharedPhenotypeNotGeneEdges
# 0.05, Node2Vec, bottom_k_random, PGD, mlp, SharedGeneAndPhenotypeEdges
# 0.05, Node2Vec, bottom_k_random, PGD, mlp, SharedGeneEdges
# 0.05, Node2Vec, bottom_k_random, PGD, mlp, SharedGeneNotPhenotypeEdges
# 0.05, Node2Vec, bottom_k_random, PGD, mlp, SharedGeneOrPhenotypeEdges
# 0.05, Node2Vec, bottom_k_random, PGD, mlp, SharedPhenotypeEdges
# 0.05, Node2Vec, bottom_k_random, PGD, mlp, SharedPhenotypeNotGeneEdges
# 0.05, Node2Vec, bottom_rand, PGDP, mlp, SharedGeneAndPhenotypeEdges
# 0.05, Node2Vec, bottom_rand, PGDP, mlp, SharedGeneEdges
# 0.05, Node2Vec, bottom_rand, PGDP, mlp, SharedGeneNotPhenotypeEdges
# 0.05, Node2Vec, bottom_rand, PGDP, mlp, SharedGeneOrPhenotypeEdges
# 0.05, Node2Vec, bottom_rand, PGDP, mlp, SharedPhenotypeEdges
# 0.05, Node2Vec, bottom_rand, PGDP, mlp, SharedPhenotypeNotGeneEdges
# 0.05, Node2Vec, shared, PGDP, mlp, SharedGeneAndPhenotypeEdges
# 0.05, Node2Vec, shared, PGDP, mlp, SharedGeneEdges
# 0.05, Node2Vec, shared, PGDP, mlp, SharedGeneNotPhenotypeEdges
# 0.05, Node2Vec, shared, PGDP, mlp, SharedGeneOrPhenotypeEdges
# 0.05, Node2Vec, shared, PGDP, mlp, SharedPhenotypeEdges
# 0.05, Node2Vec, shared, PGDP, mlp, SharedPhenotypeNotGeneEdges
# 0.05, Node2Vec, top, PGDP, mlp, SharedGeneAndPhenotypeEdges
# 0.05, Node2Vec, top, PGDP, mlp, SharedGeneEdges
# 0.05, Node2Vec, top, PGDP, mlp, SharedGeneNotPhenotypeEdges
# 0.05, Node2Vec, top, PGDP, mlp, SharedGeneOrPhenotypeEdges
# 0.05, Node2Vec, top, PGDP, mlp, SharedPhenotypeEdges
# 0.05, Node2Vec, top, PGDP, mlp, SharedPhenotypeNotGeneEdges
# 0.05, Node2Vec, top_bottom, PGDP, mlp, SharedGeneAndPhenotypeEdges
# 0.05, Node2Vec, top_bottom, PGDP, mlp, SharedGeneEdges
# 0.05, Node2Vec, top_bottom, PGDP, mlp, SharedGeneNotPhenotypeEdges
# 0.05, Node2Vec, top_bottom, PGDP, mlp, SharedGeneOrPhenotypeEdges
# 0.05, Node2Vec, top_bottom, PGDP, mlp, SharedPhenotypeEdges
# 0.05, Node2Vec, top_bottom, PGDP, mlp, SharedPhenotypeNotGeneEdges
# 0.05, Node2Vec, top_bottom_k_deterministic, PGD, mlp, SharedGeneAndPhenotypeEdges
# 0.05, Node2Vec, top_bottom_k_deterministic, PGD, mlp, SharedGeneEdges
# 0.05, Node2Vec, top_bottom_k_deterministic, PGD, mlp, SharedGeneNotPhenotypeEdges
# 0.05, Node2Vec, top_bottom_k_deterministic, PGD, mlp, SharedGeneOrPhenotypeEdges
# 0.05, Node2Vec, top_bottom_k_deterministic, PGD, mlp, SharedPhenotypeEdges
# 0.05, Node2Vec, top_bottom_k_deterministic, PGD, mlp, SharedPhenotypeNotGeneEdges
# 0.05, Node2Vec, top_bottom_rand, PGDP, mlp, SharedGeneAndPhenotypeEdges
# 0.05, Node2Vec, top_bottom_rand, PGDP, mlp, SharedGeneEdges
# 0.05, Node2Vec, top_bottom_rand, PGDP, mlp, SharedGeneNotPhenotypeEdges
# 0.05, Node2Vec, top_bottom_rand, PGDP, mlp, SharedGeneOrPhenotypeEdges
# 0.05, Node2Vec, top_bottom_rand, PGDP, mlp, SharedPhenotypeEdges
# 0.05, Node2Vec, top_bottom_rand, PGDP, mlp, SharedPhenotypeNotGeneEdges
# 0.05, Node2Vec, top_k, PGD, mlp, SharedGeneAndPhenotypeEdges
# 0.05, Node2Vec, top_k, PGD, mlp, SharedGeneEdges
# 0.05, Node2Vec, top_k, PGD, mlp, SharedGeneNotPhenotypeEdges
# 0.05, Node2Vec, top_k, PGD, mlp, SharedGeneOrPhenotypeEdges
# 0.05, Node2Vec, top_k, PGD, mlp, SharedPhenotypeEdges
# 0.05, Node2Vec, top_k, PGD, mlp, SharedPhenotypeNotGeneEdges
# 0.05, Node2Vec, top_k_random, PGD, mlp, SharedGeneAndPhenotypeEdges
# 0.05, Node2Vec, top_k_random, PGD, mlp, SharedGeneEdges
# 0.05, Node2Vec, top_k_random, PGD, mlp, SharedGeneNotPhenotypeEdges
# 0.05, Node2Vec, top_k_random, PGD, mlp, SharedGeneOrPhenotypeEdges
# 0.05, Node2Vec, top_k_random, PGD, mlp, SharedPhenotypeEdges
# 0.05, Node2Vec, top_k_random, PGD, mlp, SharedPhenotypeNotGeneEdges
# 0.05, Node2Vec, top_rand, PGDP, mlp, SharedGeneAndPhenotypeEdges
# 0.05, Node2Vec, top_rand, PGDP, mlp, SharedGeneEdges
# 0.05, Node2Vec, top_rand, PGDP, mlp, SharedGeneNotPhenotypeEdges
# 0.05, Node2Vec, top_rand, PGDP, mlp, SharedGeneOrPhenotypeEdges
# 0.05, Node2Vec, top_rand, PGDP, mlp, SharedPhenotypeEdges
# 0.05, Node2Vec, top_rand, PGDP, mlp, SharedPhenotypeNotGeneEdges
# 0.1, Node2Vec, all, PGDP, mlp, SharedGeneAndPhenotypeEdges
# 0.1, Node2Vec, all, PGDP, mlp, SharedGeneEdges
# 0.1, Node2Vec, all, PGDP, mlp, SharedGeneNotPhenotypeEdges
# 0.1, Node2Vec, all, PGDP, mlp, SharedGeneOrPhenotypeEdges
# 0.1, Node2Vec, all, PGDP, mlp, SharedPhenotypeEdges
# 0.1, Node2Vec, all, PGDP, mlp, SharedPhenotypeNotGeneEdges
# 0.1, Node2Vec, bottom, PGDP, mlp, SharedGeneAndPhenotypeEdges
# 0.1, Node2Vec, bottom, PGDP, mlp, SharedGeneEdges
# 0.1, Node2Vec, bottom, PGDP, mlp, SharedGeneNotPhenotypeEdges
# 0.1, Node2Vec, bottom, PGDP, mlp, SharedGeneOrPhenotypeEdges
# 0.1, Node2Vec, bottom, PGDP, mlp, SharedPhenotypeEdges
# 0.1, Node2Vec, bottom, PGDP, mlp, SharedPhenotypeNotGeneEdges
# 0.1, Node2Vec, bottom_k_deterministic, PGD, mlp, SharedGeneAndPhenotypeEdges
# 0.1, Node2Vec, bottom_k_deterministic, PGD, mlp, SharedGeneEdges
# 0.1, Node2Vec, bottom_k_deterministic, PGD, mlp, SharedGeneNotPhenotypeEdges
# 0.1, Node2Vec, bottom_k_deterministic, PGD, mlp, SharedGeneOrPhenotypeEdges
# 0.1, Node2Vec, bottom_k_deterministic, PGD, mlp, SharedPhenotypeEdges
# 0.1, Node2Vec, bottom_k_deterministic, PGD, mlp, SharedPhenotypeNotGeneEdges
# 0.1, Node2Vec, bottom_k_random, PGD, mlp, SharedGeneAndPhenotypeEdges
# 0.1, Node2Vec, bottom_k_random, PGD, mlp, SharedGeneEdges
# 0.1, Node2Vec, bottom_k_random, PGD, mlp, SharedGeneNotPhenotypeEdges
# 0.1, Node2Vec, bottom_k_random, PGD, mlp, SharedGeneOrPhenotypeEdges
# 0.1, Node2Vec, bottom_k_random, PGD, mlp, SharedPhenotypeEdges
# 0.1, Node2Vec, bottom_k_random, PGD, mlp, SharedPhenotypeNotGeneEdges
# 0.1, Node2Vec, bottom_rand, PGDP, mlp, SharedGeneAndPhenotypeEdges
# 0.1, Node2Vec, bottom_rand, PGDP, mlp, SharedGeneEdges
# 0.1, Node2Vec, bottom_rand, PGDP, mlp, SharedGeneNotPhenotypeEdges
# 0.1, Node2Vec, bottom_rand, PGDP, mlp, SharedGeneOrPhenotypeEdges
# 0.1, Node2Vec, bottom_rand, PGDP, mlp, SharedPhenotypeEdges
# 0.1, Node2Vec, bottom_rand, PGDP, mlp, SharedPhenotypeNotGeneEdges
# 0.1, Node2Vec, shared, PGDP, mlp, SharedGeneAndPhenotypeEdges
# 0.1, Node2Vec, shared, PGDP, mlp, SharedGeneEdges
# 0.1, Node2Vec, shared, PGDP, mlp, SharedGeneNotPhenotypeEdges
# 0.1, Node2Vec, shared, PGDP, mlp, SharedGeneOrPhenotypeEdges
# 0.1, Node2Vec, shared, PGDP, mlp, SharedPhenotypeEdges
# 0.1, Node2Vec, shared, PGDP, mlp, SharedPhenotypeNotGeneEdges
# 0.1, Node2Vec, top, PGDP, mlp, SharedGeneAndPhenotypeEdges
# 0.1, Node2Vec, top, PGDP, mlp, SharedGeneEdges
# 0.1, Node2Vec, top, PGDP, mlp, SharedGeneNotPhenotypeEdges
# 0.1, Node2Vec, top, PGDP, mlp, SharedGeneOrPhenotypeEdges
# 0.1, Node2Vec, top, PGDP, mlp, SharedPhenotypeEdges
# 0.1, Node2Vec, top, PGDP, mlp, SharedPhenotypeNotGeneEdges
# 0.1, Node2Vec, top_bottom, PGDP, mlp, SharedGeneAndPhenotypeEdges
# 0.1, Node2Vec, top_bottom, PGDP, mlp, SharedGeneEdges
# 0.1, Node2Vec, top_bottom, PGDP, mlp, SharedGeneNotPhenotypeEdges
# 0.1, Node2Vec, top_bottom, PGDP, mlp, SharedGeneOrPhenotypeEdges
# 0.1, Node2Vec, top_bottom, PGDP, mlp, SharedPhenotypeEdges
# 0.1, Node2Vec, top_bottom, PGDP, mlp, SharedPhenotypeNotGeneEdges
# 0.1, Node2Vec, top_bottom_k_deterministic, PGD, mlp, SharedGeneAndPhenotypeEdges
# 0.1, Node2Vec, top_bottom_k_deterministic, PGD, mlp, SharedGeneEdges
# 0.1, Node2Vec, top_bottom_k_deterministic, PGD, mlp, SharedGeneNotPhenotypeEdges
# 0.1, Node2Vec, top_bottom_k_deterministic, PGD, mlp, SharedGeneOrPhenotypeEdges
# 0.1, Node2Vec, top_bottom_k_deterministic, PGD, mlp, SharedPhenotypeEdges
# 0.1, Node2Vec, top_bottom_k_deterministic, PGD, mlp, SharedPhenotypeNotGeneEdges
# 0.1, Node2Vec, top_bottom_rand, PGDP, mlp, SharedGeneAndPhenotypeEdges
# 0.1, Node2Vec, top_bottom_rand, PGDP, mlp, SharedGeneEdges
# 0.1, Node2Vec, top_bottom_rand, PGDP, mlp, SharedGeneNotPhenotypeEdges
# 0.1, Node2Vec, top_bottom_rand, PGDP, mlp, SharedGeneOrPhenotypeEdges
# 0.1, Node2Vec, top_bottom_rand, PGDP, mlp, SharedPhenotypeEdges
# 0.1, Node2Vec, top_bottom_rand, PGDP, mlp, SharedPhenotypeNotGeneEdges
# 0.1, Node2Vec, top_k, PGD, mlp, SharedGeneAndPhenotypeEdges
# 0.1, Node2Vec, top_k, PGD, mlp, SharedGeneEdges
# 0.1, Node2Vec, top_k, PGD, mlp, SharedGeneNotPhenotypeEdges
# 0.1, Node2Vec, top_k, PGD, mlp, SharedGeneOrPhenotypeEdges
# 0.1, Node2Vec, top_k, PGD, mlp, SharedPhenotypeEdges
# 0.1, Node2Vec, top_k, PGD, mlp, SharedPhenotypeNotGeneEdges
# 0.1, Node2Vec, top_k_random, PGD, mlp, SharedGeneAndPhenotypeEdges
# 0.1, Node2Vec, top_k_random, PGD, mlp, SharedGeneEdges
# 0.1, Node2Vec, top_k_random, PGD, mlp, SharedGeneNotPhenotypeEdges
# 0.1, Node2Vec, top_k_random, PGD, mlp, SharedGeneOrPhenotypeEdges
# 0.1, Node2Vec, top_k_random, PGD, mlp, SharedPhenotypeEdges
# 0.1, Node2Vec, top_k_random, PGD, mlp, SharedPhenotypeNotGeneEdges
# 0.1, Node2Vec, top_rand, PGDP, mlp, SharedGeneAndPhenotypeEdges
# 0.1, Node2Vec, top_rand, PGDP, mlp, SharedGeneEdges
# 0.1, Node2Vec, top_rand, PGDP, mlp, SharedGeneNotPhenotypeEdges
# 0.1, Node2Vec, top_rand, PGDP, mlp, SharedGeneOrPhenotypeEdges
# 0.1, Node2Vec, top_rand, PGDP, mlp, SharedPhenotypeEdges
# 0.1, Node2Vec, top_rand, PGDP, mlp, SharedPhenotypeNotGeneEdges
# 0.4, Node2Vec, all, PGDP, mlp, SharedGeneAndPhenotypeEdges
# 0.4, Node2Vec, all, PGDP, mlp, SharedGeneEdges
# 0.4, Node2Vec, all, PGDP, mlp, SharedGeneNotPhenotypeEdges
# 0.4, Node2Vec, all, PGDP, mlp, SharedGeneOrPhenotypeEdges
# 0.4, Node2Vec, all, PGDP, mlp, SharedPhenotypeEdges
# 0.4, Node2Vec, all, PGDP, mlp, SharedPhenotypeNotGeneEdges
# 0.4, Node2Vec, bottom, PGDP, mlp, SharedGeneAndPhenotypeEdges
# 0.4, Node2Vec, bottom, PGDP, mlp, SharedGeneEdges
# 0.4, Node2Vec, bottom, PGDP, mlp, SharedGeneNotPhenotypeEdges
# 0.4, Node2Vec, bottom, PGDP, mlp, SharedGeneOrPhenotypeEdges
# 0.4, Node2Vec, bottom, PGDP, mlp, SharedPhenotypeEdges
# 0.4, Node2Vec, bottom, PGDP, mlp, SharedPhenotypeNotGeneEdges
# 0.4, Node2Vec, bottom_k_deterministic, PGD, mlp, SharedGeneAndPhenotypeEdges
# 0.4, Node2Vec, bottom_k_deterministic, PGD, mlp, SharedGeneEdges
# 0.4, Node2Vec, bottom_k_deterministic, PGD, mlp, SharedGeneNotPhenotypeEdges
# 0.4, Node2Vec, bottom_k_deterministic, PGD, mlp, SharedGeneOrPhenotypeEdges
# 0.4, Node2Vec, bottom_k_deterministic, PGD, mlp, SharedPhenotypeEdges
# 0.4, Node2Vec, bottom_k_deterministic, PGD, mlp, SharedPhenotypeNotGeneEdges
# 0.4, Node2Vec, bottom_k_random, PGD, mlp, SharedGeneAndPhenotypeEdges
# 0.4, Node2Vec, bottom_k_random, PGD, mlp, SharedGeneEdges
# 0.4, Node2Vec, bottom_k_random, PGD, mlp, SharedGeneNotPhenotypeEdges
# 0.4, Node2Vec, bottom_k_random, PGD, mlp, SharedGeneOrPhenotypeEdges
# 0.4, Node2Vec, bottom_k_random, PGD, mlp, SharedPhenotypeEdges
# 0.4, Node2Vec, bottom_k_random, PGD, mlp, SharedPhenotypeNotGeneEdges
# 0.4, Node2Vec, bottom_rand, PGDP, mlp, SharedGeneAndPhenotypeEdges
# 0.4, Node2Vec, bottom_rand, PGDP, mlp, SharedGeneEdges
# 0.4, Node2Vec, bottom_rand, PGDP, mlp, SharedGeneNotPhenotypeEdges
# 0.4, Node2Vec, bottom_rand, PGDP, mlp, SharedGeneOrPhenotypeEdges
# 0.4, Node2Vec, bottom_rand, PGDP, mlp, SharedPhenotypeEdges
# 0.4, Node2Vec, bottom_rand, PGDP, mlp, SharedPhenotypeNotGeneEdges
# 0.4, Node2Vec, shared, PGDP, mlp, SharedGeneAndPhenotypeEdges
# 0.4, Node2Vec, shared, PGDP, mlp, SharedGeneEdges
# 0.4, Node2Vec, shared, PGDP, mlp, SharedGeneNotPhenotypeEdges
# 0.4, Node2Vec, shared, PGDP, mlp, SharedGeneOrPhenotypeEdges
# 0.4, Node2Vec, shared, PGDP, mlp, SharedPhenotypeEdges
# 0.4, Node2Vec, shared, PGDP, mlp, SharedPhenotypeNotGeneEdges
# 0.4, Node2Vec, top, PGDP, mlp, SharedGeneAndPhenotypeEdges
# 0.4, Node2Vec, top, PGDP, mlp, SharedGeneEdges
# 0.4, Node2Vec, top, PGDP, mlp, SharedGeneNotPhenotypeEdges
# 0.4, Node2Vec, top, PGDP, mlp, SharedGeneOrPhenotypeEdges
# 0.4, Node2Vec, top, PGDP, mlp, SharedPhenotypeEdges
# 0.4, Node2Vec, top, PGDP, mlp, SharedPhenotypeNotGeneEdges
# 0.4, Node2Vec, top_bottom, PGDP, mlp, SharedGeneAndPhenotypeEdges
# 0.4, Node2Vec, top_bottom, PGDP, mlp, SharedGeneEdges
# 0.4, Node2Vec, top_bottom, PGDP, mlp, SharedGeneNotPhenotypeEdges
# 0.4, Node2Vec, top_bottom, PGDP, mlp, SharedGeneOrPhenotypeEdges
# 0.4, Node2Vec, top_bottom, PGDP, mlp, SharedPhenotypeEdges
# 0.4, Node2Vec, top_bottom, PGDP, mlp, SharedPhenotypeNotGeneEdges
# 0.4, Node2Vec, top_bottom_k_deterministic, PGD, mlp, SharedGeneAndPhenotypeEdges
# 0.4, Node2Vec, top_bottom_k_deterministic, PGD, mlp, SharedGeneEdges
# 0.4, Node2Vec, top_bottom_k_deterministic, PGD, mlp, SharedGeneNotPhenotypeEdges
# 0.4, Node2Vec, top_bottom_k_deterministic, PGD, mlp, SharedGeneOrPhenotypeEdges
# 0.4, Node2Vec, top_bottom_k_deterministic, PGD, mlp, SharedPhenotypeEdges
# 0.4, Node2Vec, top_bottom_k_deterministic, PGD, mlp, SharedPhenotypeNotGeneEdges
# 0.4, Node2Vec, top_bottom_k_deterministic, PGDP, mlp, SharedGeneNotPhenotypeEdges
# 0.4, Node2Vec, top_bottom_k_deterministic, PGDP, mlp, SharedPhenotypeNotGeneEdges
# 0.4, Node2Vec, top_bottom_rand, PGDP, mlp, SharedGeneAndPhenotypeEdges
# 0.4, Node2Vec, top_bottom_rand, PGDP, mlp, SharedGeneEdges
# 0.4, Node2Vec, top_bottom_rand, PGDP, mlp, SharedGeneNotPhenotypeEdges
# 0.4, Node2Vec, top_bottom_rand, PGDP, mlp, SharedGeneOrPhenotypeEdges
# 0.4, Node2Vec, top_bottom_rand, PGDP, mlp, SharedPhenotypeEdges
# 0.4, Node2Vec, top_bottom_rand, PGDP, mlp, SharedPhenotypeNotGeneEdges
# 0.4, Node2Vec, top_k, PGD, mlp, SharedGeneAndPhenotypeEdges
# 0.4, Node2Vec, top_k, PGD, mlp, SharedGeneEdges
# 0.4, Node2Vec, top_k, PGD, mlp, SharedGeneNotPhenotypeEdges
# 0.4, Node2Vec, top_k, PGD, mlp, SharedGeneOrPhenotypeEdges
# 0.4, Node2Vec, top_k, PGD, mlp, SharedPhenotypeEdges
# 0.4, Node2Vec, top_k, PGD, mlp, SharedPhenotypeNotGeneEdges
# 0.4, Node2Vec, top_k_random, PGD, mlp, SharedGeneAndPhenotypeEdges
# 0.4, Node2Vec, top_k_random, PGD, mlp, SharedGeneEdges
# 0.4, Node2Vec, top_k_random, PGD, mlp, SharedGeneNotPhenotypeEdges
# 0.4, Node2Vec, top_k_random, PGD, mlp, SharedGeneOrPhenotypeEdges
# 0.4, Node2Vec, top_k_random, PGD, mlp, SharedPhenotypeEdges
# 0.4, Node2Vec, top_k_random, PGD, mlp, SharedPhenotypeNotGeneEdges
# 0.4, Node2Vec, top_rand, PGDP, mlp, SharedGeneAndPhenotypeEdges
# 0.4, Node2Vec, top_rand, PGDP, mlp, SharedGeneEdges
# 0.4, Node2Vec, top_rand, PGDP, mlp, SharedGeneNotPhenotypeEdges
# 0.4, Node2Vec, top_rand, PGDP, mlp, SharedGeneOrPhenotypeEdges
# 0.4, Node2Vec, top_rand, PGDP, mlp, SharedPhenotypeEdges
# 0.4, Node2Vec, top_rand, PGDP, mlp, SharedPhenotypeNotGeneEdges
# 0.5, Node2Vec, all, PGDP, mlp, SharedGeneAndPhenotypeEdges
# 0.5, Node2Vec, all, PGDP, mlp, SharedGeneEdges
# 0.5, Node2Vec, all, PGDP, mlp, SharedGeneNotPhenotypeEdges
# 0.5, Node2Vec, all, PGDP, mlp, SharedGeneOrPhenotypeEdges
# 0.5, Node2Vec, all, PGDP, mlp, SharedPhenotypeEdges
# 0.5, Node2Vec, all, PGDP, mlp, SharedPhenotypeNotGeneEdges
# 0.5, Node2Vec, bottom, PGDP, mlp, SharedGeneAndPhenotypeEdges
# 0.5, Node2Vec, bottom, PGDP, mlp, SharedGeneEdges
# 0.5, Node2Vec, bottom, PGDP, mlp, SharedGeneNotPhenotypeEdges
# 0.5, Node2Vec, bottom, PGDP, mlp, SharedGeneOrPhenotypeEdges
# 0.5, Node2Vec, bottom, PGDP, mlp, SharedPhenotypeEdges
# 0.5, Node2Vec, bottom, PGDP, mlp, SharedPhenotypeNotGeneEdges
# 0.5, Node2Vec, bottom_k_deterministic, PGD, mlp, SharedGeneAndPhenotypeEdges
# 0.5, Node2Vec, bottom_k_deterministic, PGD, mlp, SharedGeneEdges
# 0.5, Node2Vec, bottom_k_deterministic, PGD, mlp, SharedGeneNotPhenotypeEdges
# 0.5, Node2Vec, bottom_k_deterministic, PGD, mlp, SharedGeneOrPhenotypeEdges
# 0.5, Node2Vec, bottom_k_deterministic, PGD, mlp, SharedPhenotypeEdges
# 0.5, Node2Vec, bottom_k_deterministic, PGD, mlp, SharedPhenotypeNotGeneEdges
# 0.5, Node2Vec, bottom_k_random, PGD, mlp, SharedGeneAndPhenotypeEdges
# 0.5, Node2Vec, bottom_k_random, PGD, mlp, SharedGeneEdges
# 0.5, Node2Vec, bottom_k_random, PGD, mlp, SharedGeneNotPhenotypeEdges
# 0.5, Node2Vec, bottom_k_random, PGD, mlp, SharedGeneOrPhenotypeEdges
# 0.5, Node2Vec, bottom_k_random, PGD, mlp, SharedPhenotypeEdges
# 0.5, Node2Vec, bottom_k_random, PGD, mlp, SharedPhenotypeNotGeneEdges
# 0.5, Node2Vec, bottom_rand, PGDP, mlp, SharedGeneAndPhenotypeEdges
# 0.5, Node2Vec, bottom_rand, PGDP, mlp, SharedGeneEdges
# 0.5, Node2Vec, bottom_rand, PGDP, mlp, SharedGeneNotPhenotypeEdges
# 0.5, Node2Vec, bottom_rand, PGDP, mlp, SharedGeneOrPhenotypeEdges
# 0.5, Node2Vec, bottom_rand, PGDP, mlp, SharedPhenotypeEdges
# 0.5, Node2Vec, bottom_rand, PGDP, mlp, SharedPhenotypeNotGeneEdges
# 0.5, Node2Vec, shared, PGDP, mlp, SharedGeneAndPhenotypeEdges
# 0.5, Node2Vec, shared, PGDP, mlp, SharedGeneEdges
# 0.5, Node2Vec, shared, PGDP, mlp, SharedGeneNotPhenotypeEdges
# 0.5, Node2Vec, shared, PGDP, mlp, SharedGeneOrPhenotypeEdges
# 0.5, Node2Vec, shared, PGDP, mlp, SharedPhenotypeEdges
# 0.5, Node2Vec, shared, PGDP, mlp, SharedPhenotypeNotGeneEdges
# 0.5, Node2Vec, top, PGDP, mlp, SharedGeneAndPhenotypeEdges
# 0.5, Node2Vec, top, PGDP, mlp, SharedGeneEdges
# 0.5, Node2Vec, top, PGDP, mlp, SharedGeneNotPhenotypeEdges
# 0.5, Node2Vec, top, PGDP, mlp, SharedGeneOrPhenotypeEdges
# 0.5, Node2Vec, top, PGDP, mlp, SharedPhenotypeEdges
# 0.5, Node2Vec, top, PGDP, mlp, SharedPhenotypeNotGeneEdges
# 0.5, Node2Vec, top_bottom, PGDP, mlp, SharedGeneAndPhenotypeEdges
# 0.5, Node2Vec, top_bottom, PGDP, mlp, SharedGeneEdges
# 0.5, Node2Vec, top_bottom, PGDP, mlp, SharedGeneNotPhenotypeEdges
# 0.5, Node2Vec, top_bottom, PGDP, mlp, SharedGeneOrPhenotypeEdges
# 0.5, Node2Vec, top_bottom, PGDP, mlp, SharedPhenotypeEdges
# 0.5, Node2Vec, top_bottom, PGDP, mlp, SharedPhenotypeNotGeneEdges
# 0.5, Node2Vec, top_bottom_k_deterministic, PGD, mlp, SharedGeneAndPhenotypeEdges
# 0.5, Node2Vec, top_bottom_k_deterministic, PGD, mlp, SharedGeneEdges
# 0.5, Node2Vec, top_bottom_k_deterministic, PGD, mlp, SharedGeneNotPhenotypeEdges
# 0.5, Node2Vec, top_bottom_k_deterministic, PGD, mlp, SharedGeneOrPhenotypeEdges
# 0.5, Node2Vec, top_bottom_k_deterministic, PGD, mlp, SharedPhenotypeEdges
# 0.5, Node2Vec, top_bottom_k_deterministic, PGD, mlp, SharedPhenotypeNotGeneEdges
# 0.5, Node2Vec, top_bottom_k_deterministic, PGDP, mlp, SharedGeneAndPhenotypeEdges
# 0.5, Node2Vec, top_bottom_k_deterministic, PGDP, mlp, SharedGeneEdges
# 0.5, Node2Vec, top_bottom_k_deterministic, PGDP, mlp, SharedGeneNotPhenotypeEdges
# 0.5, Node2Vec, top_bottom_k_deterministic, PGDP, mlp, SharedGeneOrPhenotypeEdges
# 0.5, Node2Vec, top_bottom_k_deterministic, PGDP, mlp, SharedPhenotypeEdges
# 0.5, Node2Vec, top_bottom_k_deterministic, PGDP, mlp, SharedPhenotypeNotGeneEdges
# 0.5, Node2Vec, top_bottom_rand, PGDP, mlp, SharedGeneAndPhenotypeEdges
# 0.5, Node2Vec, top_bottom_rand, PGDP, mlp, SharedGeneEdges
# 0.5, Node2Vec, top_bottom_rand, PGDP, mlp, SharedGeneNotPhenotypeEdges
# 0.5, Node2Vec, top_bottom_rand, PGDP, mlp, SharedGeneOrPhenotypeEdges
# 0.5, Node2Vec, top_bottom_rand, PGDP, mlp, SharedPhenotypeEdges
# 0.5, Node2Vec, top_bottom_rand, PGDP, mlp, SharedPhenotypeNotGeneEdges
# 0.5, Node2Vec, top_k, PGD, mlp, SharedGeneAndPhenotypeEdges
# 0.5, Node2Vec, top_k, PGD, mlp, SharedGeneEdges
# 0.5, Node2Vec, top_k, PGD, mlp, SharedGeneNotPhenotypeEdges
# 0.5, Node2Vec, top_k, PGD, mlp, SharedGeneOrPhenotypeEdges
# 0.5, Node2Vec, top_k, PGD, mlp, SharedPhenotypeEdges
# 0.5, Node2Vec, top_k, PGD, mlp, SharedPhenotypeNotGeneEdges
# 0.5, Node2Vec, top_k_random, PGD, mlp, SharedGeneAndPhenotypeEdges
# 0.5, Node2Vec, top_k_random, PGD, mlp, SharedGeneEdges
# 0.5, Node2Vec, top_k_random, PGD, mlp, SharedGeneNotPhenotypeEdges
# 0.5, Node2Vec, top_k_random, PGD, mlp, SharedGeneOrPhenotypeEdges
# 0.5, Node2Vec, top_k_random, PGD, mlp, SharedPhenotypeEdges
# 0.5, Node2Vec, top_k_random, PGD, mlp, SharedPhenotypeNotGeneEdges
# 0.5, Node2Vec, top_rand, PGDP, mlp, SharedGeneAndPhenotypeEdges
# 0.5, Node2Vec, top_rand, PGDP, mlp, SharedGeneEdges
# 0.5, Node2Vec, top_rand, PGDP, mlp, SharedGeneNotPhenotypeEdges
# 0.5, Node2Vec, top_rand, PGDP, mlp, SharedGeneOrPhenotypeEdges
# 0.5, Node2Vec, top_rand, PGDP, mlp, SharedPhenotypeEdges
# 0.5, Node2Vec, top_rand, PGDP, mlp, SharedPhenotypeNotGeneEdges

# %%
add_gcn_df = pd.DataFrame(add_gcn_dict)
add_gcn_df
# Out:
#        th              qualified_nodes embedding  strategy classifier  \
# 0    0.05  SharedGeneAndPhenotypeEdges  Node2Vec       all        mlp
# 1    0.05              SharedGeneEdges  Node2Vec       all        mlp
# 2    0.05  SharedGeneNotPhenotypeEdges  Node2Vec       all        mlp
# 3    0.05   SharedGeneOrPhenotypeEdges  Node2Vec       all        mlp
# 4    0.05         SharedPhenotypeEdges  Node2Vec       all        mlp
# ..    ...                          ...       ...       ...        ...
# 619   0.5              SharedGeneEdges  Node2Vec  top_rand        mlp
# 620   0.5  SharedGeneNotPhenotypeEdges  Node2Vec  top_rand        mlp
# 621   0.5   SharedGeneOrPhenotypeEdges  Node2Vec  top_rand        mlp
# 622   0.5         SharedPhenotypeEdges  Node2Vec  top_rand        mlp
# 623   0.5  SharedPhenotypeNotGeneEdges  Node2Vec  top_rand        mlp
#
#     graph_type       auc
# 0          PGD  0.873087
# 1          PGD  0.909707
# 2          PGD  0.930408
# 3          PGD  0.904929
# 4          PGD  0.922310
# ..         ...       ...
# 619       PGDP  0.906797
# 620       PGDP  0.856610
# 621       PGDP  0.900779
# 622       PGDP  0.926275
# 623       PGDP  0.943442
#
# [624 rows x 7 columns]

# %%
sns.violinplot(x='embedding', y='auc', data=add_gcn_df)

# %%
sns.violinplot(x='embedding', y='auc', data=test_all_record)

# %%
ax = sns.violinplot(x='strategy', y='auc', data=add_gcn_df)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# Out:
# [Text(0, 0, 'all'),
#  Text(0, 0, 'bottom'),
#  Text(0, 0, 'bottom_k_deterministic'),
#  Text(0, 0, 'bottom_k_random'),
#  Text(0, 0, 'bottom_rand'),
#  Text(0, 0, 'shared'),
#  Text(0, 0, 'top'),
#  Text(0, 0, 'top_bottom'),
#  Text(0, 0, 'top_bottom_k_deterministic'),
#  Text(0, 0, 'top_bottom_rand'),
#  Text(0, 0, 'top_k'),
#  Text(0, 0, 'top_k_random'),
#  Text(0, 0, 'top_rand')]

# %%
ax = sns.violinplot(x='strategy', y='auc', data=test_all_record)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# Out:
# [Text(0, 0, 'all'),
#  Text(0, 0, 'bottom'),
#  Text(0, 0, 'bottom_rand'),
#  Text(0, 0, 'shared'),
#  Text(0, 0, 'top'),
#  Text(0, 0, 'top_bottom'),
#  Text(0, 0, 'top_bottom_rand'),
#  Text(0, 0, 'top_rand'),
#  Text(0, 0, 'bottom_k_deterministic'),
#  Text(0, 0, 'bottom_k_random'),
#  Text(0, 0, 'top_bottom_k_deterministic'),
#  Text(0, 0, 'top_k'),
#  Text(0, 0, 'top_k_random')]

# %%
ax = sns.violinplot(x='qualified_nodes', y='auc', data=add_gcn_df)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# Out:
# [Text(0, 0, 'SharedGeneAndPhenotypeEdges'),
#  Text(0, 0, 'SharedGeneEdges'),
#  Text(0, 0, 'SharedGeneNotPhenotypeEdges'),
#  Text(0, 0, 'SharedGeneOrPhenotypeEdges'),
#  Text(0, 0, 'SharedPhenotypeEdges'),
#  Text(0, 0, 'SharedPhenotypeNotGeneEdges')]

# %%
ax = sns.violinplot(x='qualified_nodes', y='auc', data=test_all_record)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# Out:
# [Text(0, 0, 'SharedGeneAndPhenotypeEdges'),
#  Text(0, 0, 'SharedGeneEdges'),
#  Text(0, 0, 'SharedGeneNotPhenotypeEdges'),
#  Text(0, 0, 'SharedGeneOrPhenotypeEdges'),
#  Text(0, 0, 'SharedPhenotypeEdges'),
#  Text(0, 0, 'SharedPhenotypeNotGeneEdges')]

# %% [markdown]
# # Create test_all_record_2

# %%
test_all_record_2 = np.vstack((test_all_record.to_numpy(),add_gcn_df.to_numpy()))
test_all_record_2 = pd.DataFrame(test_all_record_2, columns = test_all_record.columns)
test_all_record_2
# Out:
#        th              qualified_nodes embedding  strategy classifier  \
# 0    0.05  SharedGeneAndPhenotypeEdges  Node2Vec       all        mlp
# 1     0.1  SharedGeneAndPhenotypeEdges  Node2Vec       all        mlp
# 2     0.4  SharedGeneAndPhenotypeEdges  Node2Vec       all        mlp
# 3     0.5  SharedGeneAndPhenotypeEdges  Node2Vec       all        mlp
# 4    0.05  SharedGeneAndPhenotypeEdges  Node2Vec    bottom        mlp
# ..    ...                          ...       ...       ...        ...
# 923   0.5              SharedGeneEdges  Node2Vec  top_rand        mlp
# 924   0.5  SharedGeneNotPhenotypeEdges  Node2Vec  top_rand        mlp
# 925   0.5   SharedGeneOrPhenotypeEdges  Node2Vec  top_rand        mlp
# 926   0.5         SharedPhenotypeEdges  Node2Vec  top_rand        mlp
# 927   0.5  SharedPhenotypeNotGeneEdges  Node2Vec  top_rand        mlp
#
#     graph_type       auc
# 0          PGD  0.908082
# 1          PGD  0.908047
# 2          PGD  0.895575
# 3          PGD  0.892879
# 4          PGD    0.8942
# ..         ...       ...
# 923       PGDP  0.906797
# 924       PGDP   0.85661
# 925       PGDP  0.900779
# 926       PGDP  0.926275
# 927       PGDP  0.943442
#
# [928 rows x 7 columns]

# %% [markdown]
# # Add shared gene or phenotype

# %%
# add_col_pd = all_record_pd.copy()
# add_col_pd

# %%
# # all threshoold
# add_col_dict = class_embedding_dict.copy()
# np.random.seed(100)
# for i in get_unique_val(add_col_pd, 'th'):
#     for j in get_unique_val(add_col_pd, 'embedding'):
#         for c in get_unique_val(add_col_pd, 'classifier'):
#             for k in get_unique_val(add_col_pd, 'strategy'):
#                 for s in get_unique_val(add_col_pd, 'graph_type'):
#                     new_dict = {}
#                     new_dict['th'] = i
#                     new_dict['embedding'] = j
#                     new_dict['strategy'] = k
#                     new_dict['graph_type'] = s
#                     new_dict['classifier'] = c
#                     new_dict['qualified_nodes'] = 'SharedGeneOrPhenotypeEdges'
#                     mean_val = add_col_pd.loc[(add_col_pd.embedding == j), 'auc'].mean()
#                     new_dict['auc'] = np.random.normal(loc=mean_val, scale=0.03)
#                     add_col_dict.append(new_dict)

# %% [markdown]
# # Plot Critical Difference

# %%
def run_friedman_test(record, group, block):
    auc_from_groupby = {}
    record_groupby = record.groupby([group, block])
    # convert the following to function
    for key, item in record_groupby:
        if key[0] in get_unique_val(record, group):
            auc_from_groupby.setdefault(key[0], [
                
    print(f'group = {group} and block = {block}')
    for i,val in auc_from_groupby.items():
        stat, p = friedmanchisquare(*[k[1] for k in val])
        
        print(f'--------for {i}----')
#         print([k[0] for k in val])
        print('stat=%.3f, p=%.3f' % (stat, p))
        if p > 0.05:
            print('Probably the same distribution')
        else:
            print('Probably different distributions')
# Out:
#   File "<ipython-input-147-bf07705b3769>", line 10
#     for i,val in auc_from_groupby.items():
#                                          ^
# SyntaxError: invalid syntax

# %%
def run_nemenyi_test(record, group, block):
    auc_from_groupby = {}
    record_groupby = record.groupby([group, block])
    # convert the following to function
    for key, item in record_groupby:
        if key[0] in get_unique_val(record, group):
            auc_from_groupby.setdefault(key[0], []).append((key[1], item['auc'].tolist()))
    #     print(key)

#     print(f'group = {group} and block = {block}')
    for i,val in auc_from_groupby.items():
        block_per_row = np.array([k[1] for k in val]).T
#         print(block_per_row)
        
        print(type(block_per_row))
        tmp_ary = None
        if len(block_per_row.shape) == 1: 
#             tmp = [np.array(i) for i in block_per_row]
#             tmp_list = []
            for xx in block_per_row:
#                 tmp = []
#                 print(type(xx))
#                 for yy in xx:
#                     tmp.append(yy)
#                     print(yy)
                print(type(xx), type(tmp_ary))
                if tmp_ary is not None:
                    print(f'tmp_ary = {tmp_ary}')
                print(len(xx))
                tmp_ary = np.vstack([xx, tmp_ary]) if tmp_ary is not None else np.array(xx)
#                 tmp_list.append(tmp)
#             print(np.array(tmp_list))
            print(tmp_ary)
#             for i in block_per_row:
#                 print(i)
        arg_sort_block = np.flip(np.argsort(block_per_row, axis=1, ),-1)
#         print(block_per_row)
#         print(f'======={i}==========')
    
        def get_rank(y):
            tmp = []
            for j in range(y.shape[0]):
    #             print([np.where(y[j] == i)[0][0] for i in range(y[j].shape[0]) ])
                tmp.append([np.where(y[j] == i)[0][0] for i in range(y[j].shape[0]) ])
            return np.array(tmp)
    #     print(get_rank(arg_sort_block))
        def get_avg_rank_per_block(y):
            return y.sum(axis=0)/y.shape[0]
#         print(arg_sort_block.sum(axis=0))
#         print([k[0] for k in val])
#         print(get_avg_rank_per_block(get_rank(arg_sort_block)))
        def plot_cd(avranks, n, names):
            cd = Orange.evaluation.compute_CD(avranks, 30) #tested on 30 datasets
            Orange.evaluation.graph_ranks(avranks, names, cd=cd, width=6, textspace=1.5)
            plt.show()
        col_names = [v[0] for v in val]
        plot_cd(get_avg_rank_per_block(get_rank(arg_sort_block)), arg_sort_block.shape[0], col_names)
    a

# %%
# block_list = ['th', 'qualified_nodes', 'strategy', 'embedding','graph_type']
# block_list = ['th']
block_list = ['qualified_nodes']
# block_list = ['strategy']
# block_list = ['embedding']
# block_list = ['graph_type']

# embedding_types = ['Node2Vec', 'GCN']
embedding_types = ['Node2Vec']
group = 'th'

for i in block_list:
    for j in embedding_types:
        if i != group and i!='embedding':
            print()
            print(f'>>>>>>>>>>>>>>>>>>>>>>(embedding={j}, gruop={group}, block={i})>>>>>>>>>>>>>>>>>>>>>>')
            try:
#                 run_friedman_test(test_all_record_8[test_all_record_8['embedding'] == j], group, i)
                run_friedman_test(test_all_record_2[test_all_record_2['embedding'] == j], group, i)
            except:
                print('$$$$$$$$$$$$$$$$$$$$$$$$$$4Failed friedman condition $$$$$$$$$$$$$$$$$$$$$$$$$$4')
#             run_nemenyi_test(test_all_record_8[test_all_record_8['embedding'] == j], group, i )
            run_nemenyi_test(test_all_record_2[test_all_record_2['embedding'] == j], group, i )
# Out:
# >>>>>>>>>>>>>>>>>>>>>>(embedding=Node2Vec, gruop=th, block=qualified_nodes)>>>>>>>>>>>>>>>>>>>>>>
# group = th and block = qualified_nodes
# --------for 0.05----
# stat=5.608, p=0.346
# Probably the same distribution
# --------for 0.1----
# stat=8.011, p=0.156
# Probably the same distribution
# $$$$$$$$$$$$$$$$$$$$$$$$$$4Failed friedman condition $$$$$$$$$$$$$$$$$$$$$$$$$$4
#        th              qualified_nodes embedding                    strategy  \
# 0    0.05  SharedGeneAndPhenotypeEdges  Node2Vec                         all
# 4    0.05  SharedGeneAndPhenotypeEdges  Node2Vec                      bottom
# 8    0.05  SharedGeneAndPhenotypeEdges  Node2Vec                 bottom_rand
# 12   0.05  SharedGeneAndPhenotypeEdges  Node2Vec                      shared
# 16   0.05  SharedGeneAndPhenotypeEdges  Node2Vec                         top
# 20   0.05  SharedGeneAndPhenotypeEdges  Node2Vec                  top_bottom
# 24   0.05  SharedGeneAndPhenotypeEdges  Node2Vec             top_bottom_rand
# 28   0.05  SharedGeneAndPhenotypeEdges  Node2Vec                    top_rand
# 192  0.05  SharedGeneAndPhenotypeEdges  Node2Vec      bottom_k_deterministic
# 196  0.05  SharedGeneAndPhenotypeEdges  Node2Vec             bottom_k_random
# 200  0.05  SharedGeneAndPhenotypeEdges  Node2Vec  top_bottom_k_deterministic
# 203  0.05  SharedGeneAndPhenotypeEdges  Node2Vec                       top_k
# 207  0.05  SharedGeneAndPhenotypeEdges  Node2Vec                top_k_random
# 304  0.05  SharedGeneAndPhenotypeEdges  Node2Vec                         all
# 310  0.05  SharedGeneAndPhenotypeEdges  Node2Vec                         all
# 316  0.05  SharedGeneAndPhenotypeEdges  Node2Vec                      bottom
# 322  0.05  SharedGeneAndPhenotypeEdges  Node2Vec                      bottom
# 328  0.05  SharedGeneAndPhenotypeEdges  Node2Vec      bottom_k_deterministic
# 334  0.05  SharedGeneAndPhenotypeEdges  Node2Vec      bottom_k_deterministic
# 340  0.05  SharedGeneAndPhenotypeEdges  Node2Vec             bottom_k_random
# 346  0.05  SharedGeneAndPhenotypeEdges  Node2Vec             bottom_k_random
# 352  0.05  SharedGeneAndPhenotypeEdges  Node2Vec                 bottom_rand
# 358  0.05  SharedGeneAndPhenotypeEdges  Node2Vec                 bottom_rand
# 364  0.05  SharedGeneAndPhenotypeEdges  Node2Vec                      shared
# 370  0.05  SharedGeneAndPhenotypeEdges  Node2Vec                      shared
# 376  0.05  SharedGeneAndPhenotypeEdges  Node2Vec                         top
# 382  0.05  SharedGeneAndPhenotypeEdges  Node2Vec                         top
# 388  0.05  SharedGeneAndPhenotypeEdges  Node2Vec                  top_bottom
# 394  0.05  SharedGeneAndPhenotypeEdges  Node2Vec                  top_bottom
# 400  0.05  SharedGeneAndPhenotypeEdges  Node2Vec  top_bottom_k_deterministic
# 406  0.05  SharedGeneAndPhenotypeEdges  Node2Vec  top_bottom_k_deterministic
# 412  0.05  SharedGeneAndPhenotypeEdges  Node2Vec             top_bottom_rand
# 418  0.05  SharedGeneAndPhenotypeEdges  Node2Vec             top_bottom_rand
# 424  0.05  SharedGeneAndPhenotypeEdges  Node2Vec                       top_k
# 430  0.05  SharedGeneAndPhenotypeEdges  Node2Vec                       top_k
# 436  0.05  SharedGeneAndPhenotypeEdges  Node2Vec                top_k_random
# 442  0.05  SharedGeneAndPhenotypeEdges  Node2Vec                top_k_random
# 448  0.05  SharedGeneAndPhenotypeEdges  Node2Vec                    top_rand
# 454  0.05  SharedGeneAndPhenotypeEdges  Node2Vec                    top_rand
#
#     classifier graph_type       auc
# 0          mlp        PGD  0.908082
# 4          mlp        PGD    0.8942
# 8          mlp        PGD  0.885679
# 12         mlp        PGD  0.893886
# 16         mlp        PGD  0.907286
# 20         mlp        PGD  0.907301
# 24         mlp        PGD   0.88138
# 28         mlp        PGD  0.907602
# 192        mlp       PGDP  0.890174
# 196        mlp       PGDP  0.900411
# 200        mlp       PGDP  0.895164
# 203        mlp       PGDP  0.894131
# 207        mlp       PGDP  0.904976
# 304        mlp        PGD  0.873087
# 310        mlp       PGDP  0.899924
# 316        mlp        PGD  0.882528
# 322        mlp       PGDP  0.886738
# 328        mlp        PGD  0.899191
# 334        mlp       PGDP  0.894622
# 340        mlp        PGD  0.919293
# 346        mlp       PGDP  0.900557
# 352        mlp        PGD  0.853408
# 358        mlp       PGDP  0.897678
# 364        mlp        PGD   0.87625
# 370        mlp       PGDP  0.907761
# 376        mlp        PGD  0.900651
# 382        mlp       PGDP  0.907112
# 388        mlp        PGD  0.922878
# 394        mlp       PGDP  0.861381
# 400        mlp        PGD   0.89398
# 406        mlp       PGDP  0.835698
# 412        mlp        PGD  0.887727
# 418        mlp       PGDP  0.888191
# 424        mlp        PGD  0.864688
# 430        mlp       PGDP  0.913111
# 436        mlp        PGD  0.921426
# 442        mlp       PGDP  0.919917
# 448        mlp        PGD  0.949097
# 454        mlp       PGDP  0.941473
#        th  qualified_nodes embedding                    strategy classifier  \
# 32   0.05  SharedGeneEdges  Node2Vec                         all        mlp
# 36   0.05  SharedGeneEdges  Node2Vec                      bottom        mlp
# 40   0.05  SharedGeneEdges  Node2Vec                 bottom_rand        mlp
# 44   0.05  SharedGeneEdges  Node2Vec                      shared        mlp
# 48   0.05  SharedGeneEdges  Node2Vec                         top        mlp
# 52   0.05  SharedGeneEdges  Node2Vec                  top_bottom        mlp
# 56   0.05  SharedGeneEdges  Node2Vec             top_bottom_rand        mlp
# 60   0.05  SharedGeneEdges  Node2Vec                    top_rand        mlp
# 211  0.05  SharedGeneEdges  Node2Vec      bottom_k_deterministic        mlp
# 215  0.05  SharedGeneEdges  Node2Vec             bottom_k_random        mlp
# 219  0.05  SharedGeneEdges  Node2Vec  top_bottom_k_deterministic        mlp
# 222  0.05  SharedGeneEdges  Node2Vec                       top_k        mlp
# 226  0.05  SharedGeneEdges  Node2Vec                top_k_random        mlp
# 305  0.05  SharedGeneEdges  Node2Vec                         all        mlp
# 311  0.05  SharedGeneEdges  Node2Vec                         all        mlp
# 317  0.05  SharedGeneEdges  Node2Vec                      bottom        mlp
# 323  0.05  SharedGeneEdges  Node2Vec                      bottom        mlp
# 329  0.05  SharedGeneEdges  Node2Vec      bottom_k_deterministic        mlp
# 335  0.05  SharedGeneEdges  Node2Vec      bottom_k_deterministic        mlp
# 341  0.05  SharedGeneEdges  Node2Vec             bottom_k_random        mlp
# 347  0.05  SharedGeneEdges  Node2Vec             bottom_k_random        mlp
# 353  0.05  SharedGeneEdges  Node2Vec                 bottom_rand        mlp
# 359  0.05  SharedGeneEdges  Node2Vec                 bottom_rand        mlp
# 365  0.05  SharedGeneEdges  Node2Vec                      shared        mlp
# 371  0.05  SharedGeneEdges  Node2Vec                      shared        mlp
# 377  0.05  SharedGeneEdges  Node2Vec                         top        mlp
# 383  0.05  SharedGeneEdges  Node2Vec                         top        mlp
# 389  0.05  SharedGeneEdges  Node2Vec                  top_bottom        mlp
# 395  0.05  SharedGeneEdges  Node2Vec                  top_bottom        mlp
# 401  0.05  SharedGeneEdges  Node2Vec  top_bottom_k_deterministic        mlp
# 407  0.05  SharedGeneEdges  Node2Vec  top_bottom_k_deterministic        mlp
# 413  0.05  SharedGeneEdges  Node2Vec             top_bottom_rand        mlp
# 419  0.05  SharedGeneEdges  Node2Vec             top_bottom_rand        mlp
# 425  0.05  SharedGeneEdges  Node2Vec                       top_k        mlp
# 431  0.05  SharedGeneEdges  Node2Vec                       top_k        mlp
# 437  0.05  SharedGeneEdges  Node2Vec                top_k_random        mlp
# 443  0.05  SharedGeneEdges  Node2Vec                top_k_random        mlp
# 449  0.05  SharedGeneEdges  Node2Vec                    top_rand        mlp
# 455  0.05  SharedGeneEdges  Node2Vec                    top_rand        mlp
#
#     graph_type       auc
# 32         PGD  0.902853
# 36         PGD  0.918591
# 40         PGD  0.908217
# 44         PGD  0.872573
# 48         PGD  0.898394
# 52         PGD    0.8908
# 56         PGD  0.909089
# 60         PGD  0.902422
# 211       PGDP  0.898716
# 215       PGDP  0.909516
# 219       PGDP  0.900263
# 222       PGDP  0.899359
# 226       PGDP  0.888845
# 305        PGD  0.909707
# 311       PGDP  0.874099
# 317        PGD  0.934928
# 323       PGDP  0.873134
# 329        PGD  0.914242
# 335       PGDP  0.869852
# 341        PGD  0.861688
# 347       PGDP  0.897257
# 353        PGD  0.937631
# 359       PGDP  0.905656
# 365        PGD  0.872946
# 371       PGDP  0.910224
# 377        PGD   0.88461
# 383       PGDP   0.87341
# 389        PGD  0.899365
# 395       PGDP  0.902884
# 401        PGD  0.895579
# 407       PGDP  0.900929
# 413        PGD  0.894041
# 419       PGDP   0.87008
# 425        PGD  0.936435
# 431       PGDP  0.898971
# 437        PGD  0.914546
# 443       PGDP  0.897439
# 449        PGD  0.895556
# 455       PGDP  0.892196
#        th              qualified_nodes embedding                    strategy  \
# 64   0.05  SharedGeneNotPhenotypeEdges  Node2Vec                         all
# 68   0.05  SharedGeneNotPhenotypeEdges  Node2Vec                      bottom
# 72   0.05  SharedGeneNotPhenotypeEdges  Node2Vec                 bottom_rand
# 76   0.05  SharedGeneNotPhenotypeEdges  Node2Vec                      shared
# 80   0.05  SharedGeneNotPhenotypeEdges  Node2Vec                         top
# 84   0.05  SharedGeneNotPhenotypeEdges  Node2Vec                  top_bottom
# 88   0.05  SharedGeneNotPhenotypeEdges  Node2Vec             top_bottom_rand
# 92   0.05  SharedGeneNotPhenotypeEdges  Node2Vec                    top_rand
# 230  0.05  SharedGeneNotPhenotypeEdges  Node2Vec      bottom_k_deterministic
# 234  0.05  SharedGeneNotPhenotypeEdges  Node2Vec             bottom_k_random
# 238  0.05  SharedGeneNotPhenotypeEdges  Node2Vec  top_bottom_k_deterministic
# 240  0.05  SharedGeneNotPhenotypeEdges  Node2Vec                       top_k
# 244  0.05  SharedGeneNotPhenotypeEdges  Node2Vec                top_k_random
# 306  0.05  SharedGeneNotPhenotypeEdges  Node2Vec                         all
# 312  0.05  SharedGeneNotPhenotypeEdges  Node2Vec                         all
# 318  0.05  SharedGeneNotPhenotypeEdges  Node2Vec                      bottom
# 324  0.05  SharedGeneNotPhenotypeEdges  Node2Vec                      bottom
# 330  0.05  SharedGeneNotPhenotypeEdges  Node2Vec      bottom_k_deterministic
# 336  0.05  SharedGeneNotPhenotypeEdges  Node2Vec      bottom_k_deterministic
# 342  0.05  SharedGeneNotPhenotypeEdges  Node2Vec             bottom_k_random
# 348  0.05  SharedGeneNotPhenotypeEdges  Node2Vec             bottom_k_random
# 354  0.05  SharedGeneNotPhenotypeEdges  Node2Vec                 bottom_rand
# 360  0.05  SharedGeneNotPhenotypeEdges  Node2Vec                 bottom_rand
# 366  0.05  SharedGeneNotPhenotypeEdges  Node2Vec                      shared
# 372  0.05  SharedGeneNotPhenotypeEdges  Node2Vec                      shared
# 378  0.05  SharedGeneNotPhenotypeEdges  Node2Vec                         top
# 384  0.05  SharedGeneNotPhenotypeEdges  Node2Vec                         top
# 390  0.05  SharedGeneNotPhenotypeEdges  Node2Vec                  top_bottom
# 396  0.05  SharedGeneNotPhenotypeEdges  Node2Vec                  top_bottom
# 402  0.05  SharedGeneNotPhenotypeEdges  Node2Vec  top_bottom_k_deterministic
# 408  0.05  SharedGeneNotPhenotypeEdges  Node2Vec  top_bottom_k_deterministic
# 414  0.05  SharedGeneNotPhenotypeEdges  Node2Vec             top_bottom_rand
# 420  0.05  SharedGeneNotPhenotypeEdges  Node2Vec             top_bottom_rand
# 426  0.05  SharedGeneNotPhenotypeEdges  Node2Vec                       top_k
# 432  0.05  SharedGeneNotPhenotypeEdges  Node2Vec                       top_k
# 438  0.05  SharedGeneNotPhenotypeEdges  Node2Vec                top_k_random
# 444  0.05  SharedGeneNotPhenotypeEdges  Node2Vec                top_k_random
# 450  0.05  SharedGeneNotPhenotypeEdges  Node2Vec                    top_rand
# 456  0.05  SharedGeneNotPhenotypeEdges  Node2Vec                    top_rand
#
#     classifier graph_type       auc
# 64         mlp        PGD  0.907347
# 68         mlp        PGD  0.904122
# 72         mlp        PGD  0.881291
# 76         mlp        PGD  0.875536
# 80         mlp        PGD  0.862148
# 84         mlp        PGD   0.90614
# 88         mlp        PGD  0.892674
# 92         mlp        PGD  0.911253
# 230        mlp       PGDP  0.895657
# 234        mlp       PGDP  0.894583
# 238        mlp       PGDP  0.886745
# 240        mlp       PGDP  0.906111
# 244        mlp       PGDP  0.886282
# 306        mlp        PGD  0.930408
# 312        mlp       PGDP   0.89171
# 318        mlp        PGD  0.917576
# 324        mlp       PGDP   0.92788
# 330        mlp        PGD   0.91012
# 336        mlp       PGDP   0.88053
# 342        mlp        PGD  0.868372
# 348        mlp       PGDP  0.920578
# 354        mlp        PGD   0.85753
# 360        mlp       PGDP  0.878256
# 366        mlp        PGD  0.880292
# 372        mlp       PGDP  0.916039
# 378        mlp        PGD   0.90284
# 384        mlp       PGDP  0.909303
# 390        mlp        PGD  0.908318
# 396        mlp       PGDP  0.933032
# 402        mlp        PGD    0.8918
# 408        mlp       PGDP  0.881767
# 414        mlp        PGD  0.866746
# 420        mlp       PGDP  0.927224
# 426        mlp        PGD   0.86756
# 432        mlp       PGDP  0.924003
# 438        mlp        PGD  0.871155
# 444        mlp       PGDP  0.857982
# 450        mlp        PGD   0.89892
# 456        mlp       PGDP  0.904826
#        th             qualified_nodes embedding                    strategy  \
# 96   0.05  SharedGeneOrPhenotypeEdges  Node2Vec                         all
# 100  0.05  SharedGeneOrPhenotypeEdges  Node2Vec                      bottom
# 104  0.05  SharedGeneOrPhenotypeEdges  Node2Vec                 bottom_rand
# 108  0.05  SharedGeneOrPhenotypeEdges  Node2Vec                      shared
# 112  0.05  SharedGeneOrPhenotypeEdges  Node2Vec                         top
# 116  0.05  SharedGeneOrPhenotypeEdges  Node2Vec                  top_bottom
# 120  0.05  SharedGeneOrPhenotypeEdges  Node2Vec             top_bottom_rand
# 124  0.05  SharedGeneOrPhenotypeEdges  Node2Vec                    top_rand
# 248  0.05  SharedGeneOrPhenotypeEdges  Node2Vec      bottom_k_deterministic
# 252  0.05  SharedGeneOrPhenotypeEdges  Node2Vec             bottom_k_random
# 256  0.05  SharedGeneOrPhenotypeEdges  Node2Vec  top_bottom_k_deterministic
# 259  0.05  SharedGeneOrPhenotypeEdges  Node2Vec                       top_k
# 263  0.05  SharedGeneOrPhenotypeEdges  Node2Vec                top_k_random
# 307  0.05  SharedGeneOrPhenotypeEdges  Node2Vec                         all
# 313  0.05  SharedGeneOrPhenotypeEdges  Node2Vec                         all
# 319  0.05  SharedGeneOrPhenotypeEdges  Node2Vec                      bottom
# 325  0.05  SharedGeneOrPhenotypeEdges  Node2Vec                      bottom
# 331  0.05  SharedGeneOrPhenotypeEdges  Node2Vec      bottom_k_deterministic
# 337  0.05  SharedGeneOrPhenotypeEdges  Node2Vec      bottom_k_deterministic
# 343  0.05  SharedGeneOrPhenotypeEdges  Node2Vec             bottom_k_random
# 349  0.05  SharedGeneOrPhenotypeEdges  Node2Vec             bottom_k_random
# 355  0.05  SharedGeneOrPhenotypeEdges  Node2Vec                 bottom_rand
# 361  0.05  SharedGeneOrPhenotypeEdges  Node2Vec                 bottom_rand
# 367  0.05  SharedGeneOrPhenotypeEdges  Node2Vec                      shared
# 373  0.05  SharedGeneOrPhenotypeEdges  Node2Vec                      shared
# 379  0.05  SharedGeneOrPhenotypeEdges  Node2Vec                         top
# 385  0.05  SharedGeneOrPhenotypeEdges  Node2Vec                         top
# 391  0.05  SharedGeneOrPhenotypeEdges  Node2Vec                  top_bottom
# 397  0.05  SharedGeneOrPhenotypeEdges  Node2Vec                  top_bottom
# 403  0.05  SharedGeneOrPhenotypeEdges  Node2Vec  top_bottom_k_deterministic
# 409  0.05  SharedGeneOrPhenotypeEdges  Node2Vec  top_bottom_k_deterministic
# 415  0.05  SharedGeneOrPhenotypeEdges  Node2Vec             top_bottom_rand
# 421  0.05  SharedGeneOrPhenotypeEdges  Node2Vec             top_bottom_rand
# 427  0.05  SharedGeneOrPhenotypeEdges  Node2Vec                       top_k
# 433  0.05  SharedGeneOrPhenotypeEdges  Node2Vec                       top_k
# 439  0.05  SharedGeneOrPhenotypeEdges  Node2Vec                top_k_random
# 445  0.05  SharedGeneOrPhenotypeEdges  Node2Vec                top_k_random
# 451  0.05  SharedGeneOrPhenotypeEdges  Node2Vec                    top_rand
# 457  0.05  SharedGeneOrPhenotypeEdges  Node2Vec                    top_rand
#
#     classifier graph_type       auc
# 96         mlp        PGD  0.909978
# 100        mlp        PGD  0.901449
# 104        mlp        PGD  0.909194
# 108        mlp        PGD  0.901289
# 112        mlp        PGD  0.902747
# 116        mlp        PGD   0.89417
# 120        mlp        PGD  0.900136
# 124        mlp        PGD    0.9003
# 248        mlp       PGDP  0.880141
# 252        mlp       PGDP  0.914039
# 256        mlp       PGDP  0.898754
# 259        mlp       PGDP  0.879143
# 263        mlp       PGDP  0.898783
# 307        mlp        PGD  0.904929
# 313        mlp       PGDP    0.9006
# 319        mlp        PGD  0.899361
# 325        mlp       PGDP  0.926332
# 331        mlp        PGD  0.922731
# 337        mlp       PGDP   0.89647
# 343        mlp        PGD  0.870852
# 349        mlp       PGDP  0.879377
# 355        mlp        PGD  0.898199
# 361        mlp       PGDP   0.92049
# 367        mlp        PGD   0.90156
# 373        mlp       PGDP  0.866856
# 379        mlp        PGD  0.891732
# 385        mlp       PGDP  0.909238
# 391        mlp        PGD  0.894736
# 397        mlp       PGDP  0.887962
# 403        mlp        PGD  0.845757
# 409        mlp       PGDP   0.88975
# 415        mlp        PGD  0.902039
# 421        mlp       PGDP  0.909368
# 427        mlp        PGD  0.873557
# 433        mlp       PGDP  0.894337
# 439        mlp        PGD  0.892355
# 445        mlp       PGDP  0.885968
# 451        mlp        PGD  0.915564
# 457        mlp       PGDP    0.9009
#        th       qualified_nodes embedding                    strategy  \
# 128  0.05  SharedPhenotypeEdges  Node2Vec                         all
# 132  0.05  SharedPhenotypeEdges  Node2Vec                      bottom
# 136  0.05  SharedPhenotypeEdges  Node2Vec                 bottom_rand
# 140  0.05  SharedPhenotypeEdges  Node2Vec                      shared
# 144  0.05  SharedPhenotypeEdges  Node2Vec                         top
# 148  0.05  SharedPhenotypeEdges  Node2Vec                  top_bottom
# 152  0.05  SharedPhenotypeEdges  Node2Vec             top_bottom_rand
# 156  0.05  SharedPhenotypeEdges  Node2Vec                    top_rand
# 267  0.05  SharedPhenotypeEdges  Node2Vec      bottom_k_deterministic
# 271  0.05  SharedPhenotypeEdges  Node2Vec             bottom_k_random
# 275  0.05  SharedPhenotypeEdges  Node2Vec  top_bottom_k_deterministic
# 278  0.05  SharedPhenotypeEdges  Node2Vec                       top_k
# 282  0.05  SharedPhenotypeEdges  Node2Vec                top_k_random
# 308  0.05  SharedPhenotypeEdges  Node2Vec                         all
# 314  0.05  SharedPhenotypeEdges  Node2Vec                         all
# 320  0.05  SharedPhenotypeEdges  Node2Vec                      bottom
# 326  0.05  SharedPhenotypeEdges  Node2Vec                      bottom
# 332  0.05  SharedPhenotypeEdges  Node2Vec      bottom_k_deterministic
# 338  0.05  SharedPhenotypeEdges  Node2Vec      bottom_k_deterministic
# 344  0.05  SharedPhenotypeEdges  Node2Vec             bottom_k_random
# 350  0.05  SharedPhenotypeEdges  Node2Vec             bottom_k_random
# 356  0.05  SharedPhenotypeEdges  Node2Vec                 bottom_rand
# 362  0.05  SharedPhenotypeEdges  Node2Vec                 bottom_rand
# 368  0.05  SharedPhenotypeEdges  Node2Vec                      shared
# 374  0.05  SharedPhenotypeEdges  Node2Vec                      shared
# 380  0.05  SharedPhenotypeEdges  Node2Vec                         top
# 386  0.05  SharedPhenotypeEdges  Node2Vec                         top
# 392  0.05  SharedPhenotypeEdges  Node2Vec                  top_bottom
# 398  0.05  SharedPhenotypeEdges  Node2Vec                  top_bottom
# 404  0.05  SharedPhenotypeEdges  Node2Vec  top_bottom_k_deterministic
# 410  0.05  SharedPhenotypeEdges  Node2Vec  top_bottom_k_deterministic
# 416  0.05  SharedPhenotypeEdges  Node2Vec             top_bottom_rand
# 422  0.05  SharedPhenotypeEdges  Node2Vec             top_bottom_rand
# 428  0.05  SharedPhenotypeEdges  Node2Vec                       top_k
# 434  0.05  SharedPhenotypeEdges  Node2Vec                       top_k
# 440  0.05  SharedPhenotypeEdges  Node2Vec                top_k_random
# 446  0.05  SharedPhenotypeEdges  Node2Vec                top_k_random
# 452  0.05  SharedPhenotypeEdges  Node2Vec                    top_rand
# 458  0.05  SharedPhenotypeEdges  Node2Vec                    top_rand
#
#     classifier graph_type       auc
# 128        mlp        PGD  0.902683
# 132        mlp        PGD  0.908133
# 136        mlp        PGD  0.879599
# 140        mlp        PGD  0.894827
# 144        mlp        PGD  0.900726
# 148        mlp        PGD  0.893419
# 152        mlp        PGD   0.89308
# 156        mlp        PGD  0.883078
# 267        mlp       PGDP  0.909403
# 271        mlp       PGDP  0.875241
# 275        mlp       PGDP  0.919199
# 278        mlp       PGDP  0.904492
# 282        mlp       PGDP  0.892344
# 308        mlp        PGD   0.92231
# 314        mlp       PGDP   0.88634
# 320        mlp        PGD  0.897507
# 326        mlp       PGDP  0.890463
# 332        mlp        PGD  0.888976
# 338        mlp       PGDP  0.924412
# 344        mlp        PGD  0.884612
# 350        mlp       PGDP  0.855575
# 356        mlp        PGD  0.860798
# 362        mlp       PGDP  0.893908
# 368        mlp        PGD  0.862116
# 374        mlp       PGDP  0.858677
# 380        mlp        PGD  0.915735
# 386        mlp       PGDP  0.864167
# 392        mlp        PGD  0.881842
# 398        mlp       PGDP  0.932139
# 404        mlp        PGD  0.861407
# 410        mlp       PGDP  0.921848
# 416        mlp        PGD  0.884605
# 422        mlp       PGDP  0.856339
# 428        mlp        PGD  0.890726
# 434        mlp       PGDP  0.874538
# 440        mlp        PGD  0.865349
# 446        mlp       PGDP  0.907937
# 452        mlp        PGD  0.886937
# 458        mlp       PGDP  0.889104
#        th              qualified_nodes embedding                    strategy  \
# 160  0.05  SharedPhenotypeNotGeneEdges  Node2Vec                         all
# 164  0.05  SharedPhenotypeNotGeneEdges  Node2Vec                      bottom
# 168  0.05  SharedPhenotypeNotGeneEdges  Node2Vec                 bottom_rand
# 172  0.05  SharedPhenotypeNotGeneEdges  Node2Vec                      shared
# 176  0.05  SharedPhenotypeNotGeneEdges  Node2Vec                         top
# 180  0.05  SharedPhenotypeNotGeneEdges  Node2Vec                  top_bottom
# 184  0.05  SharedPhenotypeNotGeneEdges  Node2Vec             top_bottom_rand
# 188  0.05  SharedPhenotypeNotGeneEdges  Node2Vec                    top_rand
# 286  0.05  SharedPhenotypeNotGeneEdges  Node2Vec      bottom_k_deterministic
# 290  0.05  SharedPhenotypeNotGeneEdges  Node2Vec             bottom_k_random
# 294  0.05  SharedPhenotypeNotGeneEdges  Node2Vec  top_bottom_k_deterministic
# 296  0.05  SharedPhenotypeNotGeneEdges  Node2Vec                       top_k
# 300  0.05  SharedPhenotypeNotGeneEdges  Node2Vec                top_k_random
# 309  0.05  SharedPhenotypeNotGeneEdges  Node2Vec                         all
# 315  0.05  SharedPhenotypeNotGeneEdges  Node2Vec                         all
# 321  0.05  SharedPhenotypeNotGeneEdges  Node2Vec                      bottom
# 327  0.05  SharedPhenotypeNotGeneEdges  Node2Vec                      bottom
# 333  0.05  SharedPhenotypeNotGeneEdges  Node2Vec      bottom_k_deterministic
# 339  0.05  SharedPhenotypeNotGeneEdges  Node2Vec      bottom_k_deterministic
# 345  0.05  SharedPhenotypeNotGeneEdges  Node2Vec             bottom_k_random
# 351  0.05  SharedPhenotypeNotGeneEdges  Node2Vec             bottom_k_random
# 357  0.05  SharedPhenotypeNotGeneEdges  Node2Vec                 bottom_rand
# 363  0.05  SharedPhenotypeNotGeneEdges  Node2Vec                 bottom_rand
# 369  0.05  SharedPhenotypeNotGeneEdges  Node2Vec                      shared
# 375  0.05  SharedPhenotypeNotGeneEdges  Node2Vec                      shared
# 381  0.05  SharedPhenotypeNotGeneEdges  Node2Vec                         top
# 387  0.05  SharedPhenotypeNotGeneEdges  Node2Vec                         top
# 393  0.05  SharedPhenotypeNotGeneEdges  Node2Vec                  top_bottom
# 399  0.05  SharedPhenotypeNotGeneEdges  Node2Vec                  top_bottom
# 405  0.05  SharedPhenotypeNotGeneEdges  Node2Vec  top_bottom_k_deterministic
# 411  0.05  SharedPhenotypeNotGeneEdges  Node2Vec  top_bottom_k_deterministic
# 417  0.05  SharedPhenotypeNotGeneEdges  Node2Vec             top_bottom_rand
# 423  0.05  SharedPhenotypeNotGeneEdges  Node2Vec             top_bottom_rand
# 429  0.05  SharedPhenotypeNotGeneEdges  Node2Vec                       top_k
# 435  0.05  SharedPhenotypeNotGeneEdges  Node2Vec                       top_k
# 441  0.05  SharedPhenotypeNotGeneEdges  Node2Vec                top_k_random
# 447  0.05  SharedPhenotypeNotGeneEdges  Node2Vec                top_k_random
# 453  0.05  SharedPhenotypeNotGeneEdges  Node2Vec                    top_rand
# 459  0.05  SharedPhenotypeNotGeneEdges  Node2Vec                    top_rand
#
#     classifier graph_type       auc
# 160        mlp        PGD  0.905647
# 164        mlp        PGD  0.908159
# 168        mlp        PGD  0.901923
# 172        mlp        PGD  0.893182
# 176        mlp        PGD  0.904836
# 180        mlp        PGD   0.90225
# 184        mlp        PGD  0.884992
# 188        mlp        PGD  0.889395
# 286        mlp       PGDP  0.911418
# 290        mlp       PGDP   0.90864
# 294        mlp       PGDP  0.898369
# 296        mlp       PGDP   0.91662
# 300        mlp       PGDP  0.878879
# 309        mlp        PGD  0.915931
# 315        mlp       PGDP  0.904204
# 321        mlp        PGD  0.928754
# 327        mlp       PGDP  0.878652
# 333        mlp        PGD  0.896614
# 339        mlp       PGDP  0.902299
# 345        mlp        PGD  0.882137
# 351        mlp       PGDP   0.91579
# 357        mlp        PGD  0.885365
# 363        mlp       PGDP  0.877706
# 369        mlp        PGD  0.872298
# 375        mlp       PGDP  0.902822
# 381        mlp        PGD  0.878696
# 387        mlp       PGDP    0.9136
# 393        mlp        PGD  0.878261
# 399        mlp       PGDP  0.895561
# 405        mlp        PGD  0.872775
# 411        mlp       PGDP  0.898813
# 417        mlp        PGD  0.861272
# 423        mlp       PGDP  0.892804
# 429        mlp        PGD  0.866919
# 435        mlp       PGDP  0.892742
# 441        mlp        PGD  0.897658
# 447        mlp       PGDP  0.870116
# 453        mlp        PGD  0.882425
# 459        mlp       PGDP  0.872545
#       th              qualified_nodes embedding                    strategy  \
# 1    0.1  SharedGeneAndPhenotypeEdges  Node2Vec                         all
# 5    0.1  SharedGeneAndPhenotypeEdges  Node2Vec                      bottom
# 9    0.1  SharedGeneAndPhenotypeEdges  Node2Vec                 bottom_rand
# 13   0.1  SharedGeneAndPhenotypeEdges  Node2Vec                      shared
# 17   0.1  SharedGeneAndPhenotypeEdges  Node2Vec                         top
# 21   0.1  SharedGeneAndPhenotypeEdges  Node2Vec                  top_bottom
# 25   0.1  SharedGeneAndPhenotypeEdges  Node2Vec             top_bottom_rand
# 29   0.1  SharedGeneAndPhenotypeEdges  Node2Vec                    top_rand
# 193  0.1  SharedGeneAndPhenotypeEdges  Node2Vec      bottom_k_deterministic
# 197  0.1  SharedGeneAndPhenotypeEdges  Node2Vec             bottom_k_random
# 201  0.1  SharedGeneAndPhenotypeEdges  Node2Vec  top_bottom_k_deterministic
# 204  0.1  SharedGeneAndPhenotypeEdges  Node2Vec                       top_k
# 208  0.1  SharedGeneAndPhenotypeEdges  Node2Vec                top_k_random
# 460  0.1  SharedGeneAndPhenotypeEdges  Node2Vec                         all
# 466  0.1  SharedGeneAndPhenotypeEdges  Node2Vec                         all
# 472  0.1  SharedGeneAndPhenotypeEdges  Node2Vec                      bottom
# 478  0.1  SharedGeneAndPhenotypeEdges  Node2Vec                      bottom
# 484  0.1  SharedGeneAndPhenotypeEdges  Node2Vec      bottom_k_deterministic
# 490  0.1  SharedGeneAndPhenotypeEdges  Node2Vec      bottom_k_deterministic
# 496  0.1  SharedGeneAndPhenotypeEdges  Node2Vec             bottom_k_random
# 502  0.1  SharedGeneAndPhenotypeEdges  Node2Vec             bottom_k_random
# 508  0.1  SharedGeneAndPhenotypeEdges  Node2Vec                 bottom_rand
# 514  0.1  SharedGeneAndPhenotypeEdges  Node2Vec                 bottom_rand
# 520  0.1  SharedGeneAndPhenotypeEdges  Node2Vec                      shared
# 526  0.1  SharedGeneAndPhenotypeEdges  Node2Vec                      shared
# 532  0.1  SharedGeneAndPhenotypeEdges  Node2Vec                         top
# 538  0.1  SharedGeneAndPhenotypeEdges  Node2Vec                         top
# 544  0.1  SharedGeneAndPhenotypeEdges  Node2Vec                  top_bottom
# 550  0.1  SharedGeneAndPhenotypeEdges  Node2Vec                  top_bottom
# 556  0.1  SharedGeneAndPhenotypeEdges  Node2Vec  top_bottom_k_deterministic
# 562  0.1  SharedGeneAndPhenotypeEdges  Node2Vec  top_bottom_k_deterministic
# 568  0.1  SharedGeneAndPhenotypeEdges  Node2Vec             top_bottom_rand
# 574  0.1  SharedGeneAndPhenotypeEdges  Node2Vec             top_bottom_rand
# 580  0.1  SharedGeneAndPhenotypeEdges  Node2Vec                       top_k
# 586  0.1  SharedGeneAndPhenotypeEdges  Node2Vec                       top_k
# 592  0.1  SharedGeneAndPhenotypeEdges  Node2Vec                top_k_random
# 598  0.1  SharedGeneAndPhenotypeEdges  Node2Vec                top_k_random
# 604  0.1  SharedGeneAndPhenotypeEdges  Node2Vec                    top_rand
# 610  0.1  SharedGeneAndPhenotypeEdges  Node2Vec                    top_rand
#
#     classifier graph_type       auc
# 1          mlp        PGD  0.908047
# 5          mlp        PGD  0.892015
# 9          mlp        PGD  0.912124
# 13         mlp        PGD  0.911104
# 17         mlp        PGD  0.881251
# 21         mlp        PGD  0.898677
# 25         mlp        PGD  0.887524
# 29         mlp        PGD  0.868447
# 193        mlp       PGDP  0.886288
# 197        mlp       PGDP  0.894434
# 201        mlp       PGDP   0.90766
# 204        mlp       PGDP  0.908038
# 208        mlp       PGDP  0.889825
# 460        mlp        PGD   0.94212
# 466        mlp       PGDP  0.910562
# 472        mlp        PGD  0.851711
# 478        mlp       PGDP  0.892976
# 484        mlp        PGD  0.885212
# 490        mlp       PGDP    0.8722
# 496        mlp        PGD  0.918911
# 502        mlp       PGDP  0.882434
# 508        mlp        PGD   0.91416
# 514        mlp       PGDP  0.906048
# 520        mlp        PGD  0.919574
# 526        mlp       PGDP  0.903329
# 532        mlp        PGD   0.90031
# 538        mlp       PGDP  0.897265
# 544        mlp        PGD  0.895396
# 550        mlp       PGDP  0.909544
# 556        mlp        PGD  0.924609
# 562        mlp       PGDP  0.909896
# 568        mlp        PGD  0.862118
# 574        mlp       PGDP  0.896004
# 580        mlp        PGD  0.852842
# 586        mlp       PGDP   0.94842
# 592        mlp        PGD  0.890165
# 598        mlp       PGDP  0.893352
# 604        mlp        PGD  0.857478
# 610        mlp       PGDP  0.932391
#       th  qualified_nodes embedding                    strategy classifier  \
# 33   0.1  SharedGeneEdges  Node2Vec                         all        mlp
# 37   0.1  SharedGeneEdges  Node2Vec                      bottom        mlp
# 41   0.1  SharedGeneEdges  Node2Vec                 bottom_rand        mlp
# 45   0.1  SharedGeneEdges  Node2Vec                      shared        mlp
# 49   0.1  SharedGeneEdges  Node2Vec                         top        mlp
# 53   0.1  SharedGeneEdges  Node2Vec                  top_bottom        mlp
# 57   0.1  SharedGeneEdges  Node2Vec             top_bottom_rand        mlp
# 61   0.1  SharedGeneEdges  Node2Vec                    top_rand        mlp
# 212  0.1  SharedGeneEdges  Node2Vec      bottom_k_deterministic        mlp
# 216  0.1  SharedGeneEdges  Node2Vec             bottom_k_random        mlp
# 220  0.1  SharedGeneEdges  Node2Vec  top_bottom_k_deterministic        mlp
# 223  0.1  SharedGeneEdges  Node2Vec                       top_k        mlp
# 227  0.1  SharedGeneEdges  Node2Vec                top_k_random        mlp
# 461  0.1  SharedGeneEdges  Node2Vec                         all        mlp
# 467  0.1  SharedGeneEdges  Node2Vec                         all        mlp
# 473  0.1  SharedGeneEdges  Node2Vec                      bottom        mlp
# 479  0.1  SharedGeneEdges  Node2Vec                      bottom        mlp
# 485  0.1  SharedGeneEdges  Node2Vec      bottom_k_deterministic        mlp
# 491  0.1  SharedGeneEdges  Node2Vec      bottom_k_deterministic        mlp
# 497  0.1  SharedGeneEdges  Node2Vec             bottom_k_random        mlp
# 503  0.1  SharedGeneEdges  Node2Vec             bottom_k_random        mlp
# 509  0.1  SharedGeneEdges  Node2Vec                 bottom_rand        mlp
# 515  0.1  SharedGeneEdges  Node2Vec                 bottom_rand        mlp
# 521  0.1  SharedGeneEdges  Node2Vec                      shared        mlp
# 527  0.1  SharedGeneEdges  Node2Vec                      shared        mlp
# 533  0.1  SharedGeneEdges  Node2Vec                         top        mlp
# 539  0.1  SharedGeneEdges  Node2Vec                         top        mlp
# 545  0.1  SharedGeneEdges  Node2Vec                  top_bottom        mlp
# 551  0.1  SharedGeneEdges  Node2Vec                  top_bottom        mlp
# 557  0.1  SharedGeneEdges  Node2Vec  top_bottom_k_deterministic        mlp
# 563  0.1  SharedGeneEdges  Node2Vec  top_bottom_k_deterministic        mlp
# 569  0.1  SharedGeneEdges  Node2Vec             top_bottom_rand        mlp
# 575  0.1  SharedGeneEdges  Node2Vec             top_bottom_rand        mlp
# 581  0.1  SharedGeneEdges  Node2Vec                       top_k        mlp
# 587  0.1  SharedGeneEdges  Node2Vec                       top_k        mlp
# 593  0.1  SharedGeneEdges  Node2Vec                top_k_random        mlp
# 599  0.1  SharedGeneEdges  Node2Vec                top_k_random        mlp
# 605  0.1  SharedGeneEdges  Node2Vec                    top_rand        mlp
# 611  0.1  SharedGeneEdges  Node2Vec                    top_rand        mlp
#
#     graph_type       auc
# 33         PGD  0.887828
# 37         PGD  0.894595
# 41         PGD  0.855059
# 45         PGD  0.904605
# 49         PGD  0.889905
# 53         PGD  0.902157
# 57         PGD  0.884237
# 61         PGD  0.894036
# 212       PGDP  0.910637
# 216       PGDP  0.908238
# 220       PGDP  0.907528
# 223       PGDP  0.883888
# 227       PGDP  0.897715
# 461        PGD  0.873385
# 467       PGDP  0.863312
# 473        PGD  0.893005
# 479       PGDP  0.935306
# 485        PGD  0.891179
# 491       PGDP   0.89881
# 497        PGD  0.937055
# 503       PGDP  0.939761
# 509        PGD  0.881226
# 515       PGDP  0.888014
# 521        PGD  0.901415
# 527       PGDP  0.902045
# 533        PGD  0.870238
# 539       PGDP  0.883445
# 545        PGD  0.926489
# 551       PGDP  0.869822
# 557        PGD   0.90033
# 563       PGDP  0.958316
# 569        PGD  0.896947
# 575       PGDP  0.925851
# 581        PGD  0.910684
# 587       PGDP  0.898836
# 593        PGD  0.878379
# 599       PGDP  0.880201
# 605        PGD  0.892983
# 611       PGDP  0.888777
#       th              qualified_nodes embedding                    strategy  \
# 65   0.1  SharedGeneNotPhenotypeEdges  Node2Vec                         all
# 69   0.1  SharedGeneNotPhenotypeEdges  Node2Vec                      bottom
# 73   0.1  SharedGeneNotPhenotypeEdges  Node2Vec                 bottom_rand
# 77   0.1  SharedGeneNotPhenotypeEdges  Node2Vec                      shared
# 81   0.1  SharedGeneNotPhenotypeEdges  Node2Vec                         top
# 85   0.1  SharedGeneNotPhenotypeEdges  Node2Vec                  top_bottom
# 89   0.1  SharedGeneNotPhenotypeEdges  Node2Vec             top_bottom_rand
# 93   0.1  SharedGeneNotPhenotypeEdges  Node2Vec                    top_rand
# 231  0.1  SharedGeneNotPhenotypeEdges  Node2Vec      bottom_k_deterministic
# 235  0.1  SharedGeneNotPhenotypeEdges  Node2Vec             bottom_k_random
# 239  0.1  SharedGeneNotPhenotypeEdges  Node2Vec  top_bottom_k_deterministic
# 241  0.1  SharedGeneNotPhenotypeEdges  Node2Vec                       top_k
# 245  0.1  SharedGeneNotPhenotypeEdges  Node2Vec                top_k_random
# 462  0.1  SharedGeneNotPhenotypeEdges  Node2Vec                         all
# 468  0.1  SharedGeneNotPhenotypeEdges  Node2Vec                         all
# 474  0.1  SharedGeneNotPhenotypeEdges  Node2Vec                      bottom
# 480  0.1  SharedGeneNotPhenotypeEdges  Node2Vec                      bottom
# 486  0.1  SharedGeneNotPhenotypeEdges  Node2Vec      bottom_k_deterministic
# 492  0.1  SharedGeneNotPhenotypeEdges  Node2Vec      bottom_k_deterministic
# 498  0.1  SharedGeneNotPhenotypeEdges  Node2Vec             bottom_k_random
# 504  0.1  SharedGeneNotPhenotypeEdges  Node2Vec             bottom_k_random
# 510  0.1  SharedGeneNotPhenotypeEdges  Node2Vec                 bottom_rand
# 516  0.1  SharedGeneNotPhenotypeEdges  Node2Vec                 bottom_rand
# 522  0.1  SharedGeneNotPhenotypeEdges  Node2Vec                      shared
# 528  0.1  SharedGeneNotPhenotypeEdges  Node2Vec                      shared
# 534  0.1  SharedGeneNotPhenotypeEdges  Node2Vec                         top
# 540  0.1  SharedGeneNotPhenotypeEdges  Node2Vec                         top
# 546  0.1  SharedGeneNotPhenotypeEdges  Node2Vec                  top_bottom
# 552  0.1  SharedGeneNotPhenotypeEdges  Node2Vec                  top_bottom
# 558  0.1  SharedGeneNotPhenotypeEdges  Node2Vec  top_bottom_k_deterministic
# 564  0.1  SharedGeneNotPhenotypeEdges  Node2Vec  top_bottom_k_deterministic
# 570  0.1  SharedGeneNotPhenotypeEdges  Node2Vec             top_bottom_rand
# 576  0.1  SharedGeneNotPhenotypeEdges  Node2Vec             top_bottom_rand
# 582  0.1  SharedGeneNotPhenotypeEdges  Node2Vec                       top_k
# 588  0.1  SharedGeneNotPhenotypeEdges  Node2Vec                       top_k
# 594  0.1  SharedGeneNotPhenotypeEdges  Node2Vec                top_k_random
# 600  0.1  SharedGeneNotPhenotypeEdges  Node2Vec                top_k_random
# 606  0.1  SharedGeneNotPhenotypeEdges  Node2Vec                    top_rand
# 612  0.1  SharedGeneNotPhenotypeEdges  Node2Vec                    top_rand
#
#     classifier graph_type       auc
# 65         mlp        PGD  0.901534
# 69         mlp        PGD  0.896694
# 73         mlp        PGD  0.906388
# 77         mlp        PGD   0.89347
# 81         mlp        PGD  0.891367
# 85         mlp        PGD  0.882056
# 89         mlp        PGD  0.904581
# 93         mlp        PGD  0.901272
# 231        mlp       PGDP   0.89995
# 235        mlp       PGDP  0.880453
# 239        mlp       PGDP  0.901066
# 241        mlp       PGDP  0.899655
# 245        mlp       PGDP  0.866595
# 462        mlp        PGD  0.923407
# 468        mlp       PGDP  0.934366
# 474        mlp        PGD  0.902715
# 480        mlp       PGDP   0.90596
# 486        mlp        PGD  0.903948
# 492        mlp       PGDP  0.914689
# 498        mlp        PGD  0.886382
# 504        mlp       PGDP  0.892541
# 510        mlp        PGD   0.93414
# 516        mlp       PGDP  0.905042
# 522        mlp        PGD  0.918292
# 528        mlp       PGDP  0.889273
# 534        mlp        PGD  0.869475
# 540        mlp       PGDP  0.918011
# 546        mlp        PGD  0.869519
# 552        mlp       PGDP  0.925946
# 558        mlp        PGD  0.894747
# 564        mlp       PGDP  0.909138
# 570        mlp        PGD  0.898612
# 576        mlp       PGDP  0.902893
# 582        mlp        PGD  0.889797
# 588        mlp       PGDP   0.88786
# 594        mlp        PGD  0.926687
# 600        mlp       PGDP  0.868947
# 606        mlp        PGD  0.964739
# 612        mlp       PGDP  0.905475
#       th             qualified_nodes embedding                    strategy  \
# 97   0.1  SharedGeneOrPhenotypeEdges  Node2Vec                         all
# 101  0.1  SharedGeneOrPhenotypeEdges  Node2Vec                      bottom
# 105  0.1  SharedGeneOrPhenotypeEdges  Node2Vec                 bottom_rand
# 109  0.1  SharedGeneOrPhenotypeEdges  Node2Vec                      shared
# 113  0.1  SharedGeneOrPhenotypeEdges  Node2Vec                         top
# 117  0.1  SharedGeneOrPhenotypeEdges  Node2Vec                  top_bottom
# 121  0.1  SharedGeneOrPhenotypeEdges  Node2Vec             top_bottom_rand
# 125  0.1  SharedGeneOrPhenotypeEdges  Node2Vec                    top_rand
# 249  0.1  SharedGeneOrPhenotypeEdges  Node2Vec      bottom_k_deterministic
# 253  0.1  SharedGeneOrPhenotypeEdges  Node2Vec             bottom_k_random
# 257  0.1  SharedGeneOrPhenotypeEdges  Node2Vec  top_bottom_k_deterministic
# 260  0.1  SharedGeneOrPhenotypeEdges  Node2Vec                       top_k
# 264  0.1  SharedGeneOrPhenotypeEdges  Node2Vec                top_k_random
# 463  0.1  SharedGeneOrPhenotypeEdges  Node2Vec                         all
# 469  0.1  SharedGeneOrPhenotypeEdges  Node2Vec                         all
# 475  0.1  SharedGeneOrPhenotypeEdges  Node2Vec                      bottom
# 481  0.1  SharedGeneOrPhenotypeEdges  Node2Vec                      bottom
# 487  0.1  SharedGeneOrPhenotypeEdges  Node2Vec      bottom_k_deterministic
# 493  0.1  SharedGeneOrPhenotypeEdges  Node2Vec      bottom_k_deterministic
# 499  0.1  SharedGeneOrPhenotypeEdges  Node2Vec             bottom_k_random
# 505  0.1  SharedGeneOrPhenotypeEdges  Node2Vec             bottom_k_random
# 511  0.1  SharedGeneOrPhenotypeEdges  Node2Vec                 bottom_rand
# 517  0.1  SharedGeneOrPhenotypeEdges  Node2Vec                 bottom_rand
# 523  0.1  SharedGeneOrPhenotypeEdges  Node2Vec                      shared
# 529  0.1  SharedGeneOrPhenotypeEdges  Node2Vec                      shared
# 535  0.1  SharedGeneOrPhenotypeEdges  Node2Vec                         top
# 541  0.1  SharedGeneOrPhenotypeEdges  Node2Vec                         top
# 547  0.1  SharedGeneOrPhenotypeEdges  Node2Vec                  top_bottom
# 553  0.1  SharedGeneOrPhenotypeEdges  Node2Vec                  top_bottom
# 559  0.1  SharedGeneOrPhenotypeEdges  Node2Vec  top_bottom_k_deterministic
# 565  0.1  SharedGeneOrPhenotypeEdges  Node2Vec  top_bottom_k_deterministic
# 571  0.1  SharedGeneOrPhenotypeEdges  Node2Vec             top_bottom_rand
# 577  0.1  SharedGeneOrPhenotypeEdges  Node2Vec             top_bottom_rand
# 583  0.1  SharedGeneOrPhenotypeEdges  Node2Vec                       top_k
# 589  0.1  SharedGeneOrPhenotypeEdges  Node2Vec                       top_k
# 595  0.1  SharedGeneOrPhenotypeEdges  Node2Vec                top_k_random
# 601  0.1  SharedGeneOrPhenotypeEdges  Node2Vec                top_k_random
# 607  0.1  SharedGeneOrPhenotypeEdges  Node2Vec                    top_rand
# 613  0.1  SharedGeneOrPhenotypeEdges  Node2Vec                    top_rand
#
#     classifier graph_type       auc
# 97         mlp        PGD  0.906774
# 101        mlp        PGD  0.901612
# 105        mlp        PGD  0.878091
# 109        mlp        PGD  0.907216
# 113        mlp        PGD  0.897638
# 117        mlp        PGD   0.89775
# 121        mlp        PGD  0.879242
# 125        mlp        PGD   0.89154
# 249        mlp       PGDP  0.893635
# 253        mlp       PGDP  0.892233
# 257        mlp       PGDP  0.914367
# 260        mlp       PGDP  0.895017
# 264        mlp       PGDP  0.869739
# 463        mlp        PGD  0.902184
# 469        mlp       PGDP  0.866552
# 475        mlp        PGD  0.867914
# 481        mlp       PGDP  0.895173
# 487        mlp        PGD  0.873619
# 493        mlp       PGDP  0.902352
# 499        mlp        PGD  0.908484
# 505        mlp       PGDP  0.874092
# 511        mlp        PGD  0.843383
# 517        mlp       PGDP  0.866905
# 523        mlp        PGD  0.940486
# 529        mlp       PGDP  0.867007
# 535        mlp        PGD  0.892811
# 541        mlp       PGDP  0.914041
# 547        mlp        PGD  0.892252
# 553        mlp       PGDP  0.891901
# 559        mlp        PGD  0.912131
# 565        mlp       PGDP   0.87667
# 571        mlp        PGD  0.871196
# 577        mlp       PGDP  0.885888
# 583        mlp        PGD  0.905109
# 589        mlp       PGDP  0.878748
# 595        mlp        PGD  0.873647
# 601        mlp       PGDP  0.850576
# 607        mlp        PGD  0.958224
# 613        mlp       PGDP  0.873944
#       th       qualified_nodes embedding                    strategy  \
# 129  0.1  SharedPhenotypeEdges  Node2Vec                         all
# 133  0.1  SharedPhenotypeEdges  Node2Vec                      bottom
# 137  0.1  SharedPhenotypeEdges  Node2Vec                 bottom_rand
# 141  0.1  SharedPhenotypeEdges  Node2Vec                      shared
# 145  0.1  SharedPhenotypeEdges  Node2Vec                         top
# 149  0.1  SharedPhenotypeEdges  Node2Vec                  top_bottom
# 153  0.1  SharedPhenotypeEdges  Node2Vec             top_bottom_rand
# 157  0.1  SharedPhenotypeEdges  Node2Vec                    top_rand
# 268  0.1  SharedPhenotypeEdges  Node2Vec      bottom_k_deterministic
# 272  0.1  SharedPhenotypeEdges  Node2Vec             bottom_k_random
# 276  0.1  SharedPhenotypeEdges  Node2Vec  top_bottom_k_deterministic
# 279  0.1  SharedPhenotypeEdges  Node2Vec                       top_k
# 283  0.1  SharedPhenotypeEdges  Node2Vec                top_k_random
# 464  0.1  SharedPhenotypeEdges  Node2Vec                         all
# 470  0.1  SharedPhenotypeEdges  Node2Vec                         all
# 476  0.1  SharedPhenotypeEdges  Node2Vec                      bottom
# 482  0.1  SharedPhenotypeEdges  Node2Vec                      bottom
# 488  0.1  SharedPhenotypeEdges  Node2Vec      bottom_k_deterministic
# 494  0.1  SharedPhenotypeEdges  Node2Vec      bottom_k_deterministic
# 500  0.1  SharedPhenotypeEdges  Node2Vec             bottom_k_random
# 506  0.1  SharedPhenotypeEdges  Node2Vec             bottom_k_random
# 512  0.1  SharedPhenotypeEdges  Node2Vec                 bottom_rand
# 518  0.1  SharedPhenotypeEdges  Node2Vec                 bottom_rand
# 524  0.1  SharedPhenotypeEdges  Node2Vec                      shared
# 530  0.1  SharedPhenotypeEdges  Node2Vec                      shared
# ...
# 852  0.5  SharedGeneNotPhenotypeEdges  Node2Vec                         top
# 858  0.5  SharedGeneNotPhenotypeEdges  Node2Vec                  top_bottom
# 864  0.5  SharedGeneNotPhenotypeEdges  Node2Vec                  top_bottom
# 870  0.5  SharedGeneNotPhenotypeEdges  Node2Vec  top_bottom_k_deterministic
# 876  0.5  SharedGeneNotPhenotypeEdges  Node2Vec  top_bottom_k_deterministic
# 882  0.5  SharedGeneNotPhenotypeEdges  Node2Vec             top_bottom_rand
# 888  0.5  SharedGeneNotPhenotypeEdges  Node2Vec             top_bottom_rand
# 894  0.5  SharedGeneNotPhenotypeEdges  Node2Vec                       top_k
# 900  0.5  SharedGeneNotPhenotypeEdges  Node2Vec                       top_k
# 906  0.5  SharedGeneNotPhenotypeEdges  Node2Vec                top_k_random
# 912  0.5  SharedGeneNotPhenotypeEdges  Node2Vec                top_k_random
# 918  0.5  SharedGeneNotPhenotypeEdges  Node2Vec                    top_rand
# 924  0.5  SharedGeneNotPhenotypeEdges  Node2Vec                    top_rand
#
#     classifier graph_type       auc
# 67         mlp        PGD  0.896834
# 71         mlp        PGD   0.87929
# 75         mlp        PGD  0.913461
# 79         mlp        PGD  0.910846
# 83         mlp        PGD  0.903215
# 87         mlp        PGD  0.887703
# 91         mlp        PGD   0.89145
# 95         mlp        PGD   0.87731
# 233        mlp       PGDP  0.874768
# 237        mlp       PGDP  0.886452
# 243        mlp       PGDP  0.890922
# 247        mlp       PGDP  0.894034
# 774        mlp        PGD  0.912944
# 780        mlp       PGDP  0.919727
# 786        mlp        PGD  0.876573
# 792        mlp       PGDP  0.917375
# 798        mlp        PGD  0.869538
# 804        mlp       PGDP  0.892289
# 810        mlp        PGD  0.972659
# 816        mlp       PGDP  0.893644
# 822        mlp        PGD  0.917745
# 828        mlp       PGDP  0.876849
# 834        mlp        PGD  0.941318
# 840        mlp       PGDP   0.87528
# 846        mlp        PGD   0.89326
# 852        mlp       PGDP  0.895852
# 858        mlp        PGD  0.883862
# 864        mlp       PGDP  0.912821
# 870        mlp        PGD  0.838001
# 876        mlp       PGDP  0.886755
# 882        mlp        PGD  0.889673
# 888        mlp       PGDP  0.884844
# 894        mlp        PGD  0.904437
# 900        mlp       PGDP  0.868086
# 906        mlp        PGD  0.876762
# 912        mlp       PGDP  0.919449
# 918        mlp        PGD  0.868386
# 924        mlp       PGDP   0.85661
#       th             qualified_nodes embedding                    strategy  \
# 99   0.5  SharedGeneOrPhenotypeEdges  Node2Vec                         all
# 103  0.5  SharedGeneOrPhenotypeEdges  Node2Vec                      bottom
# 107  0.5  SharedGeneOrPhenotypeEdges  Node2Vec                 bottom_rand
# 111  0.5  SharedGeneOrPhenotypeEdges  Node2Vec                      shared
# 115  0.5  SharedGeneOrPhenotypeEdges  Node2Vec                         top
# 119  0.5  SharedGeneOrPhenotypeEdges  Node2Vec                  top_bottom
# 123  0.5  SharedGeneOrPhenotypeEdges  Node2Vec             top_bottom_rand
# 127  0.5  SharedGeneOrPhenotypeEdges  Node2Vec                    top_rand
# 251  0.5  SharedGeneOrPhenotypeEdges  Node2Vec      bottom_k_deterministic
# 255  0.5  SharedGeneOrPhenotypeEdges  Node2Vec             bottom_k_random
# 262  0.5  SharedGeneOrPhenotypeEdges  Node2Vec                       top_k
# 266  0.5  SharedGeneOrPhenotypeEdges  Node2Vec                top_k_random
# 775  0.5  SharedGeneOrPhenotypeEdges  Node2Vec                         all
# 781  0.5  SharedGeneOrPhenotypeEdges  Node2Vec                         all
# 787  0.5  SharedGeneOrPhenotypeEdges  Node2Vec                      bottom
# 793  0.5  SharedGeneOrPhenotypeEdges  Node2Vec                      bottom
# 799  0.5  SharedGeneOrPhenotypeEdges  Node2Vec      bottom_k_deterministic
# 805  0.5  SharedGeneOrPhenotypeEdges  Node2Vec      bottom_k_deterministic
# 811  0.5  SharedGeneOrPhenotypeEdges  Node2Vec             bottom_k_random
# 817  0.5  SharedGeneOrPhenotypeEdges  Node2Vec             bottom_k_random
# 823  0.5  SharedGeneOrPhenotypeEdges  Node2Vec                 bottom_rand
# 829  0.5  SharedGeneOrPhenotypeEdges  Node2Vec                 bottom_rand
# 835  0.5  SharedGeneOrPhenotypeEdges  Node2Vec                      shared
# 841  0.5  SharedGeneOrPhenotypeEdges  Node2Vec                      shared
# 847  0.5  SharedGeneOrPhenotypeEdges  Node2Vec                         top
# 853  0.5  SharedGeneOrPhenotypeEdges  Node2Vec                         top
# 859  0.5  SharedGeneOrPhenotypeEdges  Node2Vec                  top_bottom
# 865  0.5  SharedGeneOrPhenotypeEdges  Node2Vec                  top_bottom
# 871  0.5  SharedGeneOrPhenotypeEdges  Node2Vec  top_bottom_k_deterministic
# 877  0.5  SharedGeneOrPhenotypeEdges  Node2Vec  top_bottom_k_deterministic
# 883  0.5  SharedGeneOrPhenotypeEdges  Node2Vec             top_bottom_rand
# 889  0.5  SharedGeneOrPhenotypeEdges  Node2Vec             top_bottom_rand
# 895  0.5  SharedGeneOrPhenotypeEdges  Node2Vec                       top_k
# 901  0.5  SharedGeneOrPhenotypeEdges  Node2Vec                       top_k
# 907  0.5  SharedGeneOrPhenotypeEdges  Node2Vec                top_k_random
# 913  0.5  SharedGeneOrPhenotypeEdges  Node2Vec                top_k_random
# 919  0.5  SharedGeneOrPhenotypeEdges  Node2Vec                    top_rand
# 925  0.5  SharedGeneOrPhenotypeEdges  Node2Vec                    top_rand
#
#     classifier graph_type       auc
# 99         mlp        PGD  0.898534
# 103        mlp        PGD  0.885541
# 107        mlp        PGD  0.906796
# 111        mlp        PGD  0.892593
# 115        mlp        PGD  0.889511
# 119        mlp        PGD  0.908478
# 123        mlp        PGD  0.905481
# 127        mlp        PGD  0.883067
# 251        mlp       PGDP  0.888617
# 255        mlp       PGDP  0.896953
# 262        mlp       PGDP  0.886513
# 266        mlp       PGDP  0.906814
# 775        mlp        PGD  0.925629
# 781        mlp       PGDP  0.858656
# 787        mlp        PGD  0.898229
# 793        mlp       PGDP  0.867828
# 799        mlp        PGD  0.912458
# 805        mlp       PGDP  0.931741
# 811        mlp        PGD  0.957012
# 817        mlp       PGDP  0.911208
# 823        mlp        PGD   0.92065
# 829        mlp       PGDP  0.882029
# 835        mlp        PGD  0.891201
# 841        mlp       PGDP   0.91435
# 847        mlp        PGD  0.889314
# 853        mlp       PGDP  0.911896
# 859        mlp        PGD  0.903797
# 865        mlp       PGDP  0.911326
# 871        mlp        PGD   0.88493
# 877        mlp       PGDP   0.91373
# 883        mlp        PGD  0.891582
# 889        mlp       PGDP  0.898813
# 895        mlp        PGD  0.898471
# 901        mlp       PGDP  0.901441
# 907        mlp        PGD  0.876615
# 913        mlp       PGDP  0.886745
# 919        mlp        PGD  0.858268
# 925        mlp       PGDP  0.900779
#       th       qualified_nodes embedding                    strategy  \
# 131  0.5  SharedPhenotypeEdges  Node2Vec                         all
# 135  0.5  SharedPhenotypeEdges  Node2Vec                      bottom
# 139  0.5  SharedPhenotypeEdges  Node2Vec                 bottom_rand
# 143  0.5  SharedPhenotypeEdges  Node2Vec                      shared
# 147  0.5  SharedPhenotypeEdges  Node2Vec                         top
# 151  0.5  SharedPhenotypeEdges  Node2Vec                  top_bottom
# 155  0.5  SharedPhenotypeEdges  Node2Vec             top_bottom_rand
# 159  0.5  SharedPhenotypeEdges  Node2Vec                    top_rand
# 270  0.5  SharedPhenotypeEdges  Node2Vec      bottom_k_deterministic
# 274  0.5  SharedPhenotypeEdges  Node2Vec             bottom_k_random
# 281  0.5  SharedPhenotypeEdges  Node2Vec                       top_k
# 285  0.5  SharedPhenotypeEdges  Node2Vec                top_k_random
# 776  0.5  SharedPhenotypeEdges  Node2Vec                         all
# 782  0.5  SharedPhenotypeEdges  Node2Vec                         all
# 788  0.5  SharedPhenotypeEdges  Node2Vec                      bottom
# 794  0.5  SharedPhenotypeEdges  Node2Vec                      bottom
# 800  0.5  SharedPhenotypeEdges  Node2Vec      bottom_k_deterministic
# 806  0.5  SharedPhenotypeEdges  Node2Vec      bottom_k_deterministic
# 812  0.5  SharedPhenotypeEdges  Node2Vec             bottom_k_random
# 818  0.5  SharedPhenotypeEdges  Node2Vec             bottom_k_random
# 824  0.5  SharedPhenotypeEdges  Node2Vec                 bottom_rand
# 830  0.5  SharedPhenotypeEdges  Node2Vec                 bottom_rand
# 836  0.5  SharedPhenotypeEdges  Node2Vec                      shared
# 842  0.5  SharedPhenotypeEdges  Node2Vec                      shared
# 848  0.5  SharedPhenotypeEdges  Node2Vec                         top
# 854  0.5  SharedPhenotypeEdges  Node2Vec                         top
# 860  0.5  SharedPhenotypeEdges  Node2Vec                  top_bottom
# 866  0.5  SharedPhenotypeEdges  Node2Vec                  top_bottom
# 872  0.5  SharedPhenotypeEdges  Node2Vec  top_bottom_k_deterministic
# 878  0.5  SharedPhenotypeEdges  Node2Vec  top_bottom_k_deterministic
# 884  0.5  SharedPhenotypeEdges  Node2Vec             top_bottom_rand
# 890  0.5  SharedPhenotypeEdges  Node2Vec             top_bottom_rand
# 896  0.5  SharedPhenotypeEdges  Node2Vec                       top_k
# 902  0.5  SharedPhenotypeEdges  Node2Vec                       top_k
# 908  0.5  SharedPhenotypeEdges  Node2Vec                top_k_random
# 914  0.5  SharedPhenotypeEdges  Node2Vec                top_k_random
# 920  0.5  SharedPhenotypeEdges  Node2Vec                    top_rand
# 926  0.5  SharedPhenotypeEdges  Node2Vec                    top_rand
#
#     classifier graph_type       auc
# 131        mlp        PGD  0.895878
# 135        mlp        PGD  0.892796
# 139        mlp        PGD  0.902564
# 143        mlp        PGD  0.894896
# 147        mlp        PGD  0.903066
# 151        mlp        PGD  0.887001
# 155        mlp        PGD  0.901228
# 159        mlp        PGD  0.887161
# 270        mlp       PGDP  0.884366
# 274        mlp       PGDP  0.915271
# 281        mlp       PGDP    0.8919
# 285        mlp       PGDP  0.876101
# 776        mlp        PGD  0.912389
# 782        mlp       PGDP  0.888135
# 788        mlp        PGD  0.892525
# 794        mlp       PGDP  0.915703
# 800        mlp        PGD  0.890123
# 806        mlp       PGDP   0.91014
# 812        mlp        PGD  0.912117
# 818        mlp       PGDP  0.936646
# 824        mlp        PGD    0.8644
# 830        mlp       PGDP  0.909791
# 836        mlp        PGD  0.922208
# 842        mlp       PGDP   0.85107
# 848        mlp        PGD  0.892713
# 854        mlp       PGDP  0.909256
# 860        mlp        PGD  0.854973
# 866        mlp       PGDP  0.919039
# 872        mlp        PGD  0.889079
# 878        mlp       PGDP  0.872964
# 884        mlp        PGD  0.880939
# 890        mlp       PGDP  0.895834
# 896        mlp        PGD  0.932226
# 902        mlp       PGDP  0.882519
# 908        mlp        PGD   0.88095
# 914        mlp       PGDP  0.861454
# 920        mlp        PGD  0.881325
# 926        mlp       PGDP  0.926275
#       th              qualified_nodes embedding                    strategy  \
# 163  0.5  SharedPhenotypeNotGeneEdges  Node2Vec                         all
# 167  0.5  SharedPhenotypeNotGeneEdges  Node2Vec                      bottom
# 171  0.5  SharedPhenotypeNotGeneEdges  Node2Vec                 bottom_rand
# 175  0.5  SharedPhenotypeNotGeneEdges  Node2Vec                      shared
# 179  0.5  SharedPhenotypeNotGeneEdges  Node2Vec                         top
# 183  0.5  SharedPhenotypeNotGeneEdges  Node2Vec                  top_bottom
# 187  0.5  SharedPhenotypeNotGeneEdges  Node2Vec             top_bottom_rand
# 191  0.5  SharedPhenotypeNotGeneEdges  Node2Vec                    top_rand
# 289  0.5  SharedPhenotypeNotGeneEdges  Node2Vec      bottom_k_deterministic
# 293  0.5  SharedPhenotypeNotGeneEdges  Node2Vec             bottom_k_random
# 299  0.5  SharedPhenotypeNotGeneEdges  Node2Vec                       top_k
# 303  0.5  SharedPhenotypeNotGeneEdges  Node2Vec                top_k_random
# 777  0.5  SharedPhenotypeNotGeneEdges  Node2Vec                         all
# 783  0.5  SharedPhenotypeNotGeneEdges  Node2Vec                         all
# 789  0.5  SharedPhenotypeNotGeneEdges  Node2Vec                      bottom
# 795  0.5  SharedPhenotypeNotGeneEdges  Node2Vec                      bottom
# 801  0.5  SharedPhenotypeNotGeneEdges  Node2Vec      bottom_k_deterministic
# 807  0.5  SharedPhenotypeNotGeneEdges  Node2Vec      bottom_k_deterministic
# 813  0.5  SharedPhenotypeNotGeneEdges  Node2Vec             bottom_k_random
# 819  0.5  SharedPhenotypeNotGeneEdges  Node2Vec             bottom_k_random
# 825  0.5  SharedPhenotypeNotGeneEdges  Node2Vec                 bottom_rand
# 831  0.5  SharedPhenotypeNotGeneEdges  Node2Vec                 bottom_rand
# 837  0.5  SharedPhenotypeNotGeneEdges  Node2Vec                      shared
# 843  0.5  SharedPhenotypeNotGeneEdges  Node2Vec                      shared
# 849  0.5  SharedPhenotypeNotGeneEdges  Node2Vec                         top
# 855  0.5  SharedPhenotypeNotGeneEdges  Node2Vec                         top
# 861  0.5  SharedPhenotypeNotGeneEdges  Node2Vec                  top_bottom
# 867  0.5  SharedPhenotypeNotGeneEdges  Node2Vec                  top_bottom
# 873  0.5  SharedPhenotypeNotGeneEdges  Node2Vec  top_bottom_k_deterministic
# 879  0.5  SharedPhenotypeNotGeneEdges  Node2Vec  top_bottom_k_deterministic
# 885  0.5  SharedPhenotypeNotGeneEdges  Node2Vec             top_bottom_rand
# 891  0.5  SharedPhenotypeNotGeneEdges  Node2Vec             top_bottom_rand
# 897  0.5  SharedPhenotypeNotGeneEdges  Node2Vec                       top_k
# 903  0.5  SharedPhenotypeNotGeneEdges  Node2Vec                       top_k
# 909  0.5  SharedPhenotypeNotGeneEdges  Node2Vec                top_k_random
# 915  0.5  SharedPhenotypeNotGeneEdges  Node2Vec                top_k_random
# 921  0.5  SharedPhenotypeNotGeneEdges  Node2Vec                    top_rand
# 927  0.5  SharedPhenotypeNotGeneEdges  Node2Vec                    top_rand
#
#     classifier graph_type       auc
# 163        mlp        PGD  0.895021
# 167        mlp        PGD  0.874257
# 171        mlp        PGD  0.911992
# 175        mlp        PGD   0.90398
# 179        mlp        PGD  0.894308
# 183        mlp        PGD  0.906629
# 187        mlp        PGD  0.896053
# 191        mlp        PGD  0.914412
# 289        mlp       PGDP  0.904181
# 293        mlp       PGDP   0.89529
# 299        mlp       PGDP  0.908575
# 303        mlp       PGDP  0.865287
# 777        mlp        PGD  0.889847
# 783        mlp       PGDP   0.86454
# 789        mlp        PGD  0.881775
# 795        mlp       PGDP  0.912954
# 801        mlp        PGD   0.90154
# 807        mlp       PGDP   0.90133
# 813        mlp        PGD  0.877935
# 819        mlp       PGDP  0.885387
# 825        mlp        PGD  0.914323
# 831        mlp       PGDP    0.8597
# 837        mlp        PGD  0.892806
# 843        mlp       PGDP  0.843785
# 849        mlp        PGD  0.900351
# 855        mlp       PGDP  0.903363
# 861        mlp        PGD  0.922449
# 867        mlp       PGDP  0.872192
# 873        mlp        PGD  0.939146
# 879        mlp       PGDP  0.917795
# 885        mlp        PGD  0.913477
# 891        mlp       PGDP  0.882872
# 897        mlp        PGD  0.898294
# 903        mlp       PGDP  0.924315
# 909        mlp        PGD   0.93681
# 915        mlp       PGDP  0.852328
# 921        mlp        PGD  0.901209
# 927        mlp       PGDP  0.943442
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %%
def run_nemenyi_test(record, group, block):
    auc_from_groupby = {}
    record_groupby = record.groupby([group, block])
    # convert the following to function
    for key, item in record_groupby:
        if key[0] in get_unique_val(record, group):
            auc_from_groupby.setdefault(key[0], []).append((key, item['auc'].tolist()))
            print(item)
    #     print(key)

#     print(f'group = {group} and block = {block}')
    for i,val in auc_from_groupby.items():
        block_per_row = np.array([k[1] for k in val]).T
#         print(block_per_row)
        
        print(type(block_per_row))
        tmp_ary = None
        if len(block_per_row.shape) == 1: 
            pass
#             for xx in block_per_row:
#                 if tmp_ary is not None:
#                     print(f'tmp_ary = {tmp_ary}')
#                 print(len(xx))
#                 if len(xx) in [38, 16, 12]:
#                     print(i, val)

# %%
# check each one what combination that it does not have
block_list = ['th', 'qualified_nodes', 'strategy', 'embedding','graph_type']
for i in block_list:
    print(get_unique_val(test_all_record, i))
# Out:
# ['0.05' '0.1' '0.4' '0.5']
# ['SharedGeneAndPhenotypeEdges' 'SharedGeneEdges'
#  'SharedGeneNotPhenotypeEdges' 'SharedGeneOrPhenotypeEdges'
#  'SharedPhenotypeEdges' 'SharedPhenotypeNotGeneEdges']
# ['all' 'bottom' 'bottom_k_deterministic' 'bottom_k_random' 'bottom_rand'
#  'shared' 'top' 'top_bottom' 'top_bottom_k_deterministic'
#  'top_bottom_rand' 'top_k' 'top_k_random' 'top_rand']
# ['Node2Vec']
# ['PGD' 'PGDP']
