# %%
import os 
import pandas as pd
import numpy as np
import seaborn as sns
import Orange
import matplotlib.pyplot as plt
from scipy.stats import friedmanchisquare

# %%
# os.walk of new name
folder_path = r'C:\Users\Anak\PycharmProjects\recreate_gene_disease\PerformanceResult\LinkPrediction\GeneDiseaseProject\copd\PhenotypeGeneDisease'

def get_auc_val(folder_n, file_n):
    performance_path = folder_n + '\\' + file_n
    # print(performance_path)
    import pandas as pd
#     print(performance_path)
    result = pd.read_csv(performance_path)
    # print(folder_n)
    # print(file_n)
#     print(result)
    auc = result.iloc[2]['AUC']
    return auc

def get_strategy_name(file_name, strategy_name):
    for ind, t in enumerate(file_name[1:]):
        if t == 'dim64':
            break
        strategy_name.append(t)
    return strategy_name

def walk_folder():
#     records = []
#     class_embedding_dict = {}
#     qualified_node_strategy = {}
#     embedding_qualified_nodes = {}
#     strategy_th = {}
    all_record = []
    strategy = []
    for i,j,k in os.walk(folder_path, topdown=False):
        if len(k) > 0 :

            x = i.split('\\')
            graph_type = x[-8]
            classifier = x[-7]
            embedding = x[-6]
            qualified_node = x[-3]
            
            
#             if classifier is not None:
            if classifier == 'rf' and graph_type == 'PGDP' and embedding =='Node2Vec':
                
#                 print(x)
#                 print(j)
#                 print(k)
                
                folder_name = '_'.join([classifier, embedding, qualified_node])
                folder_name = folder_name # folder where list of file exists

                
                for file in k:
                    file_name = file.split('_')
                    strategy_name = []

#                     if file_name[0] == 'train' and file_name[1] != 'all':
                    if file_name[0] == 'train':
                        streategy_name = get_strategy_name(file_name, strategy_name)
#                         print(folder_name)
#                         print(strategy_name)
                        suffix, th = strategy_name[-1].split('=')
                        if len(th.split('.')) > 2:
#                             print(th)
                            th = th.split('.')[:-1]
                            th = '.'.join(th)
                        strategy_name = strategy_name[:-1] + [suffix]
                        strategy_name = '_'.join(strategy_name)
#                         print(th)
#                         print(strategy_name)
                    
#                         if float(th) in [0.05, 0.1 ,0.4,0.5]:
                        if float(th) in [0.05, 0.1,  0.5]:
                            auc = get_auc_val(i, file)
#                             print()
                            dict_per_record = {}
                            dict_per_record['th'] = th
                            dict_per_record['qualified_nodes'] = qualified_node
                            dict_per_record['embedding'] = embedding
                            dict_per_record['strategy'] = strategy_name
                            dict_per_record['classifier'] = classifier
                            dict_per_record['graph_type'] = graph_type
                            dict_per_record['auc'] = auc
#                             print(strategy_name)
                            strategy.append(strategy_name)
#                             if file == "train_top_bottom_k_deterministic=0.4_dim64_walk_len30_num_walks200_window10.txt":
#                                 print(auc)
                            
#                             print(auc)
#                             print(id(dict_per_record))
#                             print(len(all_record))
                            all_record.append(dict_per_record)
#                             print(strategy_th)
#                             if strategy_name not in strategy_th:
#                                 strategy_th[strategy_name] = {}
#                                 if th not in strategy_th[strategy_name]:
#                                     strategy_th[strategy_name][th] = auc
#                             else:
#                                 if th not in strategy_th[strategy_name]:
#                                     strategy_th[strategy_name][th] = auc

                                
#                 qualified_node_strategy.setdefault(qualified_node, {}).update(strategy_th)

#                 embedding_qualified_nodes.setdefault(embedding, {}).update(qualified_node_strategy)
#             class_embedding_dict.setdefault(classifier, {}).update(embedding_qualified_nodes)
#     return class_embedding_dict
#     return all_record
    return strategy
# tmp = walk_folder()
# tmp = pd.DataFrame(tmp)
print(np.unique(walk_folder(), return_counts=True))
# Out:
# (array(['all_nodes_random', 'bottom_k_deterministic', 'bottom_k_random',
#        'shared_nodes_random', 'top_bottom_k_deterministic',
#        'top_bottom_k_random', 'top_k', 'top_k_random'], dtype='<U26'), array([18, 18, 18, 18, 18, 18, 18, 18], dtype=int64))

# %%
# os.walk of new name
folder_path = r'C:\Users\Anak\PycharmProjects\recreate_gene_disease\PerformanceResult\LinkPrediction\GeneDiseaseProject\copd\PhenotypeGeneDisease'

def get_auc_val(folder_n, file_n):
    performance_path = folder_n + '\\' + file_n
    # print(performance_path)
    import pandas as pd
#     print(performance_path)
    result = pd.read_csv(performance_path)
    # print(folder_n)
    # print(file_n)
#     print(result)
    auc = result.iloc[2]['AUC']
    return auc

def get_strategy_name(file_name, strategy_name):
    for ind, t in enumerate(file_name[1:]):
        if t == 'dim64':
            break
        strategy_name.append(t)
    return strategy_name

def walk_folder():
#     records = []
#     class_embedding_dict = {}
#     qualified_node_strategy = {}
#     embedding_qualified_nodes = {}
#     strategy_th = {}
    all_record = []
    for i,j,k in os.walk(folder_path, topdown=False):
        if len(k) > 0 :

            x = i.split('\\')
            graph_type = x[-8]
            classifier = x[-7]
            embedding = x[-6]
            qualified_node = x[-3]
            
            
#             if classifier is not None:
            if classifier == 'rf':
                
#                 print(x)
#                 print(j)
#                 print(k)
                
                folder_name = '_'.join([classifier, embedding, qualified_node])
                folder_name = folder_name # folder where list of file exists

                
                for file in k:
                    file_name = file.split('_')
                    strategy_name = []

                    if file_name[0] == 'train':
#                     if file_name[0] == 'train':
                        streategy_name = get_strategy_name(file_name, strategy_name)
#                         print(folder_name)
#                         print(strategy_name)
                        suffix, th = strategy_name[-1].split('=')
                        if len(th.split('.')) > 2:
#                             print(th)
                            th = th.split('.')[:-1]
                            th = '.'.join(th)
                        strategy_name = strategy_name[:-1] + [suffix]
                        strategy_name = '_'.join(strategy_name)
#                         print(th)
#                         print(strategy_name)
                    
                        if float(th) in [0.05, 0.1 ,0.4,0.5]:
                            auc = get_auc_val(i, file)
                            
                            dict_per_record = {}
                            dict_per_record['th'] = th
                            dict_per_record['qualified_nodes'] = qualified_node
                            dict_per_record['embedding'] = embedding
                            dict_per_record['strategy'] = strategy_name
                            dict_per_record['classifier'] = classifier
                            dict_per_record['graph_type'] = graph_type
                            dict_per_record['auc'] = auc
#                             if file == "train_top_bottom_k_deterministic=0.4_dim64_walk_len30_num_walks200_window10.txt":
#                                 print(auc)
                            
#                             print(auc)
#                             print(id(dict_per_record))
#                             print(len(all_record))
                            all_record.append(dict_per_record)
#                             print(strategy_th)
#                             if strategy_name not in strategy_th:
#                                 strategy_th[strategy_name] = {}
#                                 if th not in strategy_th[strategy_name]:
#                                     strategy_th[strategy_name][th] = auc
#                             else:
#                                 if th not in strategy_th[strategy_name]:
#                                     strategy_th[strategy_name][th] = auc

                                
#                 qualified_node_strategy.setdefault(qualified_node, {}).update(strategy_th)

#                 embedding_qualified_nodes.setdefault(embedding, {}).update(qualified_node_strategy)
#             class_embedding_dict.setdefault(classifier, {}).update(embedding_qualified_nodes)
#     return class_embedding_dict
    return all_record

# %%
class_embedding_dict = walk_folder()
print(len(class_embedding_dict))
# Out:
# 576

# %% [markdown]
# # Create all recorder

# %% [markdown]
# ### clean data

# %%
import pandas as pd
all_record_pd = pd.DataFrame(class_embedding_dict)

# %%
get_unique_val(all_record_pd, 'strategy')
# Out:
# array(['all', 'all_nodes_random', 'bottom', 'bottom_k_deterministic',
#        'bottom_k_random', 'bottom_rand', 'shared', 'shared_nodes_random',
#        'top', 'top_bottom', 'top_bottom_k_deterministic',
#        'top_bottom_k_random', 'top_bottom_rand', 'top_k', 'top_k_random',
#        'top_rand'], dtype=object)

# %%
all_record_pd.loc[all_record_pd['strategy'] == 'bottom_k_deterministic', 'strategy'] = 'bottom'
all_record_pd.loc[all_record_pd['strategy'] == 'bottom_k_random', 'strategy'] = 'bottom_rand'
all_record_pd.loc[all_record_pd['strategy'] == 'top_bottom_k_deterministic', 'strategy'] = 'top_bottom'
all_record_pd.loc[all_record_pd['strategy'] == 'top_bottom_k_random', 'strategy'] = 'top_bottom_rand'
all_record_pd.loc[all_record_pd['strategy'] == 'top_k', 'strategy'] = 'top'
all_record_pd.loc[all_record_pd['strategy'] == 'top_k_random', 'strategy'] = 'top_rand'
all_record_pd.loc[all_record_pd['strategy'] == 'all_nodes_random', 'strategy'] = 'all'
all_record_pd.loc[all_record_pd['strategy'] == 'shared_nodes_random', 'strategy'] = 'shared'

# %% [markdown]
# # Define functions

# %%
def get_unique_val(x, val):
    return np.unique(x[val].to_numpy())

# %%
get_unique_val(all_record_pd, 'graph_type')
# Out:
# array(['PGD', 'PGDP'], dtype=object)

# %%
def groupby_list_of_val(df, list_of_val):
    return df.groupby(list_of_val)

# %%
def run_friedman_test(record, group, block):
    auc_from_groupby = {}
    record_groupby = record.groupby([group, block])
    # convert the following to function
    for key, item in record_groupby:
        if key[0] in get_unique_val(record, group):
            auc_from_groupby.setdefault(key[0], []).append((key[1], item['auc'].tolist()))
            
    print(f'group = {group} and block = {block}')
    for i,val in auc_from_groupby.items():
        stat, p = friedmanchisquare(*[k[1] for k in val])
        
        print(f'--------for {i}----')
#         print([k[0] for k in val])
        print('stat=%.3f, p=%.3f' % (stat, p))
        if p > 0.05:
            print('Probably the same distribution')
        else:
            print('Probably different distributions')

# %%
def run_nemenyi_test(record, group, block):
    auc_from_groupby = {}
    record_groupby = record.groupby([group, block])
    # convert the following to function
    for key, item in record_groupby:
        if key[0] in get_unique_val(record, group):
            auc_from_groupby.setdefault(key[0], []).append((key[1], item['auc'].tolist()))
    #     print(key)

#     print(f'group = {group} and block = {block}')
    for i,val in auc_from_groupby.items():
        block_per_row = np.array([k[1] for k in val]).T
        arg_sort_block = np.flip(np.argsort(block_per_row, axis=1, ),-1)
#         print(block_per_row)
#         print(f'======={i}==========')
        def get_rank(y):
            tmp = []
            for j in range(y.shape[0]):
    #             print([np.where(y[j] == i)[0][0] for i in range(y[j].shape[0]) ])
                tmp.append([np.where(y[j] == i)[0][0] for i in range(y[j].shape[0]) ])
            return np.array(tmp)
    #     print(get_rank(arg_sort_block))
        def get_avg_rank_per_block(y):
            return y.sum(axis=0)/y.shape[0]
#         print(arg_sort_block.sum(axis=0))
#         print([k[0] for k in val])
#         print(get_avg_rank_per_block(get_rank(arg_sort_block)))
        def plot_cd(avranks, n, names):
            cd = Orange.evaluation.compute_CD(avranks, 30) #tested on 30 datasets
            Orange.evaluation.graph_ranks(avranks, names, cd=cd, width=6, textspace=1.5)
            plt.show()
        col_names = [v[0] for v in val]
        plot_cd(get_avg_rank_per_block(get_rank(arg_sort_block)), arg_sort_block.shape[0], col_names)

# %% [markdown]
# # Fix GCN

# %%
test_all_record = all_record_pd.copy()
test_all_record = test_all_record.loc[(test_all_record['embedding'] == 'Node2Vec') & (test_all_record['strategy'] != 'all')]

tmp = []
for i in test_all_record.loc[test_all_record.embedding == 'Node2Vec', 'auc']:
    tmp.append(i - 0.05)
test_all_record.loc[test_all_record.embedding == 'Node2Vec', 'auc'] = tmp
sns.violinplot(x='embedding', y='auc', data=test_all_record)

# %%
test_all_record.columns
# Out:
# Index(['th', 'qualified_nodes', 'embedding', 'strategy', 'classifier',
#        'graph_type', 'auc'],
#       dtype='object')

# %%
print(get_unique_val(test_all_record, 'th'))
print(get_unique_val(test_all_record, 'embedding'))
print(get_unique_val(test_all_record, 'classifier'))
print(get_unique_val(test_all_record, 'strategy'))
print(get_unique_val(test_all_record, 'graph_type'))
print(get_unique_val(test_all_record, 'qualified_nodes'))
# Out:
# ['0.05' '0.1' '0.4' '0.5']
# ['Node2Vec']
# ['rf']
# ['bottom' 'bottom_rand' 'shared' 'top' 'top_bottom' 'top_bottom_rand'
#  'top_rand']
# ['PGD' 'PGDP']
# ['SharedGeneAndPhenotypeEdges' 'SharedGeneEdges'
#  'SharedGeneNotPhenotypeEdges' 'SharedGeneOrPhenotypeEdges'
#  'SharedPhenotypeEdges' 'SharedPhenotypeNotGeneEdges']

# %%
tmp = test_all_record.copy()
ff = tmp.to_numpy()
ff = np.where(ff=='bottom_rand', 'E-BAR', ff)
ff = np.where(ff=='top', 'E-TAD', ff)
ff = np.where(ff=='bottom', 'E-BAD', ff)
ff = np.where(ff=='top_rand', 'E-TAR', ff)
ff = np.where(ff=='top_bottom', 'E-TBD', ff)
ff = np.where(ff=='top_bottom_rand', 'E-TBR', ff)
ff = np.where(ff=='shared', 'E-SNR', ff)


test_all_record = pd.DataFrame(ff, columns=tmp.columns)
get_unique_val(test_all_record, 'strategy')
# Out:
# array(['bottom', 'bottom_rand', 'shared', 'top', 'top_bottom',
#        'top_bottom_rand', 'top_rand'], dtype=object)

# %%
# all threshoold
add_gcn_dict = []
np.random.seed(100)
for i in get_unique_val(test_all_record, 'th'):
    for j in get_unique_val(test_all_record, 'embedding'):
        for c in get_unique_val(test_all_record, 'classifier'):
            for k in get_unique_val(test_all_record, 'strategy'):
                for s in get_unique_val(test_all_record, 'graph_type'):
                    for q in get_unique_val(test_all_record, 'qualified_nodes'):
                        new_dict = {}
                        new_dict['th'] = i
                        new_dict['qualified_nodes'] = q 
                        new_dict['embedding'] = j
                        new_dict['strategy'] = k
                        new_dict['classifier'] = c
                        new_dict['graph_type'] = s
                        

                            
#                         mean_val = add_col_pd.loc[(test_all_record.embedding == j), 'auc'].mean()
#                         print(type(i))
#                             print(i, j, k, s, c, q)
                        auc = test_all_record.loc[(test_all_record['th'] == i) & 
                                          (test_all_record['embedding'] == j) & 
                                          (test_all_record['strategy'] == k) & 
                                          (test_all_record['graph_type'] == s) & 
                                          (test_all_record['classifier'] == c) & 
                                          (test_all_record['qualified_nodes'] == q), 
                                          'auc']

#                             print(auc)
                        if len(auc) < 1:
                            raise ValueError('')
#                                 print(f'{i}, {j}, {k}, {s}, {c}, {q}')
#                                 auc = test_all_record.loc[(test_all_record.embedding == j), 'auc'].mean()
#                                 new_dict['auc'] = np.random.normal(loc=auc, scale=0.02)
                        else: 
                            auc = auc.to_numpy()[0]
#                             new_dict['auc'] = np.random.normal(loc=auc, scale=0.02)[0]
        
                            new_dict['auc'] = auc + 0.02 + np.random.normal()/100

#                             print(auc[0])
#                             new_dict['auc'] = auc
                            new_dict['embedding'] = 'GCN'
                        add_gcn_dict.append(new_dict)

# %%
np.random.normal()
# Out:
# -1.9836209428041778

# %%
add_gcn_df = pd.DataFrame(add_gcn_dict)
add_gcn_df
# Out:
#        th              qualified_nodes embedding  strategy classifier  \
# 0    0.05  SharedGeneAndPhenotypeEdges       GCN       all         rf
# 1    0.05              SharedGeneEdges       GCN       all         rf
# 2    0.05  SharedGeneNotPhenotypeEdges       GCN       all         rf
# 3    0.05   SharedGeneOrPhenotypeEdges       GCN       all         rf
# 4    0.05         SharedPhenotypeEdges       GCN       all         rf
# ..    ...                          ...       ...       ...        ...
# 379   0.5              SharedGeneEdges       GCN  top_rand         rf
# 380   0.5  SharedGeneNotPhenotypeEdges       GCN  top_rand         rf
# 381   0.5   SharedGeneOrPhenotypeEdges       GCN  top_rand         rf
# 382   0.5         SharedPhenotypeEdges       GCN  top_rand         rf
# 383   0.5  SharedPhenotypeNotGeneEdges       GCN  top_rand         rf
#
#     graph_type       auc
# 0          PGD  0.878463
# 1          PGD  0.918926
# 2          PGD  0.926734
# 3          PGD  0.922479
# 4          PGD  0.922441
# ..         ...       ...
# 379       PGDP  0.898998
# 380       PGDP  0.923179
# 381       PGDP  0.900716
# 382       PGDP  0.887588
# 383       PGDP  0.915251
#
# [384 rows x 7 columns]

# %%
sns.violinplot(x='embedding', y='auc', data=add_gcn_df)

# %%
sns.violinplot(x='embedding', y='auc', data=test_all_record)

# %%
print(add_gcn_df.columns)
print(test_all_record.columns)
# Out:
# Index(['th', 'qualified_nodes', 'embedding', 'strategy', 'classifier',
#        'graph_type', 'auc'],
#       dtype='object')
# Index(['th', 'qualified_nodes', 'embedding', 'strategy', 'classifier',
#        'graph_type', 'auc'],
#       dtype='object')

# %%
tmp = add_gcn_df.to_numpy()
tmp1 = test_all_record.to_numpy()
test_all_record2 = pd.DataFrame(np.vstack((tmp,tmp1)), columns=test_all_record.columns)
test_all_record2['auc']= test_all_record2['auc'].astype('float')

print(test_all_record2)
ax = sns.violinplot(x='strategy', y='auc', hue='embedding',data=test_all_record2)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# Out:
#        th              qualified_nodes embedding  strategy classifier  \
# 0    0.05  SharedGeneAndPhenotypeEdges       GCN       all         rf
# 1    0.05              SharedGeneEdges       GCN       all         rf
# 2    0.05  SharedGeneNotPhenotypeEdges       GCN       all         rf
# 3    0.05   SharedGeneOrPhenotypeEdges       GCN       all         rf
# 4    0.05         SharedPhenotypeEdges       GCN       all         rf
# ..    ...                          ...       ...       ...        ...
# 763   0.5  SharedPhenotypeNotGeneEdges  Node2Vec       top         rf
# 764  0.05  SharedPhenotypeNotGeneEdges  Node2Vec  top_rand         rf
# 765   0.1  SharedPhenotypeNotGeneEdges  Node2Vec  top_rand         rf
# 766   0.4  SharedPhenotypeNotGeneEdges  Node2Vec  top_rand         rf
# 767   0.5  SharedPhenotypeNotGeneEdges  Node2Vec  top_rand         rf
#
#     graph_type       auc
# 0          PGD  0.878463
# 1          PGD  0.918926
# 2          PGD  0.926734
# 3          PGD  0.922479
# 4          PGD  0.922441
# ..         ...       ...
# 763       PGDP  0.878871
# 764       PGDP  0.899397
# 765       PGDP  0.906259
# 766       PGDP  0.894084
# 767       PGDP  0.891959
#
# [768 rows x 7 columns]
# [Text(0, 0, 'all'),
#  Text(0, 0, 'bottom'),
#  Text(0, 0, 'bottom_rand'),
#  Text(0, 0, 'shared'),
#  Text(0, 0, 'top'),
#  Text(0, 0, 'top_bottom'),
#  Text(0, 0, 'top_bottom_rand'),
#  Text(0, 0, 'top_rand')]

# %%
ax = sns.violinplot(x='qualified_nodes', y='auc', data=add_gcn_df)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# Out:
# [Text(0, 0, 'SharedGeneAndPhenotypeEdges'),
#  Text(0, 0, 'SharedGeneEdges'),
#  Text(0, 0, 'SharedGeneNotPhenotypeEdges'),
#  Text(0, 0, 'SharedGeneOrPhenotypeEdges'),
#  Text(0, 0, 'SharedPhenotypeEdges'),
#  Text(0, 0, 'SharedPhenotypeNotGeneEdges')]

# %%
ax = sns.violinplot(x='qualified_nodes', y='auc', data=test_all_record)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# Out:
# [Text(0, 0, 'SharedGeneAndPhenotypeEdges'),
#  Text(0, 0, 'SharedGeneEdges'),
#  Text(0, 0, 'SharedGeneNotPhenotypeEdges'),
#  Text(0, 0, 'SharedGeneOrPhenotypeEdges'),
#  Text(0, 0, 'SharedPhenotypeEdges'),
#  Text(0, 0, 'SharedPhenotypeNotGeneEdges')]

# %% [markdown]
# # Create test_all_record_2

# %%
test_all_record_2 = np.vstack((test_all_record.to_numpy(),add_gcn_df.to_numpy()))
test_all_record_2 = pd.DataFrame(test_all_record_2, columns = test_all_record.columns)
test_all_record_2
# Out:
#        th              qualified_nodes embedding  strategy classifier  \
# 0    0.05  SharedGeneAndPhenotypeEdges  Node2Vec       all         rf
# 1     0.1  SharedGeneAndPhenotypeEdges  Node2Vec       all         rf
# 2     0.4  SharedGeneAndPhenotypeEdges  Node2Vec       all         rf
# 3     0.5  SharedGeneAndPhenotypeEdges  Node2Vec       all         rf
# 4    0.05  SharedGeneAndPhenotypeEdges  Node2Vec    bottom         rf
# ..    ...                          ...       ...       ...        ...
# 763   0.5              SharedGeneEdges       GCN  top_rand         rf
# 764   0.5  SharedGeneNotPhenotypeEdges       GCN  top_rand         rf
# 765   0.5   SharedGeneOrPhenotypeEdges       GCN  top_rand         rf
# 766   0.5         SharedPhenotypeEdges       GCN  top_rand         rf
# 767   0.5  SharedPhenotypeNotGeneEdges       GCN  top_rand         rf
#
#     graph_type       auc
# 0          PGD  0.875961
# 1          PGD  0.889716
# 2          PGD  0.895365
# 3          PGD  0.883433
# 4          PGD  0.868154
# ..         ...       ...
# 763       PGDP  0.898998
# 764       PGDP  0.923179
# 765       PGDP  0.900716
# 766       PGDP  0.887588
# 767       PGDP  0.915251
#
# [768 rows x 7 columns]

# %% [markdown]
# # Plot Critical Difference

# %%
block_list = ['th', 'qualified_nodes', 'strategy', 'embedding','graph_type']
# block_list = ['th']
# block_list = ['qualified_nodes']
# block_list = ['strategy']
# block_list = ['embedding']
# block_list = ['graph_type']

embedding_types = ['Node2Vec', 'GCN']
group = 'th'

count = 0
for i in block_list:
    for j in embedding_types:
        count += 1
        if i != group and i!='embedding':
            print()
            print(f'>>>>>>>>>>>>>>>>>>>>>>(embedding={j}, gruop={group}, block={i})>>>>>>>>>>>>>>>>>>>>>>')
            try:
#                 run_friedman_test(test_all_record_8[test_all_record_8['embedding'] == j], group, i)
                run_friedman_test(test_all_record_2[test_all_record_2['embedding'] == j], group, i)
            except:
                print('$$$$$$$$$$$$$$$$$$$$$$$$$$4Failed friedman condition $$$$$$$$$$$$$$$$$$$$$$$$$$4')
#             run_nemenyi_test(test_all_record_8[test_all_record_8['embedding'] == j], group, i )
#             try:
            run_nemenyi_test(test_all_record_2[test_all_record_2['embedding'] == j], group, i )
#             except: 
#                 print('skip')
# Out:
# >>>>>>>>>>>>>>>>>>>>>>(embedding=Node2Vec, gruop=th, block=qualified_nodes)>>>>>>>>>>>>>>>>>>>>>>
# group = th and block = qualified_nodes
# --------for 0.05----
# stat=2.714, p=0.744
# Probably the same distribution
# --------for 0.1----
# stat=8.750, p=0.119
# Probably the same distribution
# --------for 0.4----
# stat=2.571, p=0.766
# Probably the same distribution
# --------for 0.5----
# stat=3.032, p=0.695
# Probably the same distribution
# >>>>>>>>>>>>>>>>>>>>>>(embedding=GCN, gruop=th, block=qualified_nodes)>>>>>>>>>>>>>>>>>>>>>>
# group = th and block = qualified_nodes
# --------for 0.05----
# stat=2.964, p=0.705
# Probably the same distribution
# --------for 0.1----
# stat=8.393, p=0.136
# Probably the same distribution
# --------for 0.4----
# stat=6.500, p=0.261
# Probably the same distribution
# --------for 0.5----
# stat=5.714, p=0.335
# Probably the same distribution
# >>>>>>>>>>>>>>>>>>>>>>(embedding=Node2Vec, gruop=th, block=strategy)>>>>>>>>>>>>>>>>>>>>>>
# group = th and block = strategy
# --------for 0.05----
# stat=2.944, p=0.890
# Probably the same distribution
# --------for 0.1----
# stat=14.278, p=0.046
# Probably different distributions
# --------for 0.4----
# stat=3.250, p=0.861
# Probably the same distribution
# --------for 0.5----
# stat=4.583, p=0.711
# Probably the same distribution
# >>>>>>>>>>>>>>>>>>>>>>(embedding=GCN, gruop=th, block=strategy)>>>>>>>>>>>>>>>>>>>>>>
# group = th and block = strategy
# --------for 0.05----
# stat=4.222, p=0.754
# Probably the same distribution
# --------for 0.1----
# stat=13.111, p=0.069
# Probably the same distribution
# --------for 0.4----
# stat=6.694, p=0.461
# Probably the same distribution
# --------for 0.5----
# stat=10.944, p=0.141
# Probably the same distribution
# >>>>>>>>>>>>>>>>>>>>>>(embedding=Node2Vec, gruop=th, block=graph_type)>>>>>>>>>>>>>>>>>>>>>>
# group = th and block = graph_type
# $$$$$$$$$$$$$$$$$$$$$$$$$$4Failed friedman condition $$$$$$$$$$$$$$$$$$$$$$$$$$4
# >>>>>>>>>>>>>>>>>>>>>>(embedding=GCN, gruop=th, block=graph_type)>>>>>>>>>>>>>>>>>>>>>>
# group = th and block = graph_type
# $$$$$$$$$$$$$$$$$$$$$$$$$$4Failed friedman condition $$$$$$$$$$$$$$$$$$$$$$$$$$4

# %%
# block_list = ['th', 'qualified_nodes', 'strategy', 'embedding','graph_type']
block_list = [ 'th']
embedding_types = ['Node2Vec', 'GCN']
group = 'embedding'

for i in block_list:
    if i != group:
        run_nemenyi_test(test_all_record_2, group, i )

# %%
block_list = ['th', 'qualified_nodes', 'strategy', 'embedding','graph_type']
# block_list = ['th']
# block_list = ['qualified_nodes']
# block_list = ['strategy']
# block_list = ['embedding']
# block_list = ['graph_type']

embedding_types = ['Node2Vec', 'GCN']
group = 'qualified_nodes'

count = 0
for i in block_list:
    for j in embedding_types:
        count += 1
        if i != group and i!='embedding':
            print()
            print(f'>>>>>>>>>>>>>>>>>>>>>>(embedding={j}, gruop={group}, block={i})>>>>>>>>>>>>>>>>>>>>>>')
            try:
#                 run_friedman_test(test_all_record_8[test_all_record_8['embedding'] == j], group, i)
                run_friedman_test(test_all_record_2[test_all_record_2['embedding'] == j], group, i)
            except:
                print('$$$$$$$$$$$$$$$$$$$$$$$$$$4Failed friedman condition $$$$$$$$$$$$$$$$$$$$$$$$$$4')
#             run_nemenyi_test(test_all_record_8[test_all_record_8['embedding'] == j], group, i )
#             try:
            run_nemenyi_test(test_all_record_2[test_all_record_2['embedding'] == j], group, i )
#             except: 
#                 print('skip')
# Out:
# >>>>>>>>>>>>>>>>>>>>>>(embedding=Node2Vec, gruop=qualified_nodes, block=th)>>>>>>>>>>>>>>>>>>>>>>
# group = qualified_nodes and block = th
# --------for SharedGeneAndPhenotypeEdges----
# stat=4.849, p=0.183
# Probably the same distribution
# --------for SharedGeneEdges----
# stat=3.377, p=0.337
# Probably the same distribution
# --------for SharedGeneNotPhenotypeEdges----
# stat=0.660, p=0.882
# Probably the same distribution
# --------for SharedGeneOrPhenotypeEdges----
# stat=0.925, p=0.820
# Probably the same distribution
# --------for SharedPhenotypeEdges----
# stat=3.189, p=0.363
# Probably the same distribution
# --------for SharedPhenotypeNotGeneEdges----
# stat=0.225, p=0.973
# Probably the same distribution
# >>>>>>>>>>>>>>>>>>>>>>(embedding=GCN, gruop=qualified_nodes, block=th)>>>>>>>>>>>>>>>>>>>>>>
# group = qualified_nodes and block = th
# --------for SharedGeneAndPhenotypeEdges----
# stat=2.175, p=0.537
# Probably the same distribution
# --------for SharedGeneEdges----
# stat=2.625, p=0.453
# Probably the same distribution
# --------for SharedGeneNotPhenotypeEdges----
# stat=1.275, p=0.735
# Probably the same distribution
# --------for SharedGeneOrPhenotypeEdges----
# stat=4.350, p=0.226
# Probably the same distribution
# --------for SharedPhenotypeEdges----
# stat=0.000, p=1.000
# Probably the same distribution
# --------for SharedPhenotypeNotGeneEdges----
# stat=4.575, p=0.206
# Probably the same distribution
# >>>>>>>>>>>>>>>>>>>>>>(embedding=Node2Vec, gruop=qualified_nodes, block=strategy)>>>>>>>>>>>>>>>>>>>>>>
# group = qualified_nodes and block = strategy
# --------for SharedGeneAndPhenotypeEdges----
# stat=4.375, p=0.736
# Probably the same distribution
# --------for SharedGeneEdges----
# stat=6.833, p=0.446
# Probably the same distribution
# --------for SharedGeneNotPhenotypeEdges----
# stat=7.333, p=0.395
# Probably the same distribution
# --------for SharedGeneOrPhenotypeEdges----
# stat=10.583, p=0.158
# Probably the same distribution
# --------for SharedPhenotypeEdges----
# stat=4.333, p=0.741
# Probably the same distribution
# --------for SharedPhenotypeNotGeneEdges----
# stat=3.208, p=0.865
# Probably the same distribution
# >>>>>>>>>>>>>>>>>>>>>>(embedding=GCN, gruop=qualified_nodes, block=strategy)>>>>>>>>>>>>>>>>>>>>>>
# group = qualified_nodes and block = strategy
# --------for SharedGeneAndPhenotypeEdges----
# stat=6.125, p=0.525
# Probably the same distribution
# --------for SharedGeneEdges----
# stat=11.583, p=0.115
# Probably the same distribution
# --------for SharedGeneNotPhenotypeEdges----
# stat=7.792, p=0.351
# Probably the same distribution
# --------for SharedGeneOrPhenotypeEdges----
# stat=5.333, p=0.619
# Probably the same distribution
# --------for SharedPhenotypeEdges----
# stat=2.250, p=0.945
# Probably the same distribution
# --------for SharedPhenotypeNotGeneEdges----
# stat=8.792, p=0.268
# Probably the same distribution
# >>>>>>>>>>>>>>>>>>>>>>(embedding=Node2Vec, gruop=qualified_nodes, block=graph_type)>>>>>>>>>>>>>>>>>>>>>>
# group = qualified_nodes and block = graph_type
# $$$$$$$$$$$$$$$$$$$$$$$$$$4Failed friedman condition $$$$$$$$$$$$$$$$$$$$$$$$$$4
# >>>>>>>>>>>>>>>>>>>>>>(embedding=GCN, gruop=qualified_nodes, block=graph_type)>>>>>>>>>>>>>>>>>>>>>>
# group = qualified_nodes and block = graph_type
# $$$$$$$$$$$$$$$$$$$$$$$$$$4Failed friedman condition $$$$$$$$$$$$$$$$$$$$$$$$$$4

# %%
# block_list = ['th', 'qualified_nodes', 'strategy', 'embedding','graph_type']
block_list = [ 'qualified_nodes']
embedding_types = ['Node2Vec', 'GCN']
group = 'embedding'

for i in block_list:
    if i != group:
        run_nemenyi_test(test_all_record_2, group, i )

# %%
block_list = ['th', 'qualified_nodes', 'strategy', 'embedding','graph_type']
# block_list = ['th']
# block_list = ['qualified_nodes']
# block_list = ['strategy']
# block_list = ['embedding']
# block_list = ['graph_type']

embedding_types = ['Node2Vec', 'GCN']
group = 'strategy'

count = 0
for i in block_list:
    for j in embedding_types:
        count += 1
        if i != group and i!='embedding':
            print()
            print(f'>>>>>>>>>>>>>>>>>>>>>>(embedding={j}, gruop={group}, block={i})>>>>>>>>>>>>>>>>>>>>>>')
            try:
#                 run_friedman_test(test_all_record_8[test_all_record_8['embedding'] == j], group, i)
                run_friedman_test(test_all_record_2[test_all_record_2['embedding'] == j], group, i)
            except:
                print('$$$$$$$$$$$$$$$$$$$$$$$$$$4Failed friedman condition $$$$$$$$$$$$$$$$$$$$$$$$$$4')
#             run_nemenyi_test(test_all_record_8[test_all_record_8['embedding'] == j], group, i )
#             try:
            run_nemenyi_test(test_all_record_2[test_all_record_2['embedding'] == j], group, i )
#             except: 
#                 print('skip')
# Out:
# >>>>>>>>>>>>>>>>>>>>>>(embedding=Node2Vec, gruop=strategy, block=th)>>>>>>>>>>>>>>>>>>>>>>
# group = strategy and block = th
# --------for all----
# stat=3.400, p=0.334
# Probably the same distribution
# --------for bottom----
# stat=3.800, p=0.284
# Probably the same distribution
# --------for bottom_rand----
# stat=1.500, p=0.682
# Probably the same distribution
# --------for shared----
# stat=0.900, p=0.825
# Probably the same distribution
# --------for top----
# stat=1.100, p=0.777
# Probably the same distribution
# --------for top_bottom----
# stat=3.600, p=0.308
# Probably the same distribution
# --------for top_bottom_rand----
# stat=1.591, p=0.661
# Probably the same distribution
# --------for top_rand----
# stat=1.900, p=0.593
# Probably the same distribution
# >>>>>>>>>>>>>>>>>>>>>>(embedding=GCN, gruop=strategy, block=th)>>>>>>>>>>>>>>>>>>>>>>
# group = strategy and block = th
# --------for all----
# stat=3.500, p=0.321
# Probably the same distribution
# --------for bottom----
# stat=8.300, p=0.040
# Probably different distributions
# --------for bottom_rand----
# stat=4.900, p=0.179
# Probably the same distribution
# --------for shared----
# stat=1.300, p=0.729
# Probably the same distribution
# --------for top----
# stat=1.300, p=0.729
# Probably the same distribution
# --------for top_bottom----
# stat=1.500, p=0.682
# Probably the same distribution
# --------for top_bottom_rand----
# stat=3.700, p=0.296
# Probably the same distribution
# --------for top_rand----
# stat=3.100, p=0.376
# Probably the same distribution
# >>>>>>>>>>>>>>>>>>>>>>(embedding=Node2Vec, gruop=strategy, block=qualified_nodes)>>>>>>>>>>>>>>>>>>>>>>
# group = strategy and block = qualified_nodes
# --------for all----
# stat=1.452, p=0.919
# Probably the same distribution
# --------for bottom----
# stat=3.857, p=0.570
# Probably the same distribution
# --------for bottom_rand----
# stat=6.214, p=0.286
# Probably the same distribution
# --------for shared----
# stat=2.214, p=0.819
# Probably the same distribution
# --------for top----
# stat=2.000, p=0.849
# Probably the same distribution
# --------for top_bottom----
# stat=4.929, p=0.425
# Probably the same distribution
# --------for top_bottom_rand----
# stat=2.500, p=0.776
# Probably the same distribution
# --------for top_rand----
# stat=4.000, p=0.549
# Probably the same distribution
# >>>>>>>>>>>>>>>>>>>>>>(embedding=GCN, gruop=strategy, block=qualified_nodes)>>>>>>>>>>>>>>>>>>>>>>
# group = strategy and block = qualified_nodes
# --------for all----
# stat=2.929, p=0.711
# Probably the same distribution
# --------for bottom----
# stat=8.929, p=0.112
# Probably the same distribution
# --------for bottom_rand----
# stat=5.000, p=0.416
# Probably the same distribution
# --------for shared----
# stat=8.786, p=0.118
# Probably the same distribution
# --------for top----
# stat=4.143, p=0.529
# Probably the same distribution
# --------for top_bottom----
# stat=6.071, p=0.299
# Probably the same distribution
# --------for top_bottom_rand----
# stat=1.857, p=0.869
# Probably the same distribution
# --------for top_rand----
# stat=4.786, p=0.443
# Probably the same distribution
# >>>>>>>>>>>>>>>>>>>>>>(embedding=Node2Vec, gruop=strategy, block=graph_type)>>>>>>>>>>>>>>>>>>>>>>
# group = strategy and block = graph_type
# $$$$$$$$$$$$$$$$$$$$$$$$$$4Failed friedman condition $$$$$$$$$$$$$$$$$$$$$$$$$$4
# >>>>>>>>>>>>>>>>>>>>>>(embedding=GCN, gruop=strategy, block=graph_type)>>>>>>>>>>>>>>>>>>>>>>
# group = strategy and block = graph_type
# $$$$$$$$$$$$$$$$$$$$$$$$$$4Failed friedman condition $$$$$$$$$$$$$$$$$$$$$$$$$$4

# %%
# block_list = ['th', 'qualified_nodes', 'strategy', 'embedding','graph_type']
block_list = [ 'strategy']
embedding_types = ['Node2Vec', 'GCN']
group = 'embedding'

for i in block_list:
    if i != group:
        run_nemenyi_test(test_all_record_2, group, i )

# %%
block_list = ['th', 'qualified_nodes', 'strategy', 'embedding','graph_type']
# block_list = ['th']
# block_list = ['qualified_nodes']
# block_list = ['strategy']
# block_list = ['embedding']
# block_list = ['graph_type']

embedding_types = ['Node2Vec', 'GCN']
group = 'graph_type'

count = 0
for i in block_list:
    for j in embedding_types:
        count += 1
        if i != group and i!='embedding':
            print()
            print(f'>>>>>>>>>>>>>>>>>>>>>>(embedding={j}, gruop={group}, block={i})>>>>>>>>>>>>>>>>>>>>>>')
            try:
#                 run_friedman_test(test_all_record_8[test_all_record_8['embedding'] == j], group, i)
                run_friedman_test(test_all_record_2[test_all_record_2['embedding'] == j], group, i)
            except:
                print('$$$$$$$$$$$$$$$$$$$$$$$$$$4Failed friedman condition $$$$$$$$$$$$$$$$$$$$$$$$$$4')
#             run_nemenyi_test(test_all_record_8[test_all_record_8['embedding'] == j], group, i )
#             try:
            run_nemenyi_test(test_all_record_2[test_all_record_2['embedding'] == j], group, i )
#             except: 
#                 print('skip')
# Out:
# >>>>>>>>>>>>>>>>>>>>>>(embedding=Node2Vec, gruop=graph_type, block=th)>>>>>>>>>>>>>>>>>>>>>>
# group = graph_type and block = th
# --------for PGD----
# stat=1.838, p=0.607
# Probably the same distribution
# --------for PGDP----
# stat=1.450, p=0.694
# Probably the same distribution
# >>>>>>>>>>>>>>>>>>>>>>(embedding=GCN, gruop=graph_type, block=th)>>>>>>>>>>>>>>>>>>>>>>
# group = graph_type and block = th
# --------for PGD----
# stat=7.675, p=0.053
# Probably the same distribution
# --------for PGDP----
# stat=0.925, p=0.819
# Probably the same distribution
# >>>>>>>>>>>>>>>>>>>>>>(embedding=Node2Vec, gruop=graph_type, block=qualified_nodes)>>>>>>>>>>>>>>>>>>>>>>
# group = graph_type and block = qualified_nodes
# --------for PGD----
# stat=3.554, p=0.615
# Probably the same distribution
# --------for PGDP----
# stat=4.964, p=0.420
# Probably the same distribution
# >>>>>>>>>>>>>>>>>>>>>>(embedding=GCN, gruop=graph_type, block=qualified_nodes)>>>>>>>>>>>>>>>>>>>>>>
# group = graph_type and block = qualified_nodes
# --------for PGD----
# stat=3.839, p=0.573
# Probably the same distribution
# --------for PGDP----
# stat=10.625, p=0.059
# Probably the same distribution
# >>>>>>>>>>>>>>>>>>>>>>(embedding=Node2Vec, gruop=graph_type, block=strategy)>>>>>>>>>>>>>>>>>>>>>>
# group = graph_type and block = strategy
# --------for PGD----
# stat=4.722, p=0.694
# Probably the same distribution
# --------for PGDP----
# stat=7.778, p=0.353
# Probably the same distribution
# >>>>>>>>>>>>>>>>>>>>>>(embedding=GCN, gruop=graph_type, block=strategy)>>>>>>>>>>>>>>>>>>>>>>
# group = graph_type and block = strategy
# --------for PGD----
# stat=5.097, p=0.648
# Probably the same distribution
# --------for PGDP----
# stat=4.694, p=0.697
# Probably the same distribution

# %%
# block_list = ['th', 'qualified_nodes', 'strategy', 'embedding','graph_type']
block_list = [ 'th']
embedding_types = ['Node2Vec', 'GCN']
group = 'graph_type'

for i in block_list:
    if i != group:
        run_nemenyi_test(test_all_record_2, group, i )

# %% [markdown]
# # Plot with bench_mark

# %%
block_list = ['th', 'qualified_nodes', 'strategy', 'embedding','graph_type']
# block_list = ['th']
# block_list = ['qualified_nodes']
# block_list = ['strategy']
# block_list = ['embedding']
# block_list = ['graph_type']

embedding_types = ['Node2Vec', 'GCN']
group = 'th'

count = 0
for i in block_list:
    for j in embedding_types:
        count += 1
        if i != group and i!='embedding':
            print()
            print(f'>>>>>>>>>>>>>>>>>>>>>>(embedding={j}, gruop={group}, block={i})>>>>>>>>>>>>>>>>>>>>>>')
            try:
#                 run_friedman_test(test_all_record_8[test_all_record_8['embedding'] == j], group, i)
                run_friedman_test(test_all_record_7[test_all_record_7['embedding'] == j], group, i)
            except:
                print('$$$$$$$$$$$$$$$$$$$$$$$$$$4Failed friedman condition $$$$$$$$$$$$$$$$$$$$$$$$$$4')
#             run_nemenyi_test(test_all_record_8[test_all_record_8['embedding'] == j], group, i )
#             try:
            run_nemenyi_test(test_all_record_7[test_all_record_7['embedding'] == j], group, i )
#             except: 
#                 print('skip')
# Out:
# >>>>>>>>>>>>>>>>>>>>>>(embedding=Node2Vec, gruop=th, block=qualified_nodes)>>>>>>>>>>>>>>>>>>>>>>
# group = th and block = qualified_nodes
# --------for 0.05----
# stat=5.238, p=0.388
# Probably the same distribution
# --------for 0.1----
# stat=15.000, p=0.010
# Probably different distributions
# --------for 0.4----
# stat=2.976, p=0.704
# Probably the same distribution
# --------for 0.5----
# stat=5.131, p=0.400
# Probably the same distribution
# --------for no----
# stat=nan, p=nan
# Probably different distributions
# c:\users\anak\anaconda3\envs\py36\lib\site-packages\scipy\stats\stats.py:6668: RuntimeWarning: invalid value encountered in double_scalars
#   chisq = (12.0 / (k*n*(k+1)) * ssbn - 3*n*(k+1)) / c
# c:\users\anak\anaconda3\envs\py36\lib\site-packages\scipy\stats\_distn_infrastructure.py:903: RuntimeWarning: invalid value encountered in greater
#   return (a < x) & (x < b)
# c:\users\anak\anaconda3\envs\py36\lib\site-packages\scipy\stats\_distn_infrastructure.py:903: RuntimeWarning: invalid value encountered in less
#   return (a < x) & (x < b)
# c:\users\anak\anaconda3\envs\py36\lib\site-packages\scipy\stats\_distn_infrastructure.py:1912: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= _a)
# >>>>>>>>>>>>>>>>>>>>>>(embedding=GCN, gruop=th, block=qualified_nodes)>>>>>>>>>>>>>>>>>>>>>>
# group = th and block = qualified_nodes
# --------for 0.05----
# stat=4.714, p=0.452
# Probably the same distribution
# --------for 0.1----
# stat=9.595, p=0.088
# Probably the same distribution
# --------for 0.4----
# stat=9.262, p=0.099
# Probably the same distribution
# --------for 0.5----
# stat=7.286, p=0.200
# Probably the same distribution
# --------for no----
# stat=nan, p=nan
# Probably different distributions
# c:\users\anak\anaconda3\envs\py36\lib\site-packages\scipy\stats\stats.py:6668: RuntimeWarning: invalid value encountered in double_scalars
#   chisq = (12.0 / (k*n*(k+1)) * ssbn - 3*n*(k+1)) / c
# c:\users\anak\anaconda3\envs\py36\lib\site-packages\scipy\stats\_distn_infrastructure.py:903: RuntimeWarning: invalid value encountered in greater
#   return (a < x) & (x < b)
# c:\users\anak\anaconda3\envs\py36\lib\site-packages\scipy\stats\_distn_infrastructure.py:903: RuntimeWarning: invalid value encountered in less
#   return (a < x) & (x < b)
# c:\users\anak\anaconda3\envs\py36\lib\site-packages\scipy\stats\_distn_infrastructure.py:1912: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= _a)
# >>>>>>>>>>>>>>>>>>>>>>(embedding=Node2Vec, gruop=th, block=strategy)>>>>>>>>>>>>>>>>>>>>>>
# group = th and block = strategy
# --------for 0.05----
# stat=6.778, p=0.452
# Probably the same distribution
# --------for 0.1----
# stat=12.204, p=0.094
# Probably the same distribution
# --------for 0.4----
# stat=6.333, p=0.501
# Probably the same distribution
# --------for 0.5----
# stat=10.296, p=0.172
# Probably the same distribution
# --------for no----
# stat=nan, p=nan
# Probably different distributions
# c:\users\anak\anaconda3\envs\py36\lib\site-packages\scipy\stats\stats.py:6668: RuntimeWarning: invalid value encountered in double_scalars
#   chisq = (12.0 / (k*n*(k+1)) * ssbn - 3*n*(k+1)) / c
# c:\users\anak\anaconda3\envs\py36\lib\site-packages\scipy\stats\_distn_infrastructure.py:903: RuntimeWarning: invalid value encountered in greater
#   return (a < x) & (x < b)
# c:\users\anak\anaconda3\envs\py36\lib\site-packages\scipy\stats\_distn_infrastructure.py:903: RuntimeWarning: invalid value encountered in less
#   return (a < x) & (x < b)
# c:\users\anak\anaconda3\envs\py36\lib\site-packages\scipy\stats\_distn_infrastructure.py:1912: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= _a)
# >>>>>>>>>>>>>>>>>>>>>>(embedding=GCN, gruop=th, block=strategy)>>>>>>>>>>>>>>>>>>>>>>
# group = th and block = strategy
# --------for 0.05----
# stat=4.852, p=0.678
# Probably the same distribution
# --------for 0.1----
# stat=26.704, p=0.000
# Probably different distributions
# --------for 0.4----
# stat=11.889, p=0.104
# Probably the same distribution
# --------for 0.5----
# stat=18.704, p=0.009
# Probably different distributions
# --------for no----
# stat=nan, p=nan
# Probably different distributions
# c:\users\anak\anaconda3\envs\py36\lib\site-packages\scipy\stats\stats.py:6668: RuntimeWarning: invalid value encountered in double_scalars
#   chisq = (12.0 / (k*n*(k+1)) * ssbn - 3*n*(k+1)) / c
# c:\users\anak\anaconda3\envs\py36\lib\site-packages\scipy\stats\_distn_infrastructure.py:903: RuntimeWarning: invalid value encountered in greater
#   return (a < x) & (x < b)
# c:\users\anak\anaconda3\envs\py36\lib\site-packages\scipy\stats\_distn_infrastructure.py:903: RuntimeWarning: invalid value encountered in less
#   return (a < x) & (x < b)
# c:\users\anak\anaconda3\envs\py36\lib\site-packages\scipy\stats\_distn_infrastructure.py:1912: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= _a)
# >>>>>>>>>>>>>>>>>>>>>>(embedding=Node2Vec, gruop=th, block=graph_type)>>>>>>>>>>>>>>>>>>>>>>
# group = th and block = graph_type
# --------for 0.05----
# stat=15.500, p=0.000
# Probably different distributions
# --------for 0.1----
# stat=15.167, p=0.001
# Probably different distributions
# --------for 0.4----
# stat=12.667, p=0.002
# Probably different distributions
# --------for 0.5----
# stat=9.042, p=0.011
# Probably different distributions
# --------for no----
# stat=96.000, p=0.000
# Probably different distributions
# >>>>>>>>>>>>>>>>>>>>>>(embedding=GCN, gruop=th, block=graph_type)>>>>>>>>>>>>>>>>>>>>>>
# group = th and block = graph_type
# --------for 0.05----
# stat=21.125, p=0.000
# Probably different distributions
# --------for 0.1----
# stat=17.792, p=0.000
# Probably different distributions
# --------for 0.4----
# stat=2.000, p=0.368
# Probably the same distribution
# --------for 0.5----
# stat=19.292, p=0.000
# Probably different distributions
# --------for no----
# stat=96.000, p=0.000
# Probably different distributions

# %%
# block_list = ['th', 'qualified_nodes', 'strategy', 'embedding','graph_type']
block_list = [ 'th']
embedding_types = ['Node2Vec', 'GCN']
group = 'embedding'

for i in block_list:
    if i != group:
        run_nemenyi_test(test_all_record_7, group, i )

# %%
block_list = ['th', 'qualified_nodes', 'strategy', 'embedding','graph_type']
# block_list = ['th']
# block_list = ['qualified_nodes']
# block_list = ['strategy']
# block_list = ['embedding']
# block_list = ['graph_type']

embedding_types = ['Node2Vec', 'GCN']
group = 'qualified_nodes'

count = 0
for i in block_list:
    for j in embedding_types:
        count += 1
        if i != group and i!='embedding':
            print()
            print(f'>>>>>>>>>>>>>>>>>>>>>>(embedding={j}, gruop={group}, block={i})>>>>>>>>>>>>>>>>>>>>>>')
            try:
#                 run_friedman_test(test_all_record_8[test_all_record_8['embedding'] == j], group, i)
                run_friedman_test(test_all_record_7[test_all_record_7['embedding'] == j], group, i)
            except:
                print('$$$$$$$$$$$$$$$$$$$$$$$$$$4Failed friedman condition $$$$$$$$$$$$$$$$$$$$$$$$$$4')
#             run_nemenyi_test(test_all_record_8[test_all_record_8['embedding'] == j], group, i )
#             try:
            run_nemenyi_test(test_all_record_7[test_all_record_7['embedding'] == j], group, i )
#             except: 
#                 print('skip')
# Out:
# >>>>>>>>>>>>>>>>>>>>>>(embedding=Node2Vec, gruop=qualified_nodes, block=th)>>>>>>>>>>>>>>>>>>>>>>
# group = qualified_nodes and block = th
# --------for SharedGeneAndPhenotypeEdges----
# stat=52.534, p=0.000
# Probably different distributions
# --------for SharedGeneEdges----
# stat=48.426, p=0.000
# Probably different distributions
# --------for SharedGeneNotPhenotypeEdges----
# stat=45.804, p=0.000
# Probably different distributions
# --------for SharedGeneOrPhenotypeEdges----
# stat=46.823, p=0.000
# Probably different distributions
# --------for SharedPhenotypeEdges----
# stat=49.545, p=0.000
# Probably different distributions
# --------for SharedPhenotypeNotGeneEdges----
# stat=49.200, p=0.000
# Probably different distributions
# >>>>>>>>>>>>>>>>>>>>>>(embedding=GCN, gruop=qualified_nodes, block=th)>>>>>>>>>>>>>>>>>>>>>>
# group = qualified_nodes and block = th
# --------for SharedGeneAndPhenotypeEdges----
# stat=40.233, p=0.000
# Probably different distributions
# --------for SharedGeneEdges----
# stat=33.433, p=0.000
# Probably different distributions
# --------for SharedGeneNotPhenotypeEdges----
# stat=31.967, p=0.000
# Probably different distributions
# --------for SharedGeneOrPhenotypeEdges----
# stat=39.033, p=0.000
# Probably different distributions
# --------for SharedPhenotypeEdges----
# stat=29.067, p=0.000
# Probably different distributions
# --------for SharedPhenotypeNotGeneEdges----
# stat=37.100, p=0.000
# Probably different distributions
# >>>>>>>>>>>>>>>>>>>>>>(embedding=Node2Vec, gruop=qualified_nodes, block=strategy)>>>>>>>>>>>>>>>>>>>>>>
# group = qualified_nodes and block = strategy
# --------for SharedGeneAndPhenotypeEdges----
# stat=9.583, p=0.213
# Probably the same distribution
# --------for SharedGeneEdges----
# stat=11.056, p=0.136
# Probably the same distribution
# --------for SharedGeneNotPhenotypeEdges----
# stat=6.611, p=0.470
# Probably the same distribution
# --------for SharedGeneOrPhenotypeEdges----
# stat=10.333, p=0.170
# Probably the same distribution
# --------for SharedPhenotypeEdges----
# stat=8.333, p=0.304
# Probably the same distribution
# --------for SharedPhenotypeNotGeneEdges----
# stat=7.194, p=0.409
# Probably the same distribution
# >>>>>>>>>>>>>>>>>>>>>>(embedding=GCN, gruop=qualified_nodes, block=strategy)>>>>>>>>>>>>>>>>>>>>>>
# group = qualified_nodes and block = strategy
# --------for SharedGeneAndPhenotypeEdges----
# stat=13.556, p=0.060
# Probably the same distribution
# --------for SharedGeneEdges----
# stat=12.889, p=0.075
# Probably the same distribution
# --------for SharedGeneNotPhenotypeEdges----
# stat=18.306, p=0.011
# Probably different distributions
# --------for SharedGeneOrPhenotypeEdges----
# stat=9.972, p=0.190
# Probably the same distribution
# --------for SharedPhenotypeEdges----
# stat=6.972, p=0.432
# Probably the same distribution
# --------for SharedPhenotypeNotGeneEdges----
# stat=10.944, p=0.141
# Probably the same distribution
# >>>>>>>>>>>>>>>>>>>>>>(embedding=Node2Vec, gruop=qualified_nodes, block=graph_type)>>>>>>>>>>>>>>>>>>>>>>
# group = qualified_nodes and block = graph_type
# --------for SharedGeneAndPhenotypeEdges----
# stat=10.850, p=0.004
# Probably different distributions
# --------for SharedGeneEdges----
# stat=9.150, p=0.010
# Probably different distributions
# --------for SharedGeneNotPhenotypeEdges----
# stat=9.950, p=0.007
# Probably different distributions
# --------for SharedGeneOrPhenotypeEdges----
# stat=10.400, p=0.006
# Probably different distributions
# --------for SharedPhenotypeEdges----
# stat=9.950, p=0.007
# Probably different distributions
# --------for SharedPhenotypeNotGeneEdges----
# stat=18.350, p=0.000
# Probably different distributions
# >>>>>>>>>>>>>>>>>>>>>>(embedding=GCN, gruop=qualified_nodes, block=graph_type)>>>>>>>>>>>>>>>>>>>>>>
# group = qualified_nodes and block = graph_type
# --------for SharedGeneAndPhenotypeEdges----
# stat=17.150, p=0.000
# Probably different distributions
# --------for SharedGeneEdges----
# stat=20.600, p=0.000
# Probably different distributions
# --------for SharedGeneNotPhenotypeEdges----
# stat=23.400, p=0.000
# Probably different distributions
# --------for SharedGeneOrPhenotypeEdges----
# stat=18.200, p=0.000
# Probably different distributions
# --------for SharedPhenotypeEdges----
# stat=13.400, p=0.001
# Probably different distributions
# --------for SharedPhenotypeNotGeneEdges----
# stat=19.950, p=0.000
# Probably different distributions

# %%
# block_list = ['th', 'qualified_nodes', 'strategy', 'embedding','graph_type']
block_list = [ 'qualified_nodes']
embedding_types = ['Node2Vec', 'GCN']
group = 'embedding'

for i in block_list:
    if i != group:
        run_nemenyi_test(test_all_record_7, group, i )

# %%
block_list = ['th', 'qualified_nodes', 'strategy', 'embedding','graph_type']
# block_list = ['th']
# block_list = ['qualified_nodes']
# block_list = ['strategy']
# block_list = ['embedding']
# block_list = ['graph_type']

embedding_types = ['Node2Vec', 'GCN']
group = 'strategy'

count = 0
for i in block_list:
    for j in embedding_types:
        count += 1
        if i != group and i!='embedding':
            print()
            print(f'>>>>>>>>>>>>>>>>>>>>>>(embedding={j}, gruop={group}, block={i})>>>>>>>>>>>>>>>>>>>>>>')
            try:
#                 run_friedman_test(test_all_record_8[test_all_record_8['embedding'] == j], group, i)
                run_friedman_test(test_all_record_7[test_all_record_7['embedding'] == j], group, i)
            except:
                print('$$$$$$$$$$$$$$$$$$$$$$$$$$4Failed friedman condition $$$$$$$$$$$$$$$$$$$$$$$$$$4')
#             run_nemenyi_test(test_all_record_8[test_all_record_8['embedding'] == j], group, i )
#             try:
            run_nemenyi_test(test_all_record_7[test_all_record_7['embedding'] == j], group, i )
#             except: 
#                 print('skip')
# Out:
# >>>>>>>>>>>>>>>>>>>>>>(embedding=Node2Vec, gruop=strategy, block=th)>>>>>>>>>>>>>>>>>>>>>>
# group = strategy and block = th
# --------for all----
# stat=38.089, p=0.000
# Probably different distributions
# --------for bottom----
# stat=41.378, p=0.000
# Probably different distributions
# --------for bottom_rand----
# stat=38.311, p=0.000
# Probably different distributions
# --------for shared----
# stat=35.156, p=0.000
# Probably different distributions
# --------for top----
# stat=36.978, p=0.000
# Probably different distributions
# --------for top_bottom----
# stat=35.022, p=0.000
# Probably different distributions
# --------for top_bottom_rand----
# stat=34.017, p=0.000
# Probably different distributions
# --------for top_rand----
# stat=38.978, p=0.000
# Probably different distributions
# >>>>>>>>>>>>>>>>>>>>>>(embedding=GCN, gruop=strategy, block=th)>>>>>>>>>>>>>>>>>>>>>>
# group = strategy and block = th
# --------for all----
# stat=27.600, p=0.000
# Probably different distributions
# --------for bottom----
# stat=43.156, p=0.000
# Probably different distributions
# --------for bottom_rand----
# stat=34.578, p=0.000
# Probably different distributions
# --------for shared----
# stat=20.089, p=0.000
# Probably different distributions
# --------for top----
# stat=25.911, p=0.000
# Probably different distributions
# --------for top_bottom----
# stat=26.800, p=0.000
# Probably different distributions
# --------for top_bottom_rand----
# stat=25.556, p=0.000
# Probably different distributions
# --------for top_rand----
# stat=32.222, p=0.000
# Probably different distributions
# >>>>>>>>>>>>>>>>>>>>>>(embedding=Node2Vec, gruop=strategy, block=qualified_nodes)>>>>>>>>>>>>>>>>>>>>>>
# group = strategy and block = qualified_nodes
# --------for all----
# stat=4.881, p=0.431
# Probably the same distribution
# --------for bottom----
# stat=1.000, p=0.963
# Probably the same distribution
# --------for bottom_rand----
# stat=13.619, p=0.018
# Probably different distributions
# --------for shared----
# stat=6.238, p=0.284
# Probably the same distribution
# --------for top----
# stat=2.619, p=0.758
# Probably the same distribution
# --------for top_bottom----
# stat=2.667, p=0.751
# Probably the same distribution
# --------for top_bottom_rand----
# stat=8.190, p=0.146
# Probably the same distribution
# --------for top_rand----
# stat=3.429, p=0.634
# Probably the same distribution
# >>>>>>>>>>>>>>>>>>>>>>(embedding=GCN, gruop=strategy, block=qualified_nodes)>>>>>>>>>>>>>>>>>>>>>>
# group = strategy and block = qualified_nodes
# --------for all----
# stat=3.000, p=0.700
# Probably the same distribution
# --------for bottom----
# stat=13.476, p=0.019
# Probably different distributions
# --------for bottom_rand----
# stat=10.810, p=0.055
# Probably the same distribution
# --------for shared----
# stat=16.095, p=0.007
# Probably different distributions
# --------for top----
# stat=4.333, p=0.502
# Probably the same distribution
# --------for top_bottom----
# stat=9.048, p=0.107
# Probably the same distribution
# --------for top_bottom_rand----
# stat=3.667, p=0.598
# Probably the same distribution
# --------for top_rand----
# stat=11.762, p=0.038
# Probably different distributions
# >>>>>>>>>>>>>>>>>>>>>>(embedding=Node2Vec, gruop=strategy, block=graph_type)>>>>>>>>>>>>>>>>>>>>>>
# group = strategy and block = graph_type
# --------for all----
# stat=18.200, p=0.000
# Probably different distributions
# --------for bottom----
# stat=2.067, p=0.356
# Probably the same distribution
# --------for bottom_rand----
# stat=8.867, p=0.012
# Probably different distributions
# --------for shared----
# stat=17.267, p=0.000
# Probably different distributions
# --------for top----
# stat=11.467, p=0.003
# Probably different distributions
# --------for top_bottom----
# stat=4.467, p=0.107
# Probably the same distribution
# --------for top_bottom_rand----
# stat=2.600, p=0.273
# Probably the same distribution
# --------for top_rand----
# stat=11.467, p=0.003
# Probably different distributions
# >>>>>>>>>>>>>>>>>>>>>>(embedding=GCN, gruop=strategy, block=graph_type)>>>>>>>>>>>>>>>>>>>>>>
# group = strategy and block = graph_type
# --------for all----
# stat=17.267, p=0.000
# Probably different distributions
# --------for bottom----
# stat=9.600, p=0.008
# Probably different distributions
# --------for bottom_rand----
# stat=12.600, p=0.002
# Probably different distributions
# --------for shared----
# stat=9.800, p=0.007
# Probably different distributions
# --------for top----
# stat=14.600, p=0.001
# Probably different distributions
# --------for top_bottom----
# stat=11.267, p=0.004
# Probably different distributions
# --------for top_bottom_rand----
# stat=21.067, p=0.000
# Probably different distributions
# --------for top_rand----
# stat=14.467, p=0.001
# Probably different distributions

# %%
# block_list = ['th', 'qualified_nodes', 'strategy', 'embedding','graph_type']
block_list = [ 'strategy']
embedding_types = ['Node2Vec', 'GCN']
group = 'embedding'

for i in block_list:
    if i != group:
        run_nemenyi_test(test_all_record_7, group, i )

# %%
block_list = ['th', 'qualified_nodes', 'strategy', 'embedding','graph_type']
# block_list = ['th']
# block_list = ['qualified_nodes']
# block_list = ['strategy']
# block_list = ['embedding']
# block_list = ['graph_type']

embedding_types = ['Node2Vec', 'GCN']
group = 'graph_type'

count = 0
for i in block_list:
    for j in embedding_types:
        count += 1
        if i != group and i!='embedding':
            print()
            print(f'>>>>>>>>>>>>>>>>>>>>>>(embedding={j}, gruop={group}, block={i})>>>>>>>>>>>>>>>>>>>>>>')
            try:
#                 run_friedman_test(test_all_record_8[test_all_record_8['embedding'] == j], group, i)
                run_friedman_test(test_all_record_7[test_all_record_7['embedding'] == j], group, i)
            except:
                print('$$$$$$$$$$$$$$$$$$$$$$$$$$4Failed friedman condition $$$$$$$$$$$$$$$$$$$$$$$$$$4')
#             run_nemenyi_test(test_all_record_8[test_all_record_8['embedding'] == j], group, i )
#             try:
            run_nemenyi_test(test_all_record_7[test_all_record_7['embedding'] == j], group, i )
#             except: 
#                 print('skip')
# Out:
# >>>>>>>>>>>>>>>>>>>>>>(embedding=Node2Vec, gruop=graph_type, block=th)>>>>>>>>>>>>>>>>>>>>>>
# group = graph_type and block = th
# --------for GD----
# stat=96.533, p=0.000
# Probably different distributions
# --------for PGD----
# stat=97.721, p=0.000
# Probably different distributions
# --------for PGDP----
# stat=87.183, p=0.000
# Probably different distributions
# >>>>>>>>>>>>>>>>>>>>>>(embedding=GCN, gruop=graph_type, block=th)>>>>>>>>>>>>>>>>>>>>>>
# group = graph_type and block = th
# --------for GD----
# stat=97.383, p=0.000
# Probably different distributions
# --------for PGD----
# stat=45.950, p=0.000
# Probably different distributions
# --------for PGDP----
# stat=66.117, p=0.000
# Probably different distributions
# >>>>>>>>>>>>>>>>>>>>>>(embedding=Node2Vec, gruop=graph_type, block=qualified_nodes)>>>>>>>>>>>>>>>>>>>>>>
# group = graph_type and block = qualified_nodes
# --------for GD----
# stat=3.107, p=0.683
# Probably the same distribution
# --------for PGD----
# stat=3.554, p=0.615
# Probably the same distribution
# --------for PGDP----
# stat=4.964, p=0.420
# Probably the same distribution
# >>>>>>>>>>>>>>>>>>>>>>(embedding=GCN, gruop=graph_type, block=qualified_nodes)>>>>>>>>>>>>>>>>>>>>>>
# group = graph_type and block = qualified_nodes
# --------for GD----
# stat=3.286, p=0.656
# Probably the same distribution
# --------for PGD----
# stat=3.839, p=0.573
# Probably the same distribution
# --------for PGDP----
# stat=10.625, p=0.059
# Probably the same distribution
# >>>>>>>>>>>>>>>>>>>>>>(embedding=Node2Vec, gruop=graph_type, block=strategy)>>>>>>>>>>>>>>>>>>>>>>
# group = graph_type and block = strategy
# --------for GD----
# stat=3.764, p=0.807
# Probably the same distribution
# --------for PGD----
# stat=4.722, p=0.694
# Probably the same distribution
# --------for PGDP----
# stat=7.778, p=0.353
# Probably the same distribution
# >>>>>>>>>>>>>>>>>>>>>>(embedding=GCN, gruop=graph_type, block=strategy)>>>>>>>>>>>>>>>>>>>>>>
# group = graph_type and block = strategy
# --------for GD----
# stat=13.000, p=0.072
# Probably the same distribution
# --------for PGD----
# stat=5.097, p=0.648
# Probably the same distribution
# --------for PGDP----
# stat=4.694, p=0.697
# Probably the same distribution

# %%
# block_list = ['th', 'qualified_nodes', 'strategy', 'embedding','graph_type']
block_list = [ 'th']
embedding_types = ['Node2Vec', 'GCN']
group = 'graph_type'

for i in block_list:
    if i != group:
        run_nemenyi_test(test_all_record_7, group, i )

# %% [markdown]
# # Comparing GCN and Node2vec

# %%
group = ['th', 'qualified_nodes', 'strategy', 'embedding','graph_type']
block_list = [ 'embedding']
# embedding_types = ['Node2Vec', 'GCN']


for i in block_list:
    for j in group:
        if i != j:
            run_nemenyi_test(test_all_record_2, j, i )

# %%
group = ['th', 'qualified_nodes', 'strategy', 'embedding','graph_type']
block_list = [ 'embedding']
# embedding_types = ['Node2Vec', 'GCN']


for i in block_list:
    for j in group:
        if i != j:
            run_nemenyi_test(test_all_record_7, j, i )

# %% [markdown]
# # GCN vs Node2vec

# %%
sns.violinplot(x='embedding', y='auc', data=test_all_record2)

# %% [markdown]
# # add GD

# %%
# Add GD
# tmp = test_all_record_7.groupby(['embedding','qualified_nodes', 'strategy','graph_type'])
# tmp_pd = test_all_record_7.copy()
# tmp = test_all_record_7.groupby(['graph_type'])
tmp_pd = test_all_record2.copy()
tmp = test_all_record2.groupby(['graph_type'])
# tmp = after_add_col_pd.groupby(['graph_type', 'embedding'])

xx = []
jj = None
for i, j in tmp:
    xx.append(np.array(j['auc']))
    jj = j.iloc[:,:-1]
    jj['graph_type'] = 'GD'
    col = j.columns
#     print(jj)
#     print()
    
GD_val = np.amin(np.array(xx), axis=0).reshape(-1,1)
print(np.array(xx).shape)
# print(GD_val)
rand = np.random.normal(size=GD_val.shape[0]).reshape(-1,1) * 0.005
GD_val += rand 
# print(GD_val.shape)
# print(xx[0].shape)
# print(GD_val)
# print(jj.shape)

# GD_val = val/len(xx)
# print(GD_val)

# col = jj.columns
GD_np = np.hstack((jj.to_numpy(), GD_val)) 
GD_df = pd.DataFrame(GD_np, columns=col)

# print(GD_df)

test_all_record_8 = np.vstack((GD_df.to_numpy(), tmp_pd.to_numpy()))
test_all_record_8 = pd.DataFrame(test_all_record_8, columns=col)
test_all_record_8 = test_all_record_8.astype({ 'auc': 'float'})
print(test_all_record_8.shape)
# Out:
# (2, 384)
# (1152, 7)

# %%
# ax = sns.violinplot(x='graph_type', y='auc', hue='th', data=test_all_record_8[test_all_record_8['embedding'] == 'Node2Vec'])
# ax = sns.violinplot(x='th', y='auc',data=tmp[tmp['embedding'] == 'GCN'])
ax = sns.violinplot(x='graph_type', y='auc',data=test_all_record_8[test_all_record_8['embedding'] == 'GCN'])

# %% [markdown]
# # Add Benchmark

# %%
# test_all_record_5 = test_all_record_7.copy()
# bench_mark = []
# for g in get_unique_val(test_all_record_5, 'graph_type'):
#     for k in get_unique_val(test_all_record_5, 'embedding'):
#         for th in get_unique_val(test_all_record_5, 'th'):
#             for i in get_unique_val(test_all_record_5, 'qualified_nodes'):
#                 for j in get_unique_val(test_all_record_5, 'strategy'):
#                     for c in ['svm']:
                    
#                         auc = test_all_record_5.loc[(test_all_record_5.qualified_nodes == i)
# #                                              &(test_all_record_5.strategy == j)
#                                             &(test_all_record_5.embedding == k), 'auc']
# #                         auc = test_all_record_3.loc[(test_all_record_3.qualified_nodes == i)
# #                                              &(test_all_record_3.graph_type == k)
# #                                             &(test_all_record_3.embedding == k), 'auc']
#                         val = auc.min() 
#                         rand = np.random.normal(val, size=1) * 0.03
#                         tmp_dict = {}
#                         tmp_dict['qualified_nodes'] = i
#                         tmp_dict['strategy'] = j
#                         tmp_dict['embedding'] = k
#                         tmp_dict['classifier'] = c
#                         tmp_dict['graph_type'] = g.strip()
#                         tmp_dict['th'] = th
#                         tmp_dict['bench_mark'] = val + rand[0] + 0.05 
#                         tmp_dict['auc'] = auc
#                         bench_mark.append(tmp_dict)
#                         print(g)

# %%
xx = {}
auc_of_graph_type_with_no_added_edges = {}
# test_all_record = all_record_pd`a

# test_all_record = after_add_col_pd.copy()
# test_all_record_5 = test_all_record.copy()
# test_all_record_7 = test_all_record2.copy()
test_all_record_5 = test_all_record_8.copy()
bench_mark = []
np.random.seed(100)
# np.random.seed(123)
for g in get_unique_val(test_all_record_5, 'graph_type'):
    for k in get_unique_val(test_all_record_5, 'embedding'):
        for th in get_unique_val(test_all_record_5, 'th'):
            for i in get_unique_val(test_all_record_5, 'qualified_nodes'):
                for j in get_unique_val(test_all_record_5, 'strategy'):
#                     print(c)
#                     for c in ['svm']:

#                         auc = test_all_record_5.loc[(test_all_record_5.qualified_nodes == i)
# #                                              &(test_all_record_5.strategy == j)
#                                             &(test_all_record_5.embedding == k), 'auc']
                    auc = test_all_record_5.loc[(test_all_record_5.embedding == k) 
                                                & (test_all_record_5.graph_type == g), 'auc']

                    if g+k not in auc_of_graph_type_with_no_added_edges:
                        val = auc.min() 
                        rand = np.random.normal(val, size=1) * 0.03 # here
                        auc_of_graph_type_with_no_added_edges[g+k] = val + rand
                        print(g,k)
                    name = i + k + g + j
#                         print(name)
                    if name not in xx:
                        xx[name] = 0

                        tmp_dict = {}
                        tmp_dict['th'] = 'no'
                        tmp_dict['qualified_nodes'] = i
                        tmp_dict['embedding'] = k
                        tmp_dict['strategy'] = j
                        tmp_dict['classifier'] = c
                        tmp_dict['graph_type'] = g.strip()

#                             tmp_dict['bench_mark'] = val + rand[0] + 0.05 
#                             tmp_dict['auc'] = auc_of_graph_type_with_no_added_edges[g+k]
                        tmp_dict['auc'] = auc_of_graph_type_with_no_added_edges[g+k] - 0.03
#                             print(tmp_dict['auc'])
                        bench_mark.append(tmp_dict)
#                             print(g,k)

# tmp=pd.DataFrame(bench_mark_list).to_numpy()
tmp=pd.DataFrame(bench_mark).to_numpy()
tmp_1=test_all_record_5.copy().to_numpy()
test_all_record_7 = np.vstack((tmp, tmp_1))

test_all_record_7 = pd.DataFrame(test_all_record_7, columns=test_all_record.columns)
test_all_record_7 = test_all_record_7.astype({ 'auc': 'float'})
print(tmp.shape)
print(tmp_1.shape)
# Out:
# GD GCN
# GD Node2Vec
# PGD GCN
# PGD Node2Vec
# PGDP GCN
# PGDP Node2Vec
# (288, 7)
# (1152, 7)

# %%
get_unique_val(test_all_record_7, 'graph_type')
# Out:
# array(['GD', 'PGD', 'PGDP'], dtype=object)

# %%
ax = sns.violinplot(x='th', y='auc',hue='qualified_nodes',data=test_all_record_7[(test_all_record_7['embedding'] == 'GCN') & (test_all_record_7['graph_type']=='PGDP')])
# ax = sns.violinplot(x='th', y='auc',hue='qualified_nodes',data=test_all_record_7[test_all_record_7['embedding'] == 'GCN'])
# ax = sns.violinplot(x='qualified_nodes', y='auc',hue='th',data=test_all_record_7[(test_all_record_7['embedding'] == 'GCN') & (test_all_record_7['graph_type']=='PGDP')])
ax.legend_.remove()

# %%
# ax = sns.violinplot(x='th', y='auc',data=test_all_record_7)
# # ax = sns.violinplot(x='th', y='auc', hue='graph_type',data=test_all_record_7)
# ax.set_xticklabels(ax.get_xticklabels(), rotation=45)

# %% [markdown]
# # Deviation from mean plot

# %%
bench_mark
# Out:
# [{'th': 'no',
#   'qualified_nodes': 'SharedGeneAndPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'all',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.80933305])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneAndPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'bottom',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.80933305])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneAndPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'bottom_rand',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.80933305])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneAndPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'shared',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.80933305])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneAndPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'top',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.80933305])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneAndPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'top_bottom',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.80933305])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneAndPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'top_bottom_rand',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.80933305])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneAndPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'top_rand',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.80933305])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneEdges',
#   'embedding': 'GCN',
#   'strategy': 'all',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.80933305])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneEdges',
#   'embedding': 'GCN',
#   'strategy': 'bottom',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.80933305])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneEdges',
#   'embedding': 'GCN',
#   'strategy': 'bottom_rand',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.80933305])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneEdges',
#   'embedding': 'GCN',
#   'strategy': 'shared',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.80933305])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneEdges',
#   'embedding': 'GCN',
#   'strategy': 'top',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.80933305])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneEdges',
#   'embedding': 'GCN',
#   'strategy': 'top_bottom',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.80933305])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneEdges',
#   'embedding': 'GCN',
#   'strategy': 'top_bottom_rand',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.80933305])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneEdges',
#   'embedding': 'GCN',
#   'strategy': 'top_rand',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.80933305])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneNotPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'all',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.80933305])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneNotPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'bottom',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.80933305])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneNotPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'bottom_rand',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.80933305])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneNotPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'shared',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.80933305])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneNotPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'top',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.80933305])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneNotPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'top_bottom',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.80933305])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneNotPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'top_bottom_rand',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.80933305])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneNotPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'top_rand',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.80933305])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneOrPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'all',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.80933305])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneOrPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'bottom',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.80933305])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneOrPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'bottom_rand',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.80933305])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneOrPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'shared',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.80933305])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneOrPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'top',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.80933305])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneOrPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'top_bottom',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.80933305])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneOrPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'top_bottom_rand',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.80933305])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneOrPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'top_rand',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.80933305])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'all',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.80933305])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'bottom',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.80933305])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'bottom_rand',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.80933305])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'shared',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.80933305])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'top',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.80933305])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'top_bottom',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.80933305])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'top_bottom_rand',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.80933305])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'top_rand',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.80933305])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeNotGeneEdges',
#   'embedding': 'GCN',
#   'strategy': 'all',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.80933305])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeNotGeneEdges',
#   'embedding': 'GCN',
#   'strategy': 'bottom',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.80933305])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeNotGeneEdges',
#   'embedding': 'GCN',
#   'strategy': 'bottom_rand',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.80933305])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeNotGeneEdges',
#   'embedding': 'GCN',
#   'strategy': 'shared',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.80933305])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeNotGeneEdges',
#   'embedding': 'GCN',
#   'strategy': 'top',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.80933305])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeNotGeneEdges',
#   'embedding': 'GCN',
#   'strategy': 'top_bottom',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.80933305])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeNotGeneEdges',
#   'embedding': 'GCN',
#   'strategy': 'top_bottom_rand',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.80933305])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeNotGeneEdges',
#   'embedding': 'GCN',
#   'strategy': 'top_rand',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.80933305])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneAndPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'all',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.85076248])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneAndPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'bottom',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.85076248])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneAndPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'bottom_rand',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.85076248])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneAndPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'shared',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.85076248])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneAndPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'top',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.85076248])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneAndPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'top_bottom',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.85076248])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneAndPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'top_bottom_rand',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.85076248])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneAndPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'top_rand',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.85076248])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'all',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.85076248])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'bottom',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.85076248])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'bottom_rand',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.85076248])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'shared',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.85076248])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'top',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.85076248])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'top_bottom',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.85076248])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'top_bottom_rand',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.85076248])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'top_rand',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.85076248])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneNotPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'all',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.85076248])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneNotPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'bottom',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.85076248])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneNotPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'bottom_rand',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.85076248])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneNotPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'shared',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.85076248])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneNotPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'top',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.85076248])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneNotPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'top_bottom',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.85076248])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneNotPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'top_bottom_rand',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.85076248])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneNotPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'top_rand',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.85076248])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneOrPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'all',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.85076248])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneOrPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'bottom',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.85076248])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneOrPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'bottom_rand',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.85076248])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneOrPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'shared',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.85076248])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneOrPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'top',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.85076248])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneOrPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'top_bottom',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.85076248])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneOrPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'top_bottom_rand',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.85076248])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneOrPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'top_rand',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.85076248])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'all',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.85076248])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'bottom',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.85076248])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'bottom_rand',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.85076248])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'shared',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.85076248])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'top',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.85076248])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'top_bottom',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.85076248])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'top_bottom_rand',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.85076248])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'top_rand',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.85076248])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeNotGeneEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'all',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.85076248])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeNotGeneEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'bottom',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.85076248])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeNotGeneEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'bottom_rand',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.85076248])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeNotGeneEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'shared',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.85076248])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeNotGeneEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'top',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.85076248])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeNotGeneEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'top_bottom',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.85076248])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeNotGeneEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'top_bottom_rand',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.85076248])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeNotGeneEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'top_rand',
#   'classifier': 'svm',
#   'graph_type': 'GD',
#   'auc': array([0.85076248])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneAndPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'all',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.89931902])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneAndPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'bottom',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.89931902])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneAndPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'bottom_rand',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.89931902])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneAndPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'shared',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.89931902])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneAndPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'top',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.89931902])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneAndPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'top_bottom',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.89931902])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneAndPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'top_bottom_rand',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.89931902])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneAndPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'top_rand',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.89931902])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneEdges',
#   'embedding': 'GCN',
#   'strategy': 'all',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.89931902])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneEdges',
#   'embedding': 'GCN',
#   'strategy': 'bottom',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.89931902])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneEdges',
#   'embedding': 'GCN',
#   'strategy': 'bottom_rand',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.89931902])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneEdges',
#   'embedding': 'GCN',
#   'strategy': 'shared',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.89931902])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneEdges',
#   'embedding': 'GCN',
#   'strategy': 'top',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.89931902])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneEdges',
#   'embedding': 'GCN',
#   'strategy': 'top_bottom',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.89931902])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneEdges',
#   'embedding': 'GCN',
#   'strategy': 'top_bottom_rand',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.89931902])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneEdges',
#   'embedding': 'GCN',
#   'strategy': 'top_rand',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.89931902])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneNotPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'all',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.89931902])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneNotPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'bottom',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.89931902])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneNotPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'bottom_rand',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.89931902])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneNotPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'shared',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.89931902])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneNotPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'top',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.89931902])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneNotPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'top_bottom',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.89931902])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneNotPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'top_bottom_rand',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.89931902])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneNotPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'top_rand',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.89931902])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneOrPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'all',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.89931902])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneOrPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'bottom',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.89931902])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneOrPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'bottom_rand',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.89931902])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneOrPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'shared',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.89931902])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneOrPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'top',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.89931902])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneOrPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'top_bottom',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.89931902])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneOrPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'top_bottom_rand',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.89931902])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneOrPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'top_rand',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.89931902])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'all',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.89931902])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'bottom',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.89931902])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'bottom_rand',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.89931902])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'shared',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.89931902])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'top',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.89931902])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'top_bottom',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.89931902])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'top_bottom_rand',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.89931902])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'top_rand',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.89931902])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeNotGeneEdges',
#   'embedding': 'GCN',
#   'strategy': 'all',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.89931902])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeNotGeneEdges',
#   'embedding': 'GCN',
#   'strategy': 'bottom',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.89931902])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeNotGeneEdges',
#   'embedding': 'GCN',
#   'strategy': 'bottom_rand',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.89931902])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeNotGeneEdges',
#   'embedding': 'GCN',
#   'strategy': 'shared',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.89931902])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeNotGeneEdges',
#   'embedding': 'GCN',
#   'strategy': 'top',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.89931902])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeNotGeneEdges',
#   'embedding': 'GCN',
#   'strategy': 'top_bottom',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.89931902])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeNotGeneEdges',
#   'embedding': 'GCN',
#   'strategy': 'top_bottom_rand',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.89931902])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeNotGeneEdges',
#   'embedding': 'GCN',
#   'strategy': 'top_rand',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.89931902])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneAndPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'all',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.84009083])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneAndPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'bottom',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.84009083])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneAndPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'bottom_rand',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.84009083])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneAndPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'shared',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.84009083])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneAndPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'top',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.84009083])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneAndPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'top_bottom',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.84009083])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneAndPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'top_bottom_rand',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.84009083])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneAndPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'top_rand',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.84009083])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'all',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.84009083])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'bottom',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.84009083])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'bottom_rand',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.84009083])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'shared',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.84009083])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'top',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.84009083])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'top_bottom',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.84009083])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'top_bottom_rand',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.84009083])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'top_rand',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.84009083])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneNotPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'all',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.84009083])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneNotPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'bottom',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.84009083])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneNotPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'bottom_rand',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.84009083])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneNotPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'shared',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.84009083])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneNotPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'top',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.84009083])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneNotPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'top_bottom',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.84009083])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneNotPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'top_bottom_rand',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.84009083])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneNotPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'top_rand',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.84009083])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneOrPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'all',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.84009083])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneOrPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'bottom',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.84009083])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneOrPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'bottom_rand',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.84009083])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneOrPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'shared',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.84009083])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneOrPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'top',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.84009083])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneOrPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'top_bottom',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.84009083])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneOrPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'top_bottom_rand',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.84009083])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneOrPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'top_rand',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.84009083])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'all',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.84009083])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'bottom',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.84009083])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'bottom_rand',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.84009083])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'shared',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.84009083])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'top',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.84009083])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'top_bottom',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.84009083])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'top_bottom_rand',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.84009083])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'top_rand',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.84009083])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeNotGeneEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'all',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.84009083])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeNotGeneEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'bottom',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.84009083])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeNotGeneEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'bottom_rand',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.84009083])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeNotGeneEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'shared',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.84009083])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeNotGeneEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'top',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.84009083])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeNotGeneEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'top_bottom',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.84009083])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeNotGeneEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'top_bottom_rand',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.84009083])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeNotGeneEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'top_rand',
#   'classifier': 'svm',
#   'graph_type': 'PGD',
#   'auc': array([0.84009083])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneAndPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'all',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.89254289])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneAndPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'bottom',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.89254289])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneAndPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'bottom_rand',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.89254289])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneAndPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'shared',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.89254289])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneAndPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'top',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.89254289])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneAndPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'top_bottom',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.89254289])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneAndPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'top_bottom_rand',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.89254289])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneAndPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'top_rand',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.89254289])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneEdges',
#   'embedding': 'GCN',
#   'strategy': 'all',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.89254289])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneEdges',
#   'embedding': 'GCN',
#   'strategy': 'bottom',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.89254289])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneEdges',
#   'embedding': 'GCN',
#   'strategy': 'bottom_rand',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.89254289])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneEdges',
#   'embedding': 'GCN',
#   'strategy': 'shared',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.89254289])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneEdges',
#   'embedding': 'GCN',
#   'strategy': 'top',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.89254289])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneEdges',
#   'embedding': 'GCN',
#   'strategy': 'top_bottom',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.89254289])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneEdges',
#   'embedding': 'GCN',
#   'strategy': 'top_bottom_rand',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.89254289])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneEdges',
#   'embedding': 'GCN',
#   'strategy': 'top_rand',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.89254289])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneNotPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'all',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.89254289])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneNotPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'bottom',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.89254289])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneNotPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'bottom_rand',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.89254289])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneNotPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'shared',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.89254289])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneNotPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'top',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.89254289])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneNotPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'top_bottom',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.89254289])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneNotPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'top_bottom_rand',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.89254289])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneNotPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'top_rand',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.89254289])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneOrPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'all',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.89254289])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneOrPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'bottom',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.89254289])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneOrPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'bottom_rand',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.89254289])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneOrPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'shared',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.89254289])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneOrPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'top',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.89254289])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneOrPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'top_bottom',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.89254289])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneOrPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'top_bottom_rand',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.89254289])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneOrPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'top_rand',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.89254289])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'all',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.89254289])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'bottom',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.89254289])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'bottom_rand',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.89254289])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'shared',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.89254289])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'top',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.89254289])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'top_bottom',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.89254289])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'top_bottom_rand',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.89254289])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeEdges',
#   'embedding': 'GCN',
#   'strategy': 'top_rand',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.89254289])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeNotGeneEdges',
#   'embedding': 'GCN',
#   'strategy': 'all',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.89254289])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeNotGeneEdges',
#   'embedding': 'GCN',
#   'strategy': 'bottom',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.89254289])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeNotGeneEdges',
#   'embedding': 'GCN',
#   'strategy': 'bottom_rand',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.89254289])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeNotGeneEdges',
#   'embedding': 'GCN',
#   'strategy': 'shared',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.89254289])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeNotGeneEdges',
#   'embedding': 'GCN',
#   'strategy': 'top',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.89254289])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeNotGeneEdges',
#   'embedding': 'GCN',
#   'strategy': 'top_bottom',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.89254289])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeNotGeneEdges',
#   'embedding': 'GCN',
#   'strategy': 'top_bottom_rand',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.89254289])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeNotGeneEdges',
#   'embedding': 'GCN',
#   'strategy': 'top_rand',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.89254289])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneAndPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'all',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.86767302])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneAndPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'bottom',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.86767302])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneAndPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'bottom_rand',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.86767302])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneAndPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'shared',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.86767302])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneAndPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'top',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.86767302])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneAndPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'top_bottom',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.86767302])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneAndPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'top_bottom_rand',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.86767302])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneAndPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'top_rand',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.86767302])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'all',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.86767302])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'bottom',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.86767302])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'bottom_rand',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.86767302])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'shared',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.86767302])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'top',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.86767302])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'top_bottom',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.86767302])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'top_bottom_rand',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.86767302])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'top_rand',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.86767302])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneNotPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'all',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.86767302])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneNotPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'bottom',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.86767302])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneNotPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'bottom_rand',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.86767302])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneNotPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'shared',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.86767302])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneNotPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'top',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.86767302])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneNotPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'top_bottom',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.86767302])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneNotPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'top_bottom_rand',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.86767302])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneNotPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'top_rand',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.86767302])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneOrPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'all',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.86767302])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneOrPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'bottom',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.86767302])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneOrPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'bottom_rand',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.86767302])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneOrPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'shared',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.86767302])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneOrPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'top',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.86767302])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneOrPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'top_bottom',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.86767302])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneOrPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'top_bottom_rand',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.86767302])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedGeneOrPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'top_rand',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.86767302])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'all',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.86767302])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'bottom',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.86767302])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'bottom_rand',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.86767302])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'shared',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.86767302])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'top',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.86767302])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'top_bottom',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.86767302])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'top_bottom_rand',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.86767302])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'top_rand',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.86767302])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeNotGeneEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'all',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.86767302])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeNotGeneEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'bottom',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.86767302])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeNotGeneEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'bottom_rand',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.86767302])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeNotGeneEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'shared',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.86767302])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeNotGeneEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'top',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.86767302])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeNotGeneEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'top_bottom',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.86767302])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeNotGeneEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'top_bottom_rand',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.86767302])},
#  {'th': 'no',
#   'qualified_nodes': 'SharedPhenotypeNotGeneEdges',
#   'embedding': 'Node2Vec',
#   'strategy': 'top_rand',
#   'classifier': 'svm',
#   'graph_type': 'PGDP',
#   'auc': array([0.86767302])}]

# %%
tmp = test_all_record_7.groupby(['embedding','qualified_nodes', 'strategy', 'graph_type', 'th','auc'])
count = 0
bench_mark_list = []
for i,j in tmp:
#     count +=1
#     print(j.shape[0])
#     print(i)
    emb = i[0]
#     graph_type = i[1]
    qualified_nodes = i[1]
    strategy = i[2]
    graph_type = i[3]
    th = i[4]
    auc = i[5]
#     print(i)
#     graph_type = i[1]
#     qualified_nodes = i[2]
#     strategy = i[3]
    
    for b in bench_mark:
#         count +=1
#         print(b)
        dd = list(b.values())

#         emb_b = dd[2]
#         graph_type_b = dd[5]
#         qualified_nodes_b = dd[1]
#         th_b = dd[0]
#         classifier_b = dd[4]
#         strategy_b = dd[3]
#         bm_val = dd[-1] 
#         print(list(dd))
#         print(bm_val)

        emb_b = dd[2]
        graph_type_b = dd[5]
        qualified_nodes_b = dd[1]
        th_b = dd[0]
        classifier_b = dd[4]
        strategy_b = dd[3]
        bm_val = dd[-1] 
#         print(dd)
#         print(emb_b, emb)
#         print(graph_type_b, graph_type)
#         print(qualified_nodes, qualified_nodes_b)
#         print(strategy,strategy_b)
        if (emb_b == emb) and (graph_type_b == graph_type) and (qualified_nodes_b == qualified_nodes) and (strategy_b == strategy):
#         if (emb_b == emb) and (qualified_nodes_b == qualified_nodes) and (strategy_b == strategy):
            count+=1
#             print('hi')
#             print(bench_mark_val)
            bench_mark_val = {}
            bench_mark_val['th'] = th
            bench_mark_val['qualified_nodes'] = qualified_nodes_b
            bench_mark_val['embedding'] = emb_b
            bench_mark_val['strategy'] = strategy_b
            bench_mark_val['classifier'] = classifier_b
            bench_mark_val['graph_type'] = graph_type
            bench_mark_val['diff'] = auc - bm_val 
            bench_mark_list.append(bench_mark_val)

#             'th', 'qualified_nodes', 'embedding', 'strategy', 'classifier',
#        'graph_type', 'auc'
#         print()
#         print(len(b)) 
#         for k,v in b.items(): 
#             print(k)
#     print(j)
print(count)
# print(bench_mark_list)
# Out:
# 1440

# %% [markdown]
# # Box plot

# %%
deviation_df = pd.DataFrame(bench_mark_list)

# %%
# tmp = deviation_df.groupby(['embedding','graph_type'])
tmp = deviation_df.groupby(['graph_type'])
# tmp = deviation_df.groupby(['embedding'])
# tmp = deviation_df.groupby(['qualified_nodes'])
for i,j in tmp:
#     print(j)
#     print(j.shape[0])
#     j['diff'].plot.bar()
#     j['diff'].plot(kind='bar',alpha=0.75, rot=45)
#     ax = sns.pointplot(x="strategy", y="diff", hue='qualified_nodes',data=j, join=False)
#     ax = sns.barplot(x="strategy", y="diff", hue='qualified_nodes',data=j)
    print(f'                            {i}')
#     if i[0] == 'GCN' and i[1] == 'GD':
#         j.iloc[:,-1] = j['diff'] + 0.03
    
    print(j)
    
    
#     ax = sns.boxplot(x="strategy", y="diff",data=j, boxprops=dict(alpha=.3))
    
#     plt.plot(np.zeros(7), linewidth=2)
#     ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# #     sns.despine(ax=b, left=True, bottom=True)
#     plt.show()
# Out:
#                             GD
#         th              qualified_nodes embedding  strategy classifier  \
# 0     0.05  SharedGeneAndPhenotypeEdges       GCN       all        svm
# 1      0.1  SharedGeneAndPhenotypeEdges       GCN       all        svm
# 2      0.4  SharedGeneAndPhenotypeEdges       GCN       all        svm
# 3      0.5  SharedGeneAndPhenotypeEdges       GCN       all        svm
# 4       no  SharedGeneAndPhenotypeEdges       GCN       all        svm
# ...    ...                          ...       ...       ...        ...
# 1425  0.05  SharedPhenotypeNotGeneEdges  Node2Vec  top_rand        svm
# 1426   0.1  SharedPhenotypeNotGeneEdges  Node2Vec  top_rand        svm
# 1427   0.4  SharedPhenotypeNotGeneEdges  Node2Vec  top_rand        svm
# 1428   0.5  SharedPhenotypeNotGeneEdges  Node2Vec  top_rand        svm
# 1429    no  SharedPhenotypeNotGeneEdges  Node2Vec  top_rand        svm
#
#      graph_type                    diff
# 0            GD     [0.068446855660942]
# 1            GD   [0.06702647341415902]
# 2            GD   [0.09738189291304811]
# 3            GD   [0.09614451358725362]
# 4            GD                   [0.0]
# ...         ...                     ...
# 1425         GD  [0.044087077827121846]
# 1426         GD  [0.036246623516702936]
# 1427         GD   [0.02590061146251954]
# 1428         GD   [0.03630111752003662]
# 1429         GD                   [0.0]
#
# [480 rows x 7 columns]
#                             PGD
#         th              qualified_nodes embedding  strategy classifier  \
# 5     0.05  SharedGeneAndPhenotypeEdges       GCN       all        svm
# 6      0.1  SharedGeneAndPhenotypeEdges       GCN       all        svm
# 7      0.4  SharedGeneAndPhenotypeEdges       GCN       all        svm
# 8      0.5  SharedGeneAndPhenotypeEdges       GCN       all        svm
# 9       no  SharedGeneAndPhenotypeEdges       GCN       all        svm
# ...    ...                          ...       ...       ...        ...
# 1430  0.05  SharedPhenotypeNotGeneEdges  Node2Vec  top_rand        svm
# 1431   0.1  SharedPhenotypeNotGeneEdges  Node2Vec  top_rand        svm
# 1432   0.4  SharedPhenotypeNotGeneEdges  Node2Vec  top_rand        svm
# 1433   0.5  SharedPhenotypeNotGeneEdges  Node2Vec  top_rand        svm
# 1434    no  SharedPhenotypeNotGeneEdges  Node2Vec  top_rand        svm
#
#      graph_type                     diff
# 5           PGD  [-0.020855969919660766]
# 6           PGD   [0.009636708649583103]
# 7           PGD    [0.02775169918166498]
# 8           PGD  [0.0014460067143827748]
# 9           PGD                    [0.0]
# ...         ...                      ...
# 1430        PGD    [0.05708958817060972]
# 1431        PGD    [0.04643357151167249]
# 1432        PGD    [0.03886341316546127]
# 1433        PGD    [0.04736959881187708]
# 1434        PGD                    [0.0]
#
# [480 rows x 7 columns]
#                             PGDP
#         th              qualified_nodes embedding  strategy classifier  \
# 10    0.05  SharedGeneAndPhenotypeEdges       GCN       all        svm
# 11     0.1  SharedGeneAndPhenotypeEdges       GCN       all        svm
# 12     0.4  SharedGeneAndPhenotypeEdges       GCN       all        svm
# 13     0.5  SharedGeneAndPhenotypeEdges       GCN       all        svm
# 14      no  SharedGeneAndPhenotypeEdges       GCN       all        svm
# ...    ...                          ...       ...       ...        ...
# 1435  0.05  SharedPhenotypeNotGeneEdges  Node2Vec  top_rand        svm
# 1436   0.1  SharedPhenotypeNotGeneEdges  Node2Vec  top_rand        svm
# 1437   0.4  SharedPhenotypeNotGeneEdges  Node2Vec  top_rand        svm
# 1438   0.5  SharedPhenotypeNotGeneEdges  Node2Vec  top_rand        svm
# 1439    no  SharedPhenotypeNotGeneEdges  Node2Vec  top_rand        svm
#
#      graph_type                     diff
# 10         PGDP   [0.025803768357200663]
# 11         PGDP  [-0.014671950705311132]
# 12         PGDP    [0.02109015745043996]
# 13         PGDP    [0.02577384329702237]
# 14         PGDP                    [0.0]
# ...         ...                      ...
# 1435       PGDP   [0.031724425767171716]
# 1436       PGDP    [0.03858553045965374]
# 1437       PGDP   [0.026410620361429493]
# 1438       PGDP   [0.024285644465429912]
# 1439       PGDP                    [0.0]
#
# [480 rows x 7 columns]

# %%
j['diff'] = j['diff'].astype(float)
for i in list(j.columns):
    print(i, j[i].dtype)
# Out:
# th object
# qualified_nodes object
# embedding object
# strategy object
# classifier object
# graph_type object
# diff float64

# %%
# tmp = deviation_df.groupby(['embedding','graph_type'])
tmp = deviation_df.groupby(['graph_type'])
# tmp = deviation_df.groupby(['embedding'])
# tmp = deviation_df.groupby(['qualified_nodes'])
for i,j in tmp:
    print(f'                            {i}')
    j['diff'] = j['diff'].astype(float)
#     ax = sns.violinplot(x='strategy', y='diff', hue='th', data=j)
#     ax = sns.violinplot(x='th', y='diff', data=j)
#     print(j)
    ax = sns.boxplot(x="strategy", y="diff",data=j, boxprops=dict(alpha=.3))
#     plt.plot(np.zeros(7), linewidth=2)
#     ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
#     sns.despine(ax=b, left=True, bottom=True)
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
    plt.show()
# Out:
#                             GD
# c:\users\anak\anaconda3\envs\py36\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
#                             PGD
# c:\users\anak\anaconda3\envs\py36\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
#                             PGDP
# c:\users\anak\anaconda3\envs\py36\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
ax = sns.violinplot(x='embedding', y='auc' , hue='graph_type',data=test_all_record_8)

# %%
ax = sns.violinplot(x='graph_type', y='auc' , hue='embedding',data=test_all_record_8)
