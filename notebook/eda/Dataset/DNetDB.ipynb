# %%
from pathlib import Path
import pandas as pd
import os
import os.path
import numpy as np

# %%
file = r'C:\Users\Anak\PycharmProjects\recreate_gene_disease\data\raw\DNetDB\Basic information of 108 diseases.xlsx'
disease_DNetDB = pd.read_excel(io=file)
disease_DNetDB
# Out:
#                                                Disease  \
# 0    Familial combined hyperlipidemia - lymphoblast...
# 1             Aortic stenosis - cardiac left ventricle
# 2               Systemic lupus erythematosus - B cells
# 3         Systemic lupus erythematosus - myeloid cells
# 4               Systemic lupus erythematosus - T cells
# 5     T cell Large granular lymphocyte leukemia - PBMC
# 6    Facioscapulohumeral dystrophy - vastus lateral...
# 7    Limb girdle muscular dystrophy 2a - proximal m...
# 8                      Hepatocellular adenomas - liver
# 9                   Osteoarthritis - synovial membrane
# 10            Rheumatoid arthritis - synovial membrane
# 11                   Schizophrenia - prefrontal cortex
# 12        Alzheimer's disease - hippocampal CA1 tissue
# 13         Barrett's esophagus - esophageal epithelium
# 14                 Plasma cell leukemia - plasma cells
# 15    Esophagus adenocarcinoma - esophageal epithelium
# ...

# %%
disease_name = disease_DNetDB['Disease']
disease_name.shape
# Out:
# (108,)
